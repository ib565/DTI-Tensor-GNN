# %%
import numpy as np
import nibabel as nib
from dipy.io import read_bvals_bvecs
from dipy.core.gradients import gradient_table

# %%
subject_id = "100206"
subject_path = f"diffusion_data/{subject_id}/T1w/Diffusion"
dwi_img = nib.load(f'{subject_path}/data.nii.gz')
mask_img = nib.load(f'{subject_path}/nodif_brain_mask.nii.gz')

# %%
# Convert to numpy arrays for processing
dwi_data = dwi_img.get_fdata()
mask = mask_img.get_fdata() > 0

# %%
print(f"DWI data shape: {dwi_data.shape}")  # Should be (X, Y, Z, num_volumes)
print(f"Mask shape: {mask.shape}")          # Should be (X, Y, Z)
# Out:
# DWI data shape: (145, 174, 145, 288)
# Mask shape: (145, 174, 145)

# %%
# Load gradient information (bvals and bvecs)
print("\nLoading gradient information...")
bvals, bvecs = read_bvals_bvecs(f'{subject_path}/bvals', 
                               f'{subject_path}/bvecs')
print(f"Number of gradient directions: {len(bvals)}")
print(f"bvals shape: {bvals.shape}")     # Should match number of volumes
print(f"bvecs shape: {bvecs.shape}")     # Should be (num_volumes, 3)
# Out:
# Loading gradient information...
# Number of gradient directions: 288
# bvals shape: (288,)
# bvecs shape: (288, 3)

# %%
# Create gradient table for DIPY
gtab = gradient_table(bvals, bvecs)

# %%
# Identify and extract B0 (non-diffusion weighted) volumes
b0_mask = gtab.b0s_mask
b1000_mask = (bvals >= 990) & (bvals <= 1010)
print(f"Number of b=1000 directions: {np.sum(b1000_mask)}")

b0_data = dwi_data[..., b0_mask]
print(f"\nNumber of B0 volumes: {np.sum(b0_mask)}")
print(f"B0 data shape: {b0_data.shape}")

# Average B0 volumes to get a single reference image
b0_avg = np.mean(b0_data, axis=-1)
print(f"Average B0 shape: {b0_avg.shape}")
# Out:
# Number of b=1000 directions: 90
#
# Number of B0 volumes: 18
# B0 data shape: (145, 174, 145, 18)
# Average B0 shape: (145, 174, 145)

# %%
# Extract and normalize diffusion weighted volumes
dwi_vols = dwi_data[..., b1000_mask]
print(f"\nNumber of b1000 DWI volumes: {np.sum(b1000_mask)}")
print(f"DWI volumes shape: {dwi_vols.shape}")
# Out:
# Number of b1000 DWI volumes: 90
# DWI volumes shape: (145, 174, 145, 90)

# %%
# Maybe mask out voxels with very low b0 signal
b0_threshold = 250  # or some suitable threshold
valid_b0_mask = b0_avg > b0_threshold
mask = mask & valid_b0_mask  # Combine with brain mask

# %%
# Find valid voxels using the brain mask
valid_idx = np.where(mask)
print(f"\nNumber of valid voxels in mask: {len(valid_idx[0])}")
# Out:
# Number of valid voxels in mask: 926671

# %%
# Sample random voxels for training
n_samples = 100000  # Adjust this number based on your needs
sample_idx = np.random.choice(len(valid_idx[0]), 
                            min(n_samples, len(valid_idx[0])), 
                            replace=False)

# %%
# Extract features (signal intensities) from sampled voxels
features = []
for idx in sample_idx:
    x, y, z = valid_idx[0][idx], valid_idx[1][idx], valid_idx[2][idx]
    signal = dwi_vols[x, y, z, :]
    b0_ref = b0_avg[x, y, z]
    normalized_signal = signal / (b0_ref + 1e-6)
    features.append(normalized_signal)

# %%
features = np.array(features)
gradient_directions = bvecs[b1000_mask]  # Only keep directions for DWI volumes

# %%
print("\nFinal data shapes:")
print(f"Features shape: {features.shape}")           # Should be (n_samples, n_directions)
print(f"Gradient directions shape: {gradient_directions.shape}")  # Should be (n_directions, 3)

# Basic sanity checks
print("\nSanity checks:")
print(f"Max normalized value: {np.max(features)}")
print(f"Min normalized value: {np.min(features)}")
print(f"Gradient directions magnitude close to 1: {np.allclose(np.linalg.norm(gradient_directions, axis=1), 1, atol=1e-3)}")
# Out:
# Final data shapes:
# Features shape: (100000, 90)
# Gradient directions shape: (90, 3)
#
# Sanity checks:
# Max normalized value: 3.591347150072769
# Min normalized value: 0.0
# Gradient directions magnitude close to 1: True

# %%
print("Loading ground truth data...")
gt_data = np.load('ground_truth.npz')
ground_truth_tensors = gt_data['tensors']
# ground_truth_tensors = torch.tensor(ground_truth_tensors, dtype=torch.float32)
valid_coordinates = gt_data['coordinates']
print(f"Ground truth tensors shape: {ground_truth_tensors.shape}")
print(f"Valid coordinates shape: {valid_coordinates.shape}")
# Out:
# Loading ground truth data...
# Ground truth tensors shape: (936256, 6)
# Valid coordinates shape: (936256, 3)

# %%
# Number of directions to use for sparse estimation
n_directions = 21  # We can adjust this number

def create_graph_data(features, direction_indices, batch_size = 32, threshold_angle = 60):
    """
    Create graph data for a batch of samples, including ground tensor
    """
    voxel_indices = np.random.choice(len(features), size = batch_size, replace = False)
    # print(f"Creating graphs for batch of {batch_size} voxels using {n_sparse_directions} directions each")

    batch_nodes = []
    batch_edges = []
    batch_tensors = []
    batch_edge_weights = []  

    current_directions = gradient_directions[direction_indices]
    for idx in voxel_indices:
        signals = features[idx, direction_indices]
        
        # Create edges acc. to angle
        directions_norm = current_directions / np.linalg.norm(current_directions, axis=1, keepdims=True)
        cos_sim = np.dot(directions_norm, directions_norm.T)
        angles = np.arccos(np.clip(cos_sim, -1.0, 1.0)) * 180/np.pi
        
        src, dst = np.where(angles < threshold_angle)
        mask = src != dst
        edges = np.column_stack([src[mask], dst[mask]])

        weights = cos_sim[src[mask], dst[mask]]

        nodes = signals.reshape(-1, 1)
        batch_nodes.append(nodes)
        batch_edges.append(edges)
        batch_edge_weights.append(weights)
        batch_tensors.append(ground_truth_tensors[idx])
        
    return batch_nodes, batch_edges, batch_edge_weights, batch_tensors

# nodes, edges, gt_tensors = create_graph_data(features, gradient_directions, n_directions)
# # Print info for verification
# print("\nBatch statistics:")
# print(f"Number of samples in batch: {len(nodes)}")
# print(f"Number of nodes per graph: {nodes[0].shape[0]}")
# print(f"Node feature dimensionality: {nodes[0].shape[1]}")
# print(f"Ground truth tensors: {len(gt_tensors)}")

# # Print example for first sample
# print("\nFirst sample in batch:")
# print(f"Number of nodes: {nodes[0].shape[0]}")
# print(f"Number of edges: {edges[0].shape[0]}")
# print(f"Ground truth tensor components: {gt_tensors[0]}")

# %%
def select_diverse_directions(all_directions, n_select=21):
    selected = [0]  # Start with first direction
    while len(selected) < n_select:
        # Calculate angles with all selected directions
        angles = []
        for i in range(len(all_directions)):
            if i in selected:
                continue
            min_angle = float('inf')
            for s in selected:
                # Cosine similarity
                angle = np.arccos(np.clip(
                    np.dot(all_directions[i], all_directions[s]), -1.0, 1.0))
                min_angle = min(min_angle, angle)
            angles.append((i, min_angle))
        # Select direction with largest minimum angle
        next_idx = max(angles, key=lambda x: x[1])[0]
        selected.append(next_idx)
    return selected

# %%
def initialize_direction_sets(all_directions, n_sets=3, n_directions=21):
    base_sets = []
    n_total = len(all_directions)
    
    for i in range(n_sets):
        # Create a shuffled index array for this set
        shuffled_indices = np.random.permutation(n_total)
        # Use select_diverse_directions on the shuffled indices
        selected = select_diverse_directions(all_directions[shuffled_indices], n_directions)
        # Map back to original indices
        original_indices = shuffled_indices[selected]
        base_sets.append(original_indices)
    
    return base_sets

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import MessagePassing
from torch_geometric.nn import global_mean_pool
import torch.optim as optim
from torch_geometric.data import Data, Batch
from sklearn.model_selection import train_test_split

# %%
class DiffusionGNN(torch.nn.Module):
    def __init__(self, node_features = 1, hidden_dim = 128):
        super(DiffusionGNN, self).__init__()
    
        # Layers
        self.conv1 = DiffusionConv(node_features, hidden_dim)
        self.conv2 = DiffusionConv(hidden_dim, hidden_dim)

        # MLP for tensor prediction
        self.mlp = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 6),
        )

        # self.scale_net = nn.Sequential(
        #     nn.Linear(hidden_dim, 1),
        #     nn.Sigmoid()
        # )

        self.scale_net = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 6),
            nn.Softplus()
        )

        self.register_buffer('loss_weights',
            torch.tensor([10, 50, 10, 50, 50, 10]))

    
    def forward(self, x, edge_index, edge_attr, batch):
        """
        x: node_features
        edge_index = graph conn info [2, num_edges]
        batch: batch assignment for nodes
        """
        # pass through gnn layers
        x = self.conv1(x, edge_index, edge_attr)
        x = F.relu(x)
        x = self.conv2(x, edge_index, edge_attr)
        x = F.relu(x)

        # combine node features for graph
        x = global_mean_pool(x, batch)  # [batch_size, hidden_dim]

        # raw predictions
        out = self.mlp(x)

        scales = self.scale_net(x)
        out = out * scales
        
        diag_idx = [0, 2, 5]
        offdiag_idx = [1, 3, 4]

        # Diagonal elements: [0,1] using sigmoid
        diag = torch.sigmoid(out[:, diag_idx])
        
        # Off-diagonal elements: [-1,1] using tanh
        offdiag = torch.tanh(out[:, offdiag_idx])

        out_reordered = torch.zeros_like(out)
        out_reordered[:, diag_idx] = diag
        out_reordered[:, offdiag_idx] = offdiag
        
        return out_reordered
    
    def weighted_mse_loss(self, pred, target):
        squared_diff = (pred - target) ** 2  # [batch_size, 6]
        weighted_diff = squared_diff * self.loss_weights
        return torch.mean(weighted_diff)


class DiffusionConv(MessagePassing):
    def __init__(self, in_channels, out_channels):
        super(DiffusionConv, self).__init__(aggr="mean")
        
        # MLP to process messages
        self.mlp = nn.Sequential(
            nn.Linear(2 * in_channels, out_channels),
            nn.ReLU(),
            nn.Linear(out_channels, out_channels)
        )
    
    def forward(self, x, edge_index, edge_weight):
        return self.propagate(edge_index, x=x, edge_weight = edge_weight)
    
    def message(self, x_i, x_j, edge_weight):
        """
        x_i: features of target nodes
        x_j: features of source nodes
        Returns: messages to be aggregated
        """
        tmp = torch.cat([x_i, x_j], dim = 1)
        return self.mlp(tmp) * edge_weight.view(-1,1)

# %%
def convert_to_torch_geometric(nodes, edges, edge_weights, tensors):
    data_list = []
    for i in range(len(nodes)):
        # Ensure tensor is properly shaped [6] not flattened
        tensor = tensors[i].reshape(-1, 6) if len(tensors[i].shape) == 1 else tensors[i]
        
        data = Data(
            x=torch.FloatTensor(nodes[i]),          # [n_nodes, 4]
            edge_index=torch.LongTensor(edges[i].T), # [2, n_edges]
            edge_attr=torch.FloatTensor(edge_weights[i]),
            y=torch.FloatTensor(tensor)             # [1, 6]
        )
        data_list.append(data)
    return data_list

# %%
train_idx, test_idx = train_test_split(np.arange(len(features)), test_size=0.2, random_state=42)
print(f"Training with {len(train_idx)} voxels, testing with {len(test_idx)} voxels")
# Out:
# Training with 80000 voxels, testing with 20000 voxels

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
n_sets = 3
direction_sets = initialize_direction_sets(gradient_directions, n_sets)

# %%
# Training
model = DiffusionGNN(node_features=1, hidden_dim=64).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.0005)
batch_size = 32
epochs = 10

all_pred_values = [[] for _ in range(6)]
all_gt_values = [[] for _ in range(6)]

print("Starting training...")
for epoch in range(epochs):
    direction_indices = direction_sets[epoch % n_sets]
    model.train()
    epoch_loss = 0
    n_batches = 0

    # Shuffle training indices
    np.random.shuffle(train_idx)
    
    # Process batches
    for start in range(0, len(train_idx), batch_size):
        batch_idx = train_idx[start:start + batch_size]
        # Create graphs for batch
        nodes, edges, edge_weights, tensors = create_graph_data(
            features[batch_idx], direction_indices
        )
        
        # Convert to PyG and process
        data_list = convert_to_torch_geometric(nodes, edges, edge_weights, tensors)
        batch_data = Batch.from_data_list(data_list).to(device)
        
        # Training step
        optimizer.zero_grad()
        pred = model(batch_data.x, batch_data.edge_index, batch_data.edge_attr, batch_data.batch)
        y_true = batch_data.y

        # loss = F.mse_loss(pred, y_true) * 1e6
        loss = model.weighted_mse_loss(pred, y_true) * 1e6

        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        n_batches += 1
    
    for i in range(6):
        all_pred_values[i].extend(pred[:, i].detach().cpu().numpy())
        all_gt_values[i].extend(batch_data.y[:, i].cpu().numpy())

    if epoch % 1 == 0:  # Print every epoch
        # Move entire tensors to CPU once
        pred_cpu = pred.detach().cpu().numpy()
        gt_cpu = batch_data.y.cpu().numpy()
        
        print(f"\nEpoch {epoch+1} Statistics:")
        # Component-wise prediction stats
        print("\nPredictions per component:")
        for i in range(6):
            print(f"Component {i}: min={np.min(pred_cpu[:,i]):.2e}, "
                f"max={np.max(pred_cpu[:,i]):.2e}, "
                f"mean={np.mean(pred_cpu[:,i]):.2e}, "
                f"std={np.std(pred_cpu[:,i]):.2e}")
        
        # Component-wise ground truth stats
        print("\nGround Truth per component:")
        for i in range(6):
            print(f"Component {i}: min={np.min(gt_cpu[:,i]):.2e}, "
                f"max={np.max(gt_cpu[:,i]):.2e}, "
                f"mean={np.mean(gt_cpu[:,i]):.2e}, "
                f"std={np.std(gt_cpu[:,i]):.2e}")
        
        # Relative error per component
        print("\nRelative Error per component:")
        for i in range(6):
            rel_error = np.mean(np.abs(pred_cpu[:,i] - gt_cpu[:,i]) / 
                            (np.abs(gt_cpu[:,i]) + 1e-10))
            print(f"Component {i}: {rel_error:.2e}")
    
    avg_loss = epoch_loss / n_batches
    print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.6f}")
    

print("\nTraining Values Statistics:")
for i in range(6):
    pred_vals = np.array(all_pred_values[i])
    gt_vals = np.array(all_gt_values[i])
    print(f"\nComponent {i}:")
    print("Predictions:")
    print(f"Min: {np.min(pred_vals):.6f}")
    print(f"Max: {np.max(pred_vals):.6f}")
    print(f"Mean: {np.mean(pred_vals):.6f}")
    print(f"1st percentile: {np.percentile(pred_vals, 1):.6f}")
    print(f"99th percentile: {np.percentile(pred_vals, 99):.6f}")
    print("Ground Truth:")
    print(f"Min: {np.min(gt_vals):.6f}")
    print(f"Max: {np.max(gt_vals):.6f}")
    print(f"Mean: {np.mean(gt_vals):.6f}")
    print(f"1st percentile: {np.percentile(gt_vals, 1):.6f}")
    print(f"99th percentile: {np.percentile(gt_vals, 99):.6f}")

# Final evaluation on full test set
print("\nFinal Evaluation...")
model.eval()
test_losses = []
all_test_preds = []
all_test_gts = []

with torch.no_grad():
    for start in range(0, len(test_idx), batch_size):
        batch_idx = test_idx[start:start + batch_size]
        if len(batch_idx) < batch_size:
            continue
            
        nodes, edges, edge_weights, tensors = create_graph_data(
            features[batch_idx], direction_indices
        )
        data_list = convert_to_torch_geometric(nodes, edges, edge_weights, tensors)
        batch_data = Batch.from_data_list(data_list).to(device)
        
        pred = model(batch_data.x, batch_data.edge_index, batch_data.edge_attr, batch_data.batch)

        y_true = batch_data.y

        # loss = F.mse_loss(pred, y_true) * 1e6
        loss = model.weighted_mse_loss(pred, y_true) * 1e6

        pred = pred.cpu()
        batch_data = batch_data.cpu()
        
        test_loss = F.mse_loss(pred, batch_data.y) * 1e6
        test_losses.append(test_loss.item())
        
        # Store predictions and ground truths
        all_test_preds.append(pred.detach().numpy())
        all_test_gts.append(batch_data.y.numpy())

# Combine all batches
all_test_preds = np.concatenate(all_test_preds, axis=0)
all_test_gts = np.concatenate(all_test_gts, axis=0)

# Print overall test loss
avg_test_loss = np.mean(test_losses)
print(f"\nFinal Test Results:")
print(f"Average test loss: {avg_test_loss:.6f}")

# Component-wise analysis
print("\nTest Set Component Analysis:")
for i in range(6):
    pred_comp = all_test_preds[:, i]
    gt_comp = all_test_gts[:, i]
    
    # Stats
    print(f"\nComponent {i}:")
    print(f"Predictions - min: {np.min(pred_comp):.2e}, max: {np.max(pred_comp):.2e}, "
          f"mean: {np.mean(pred_comp):.2e}, std: {np.std(pred_comp):.2e}")
    print(f"Ground Truth - min: {np.min(gt_comp):.2e}, max: {np.max(gt_comp):.2e}, "
          f"mean: {np.mean(gt_comp):.2e}, std: {np.std(gt_comp):.2e}")
    
    # Relative Error
    rel_error = np.mean(np.abs(pred_comp - gt_comp) / (np.abs(gt_comp) + 1e-10))
    print(f"Relative Error: {rel_error:.2e}")


# Print some example predictions vs ground truth
print("\nExample predictions vs ground truth:")
for i in range(5):
    print(f"\nSample {i+1}:")
    print(f"Predicted: {pred[i].numpy()}")
    print(f"Actual: {batch_data.y[i].numpy()}")
# Out:
# Starting training...
#
# Epoch 1 Statistics:
#
# Predictions per component:
# Component 0: min=2.97e-08, max=2.34e-06, mean=3.41e-07, std=5.82e-07
# Component 1: min=2.51e-05, max=4.18e-05, mean=3.36e-05, std=4.03e-06
# Component 2: min=6.91e-10, max=1.27e-07, mean=1.55e-08, std=3.15e-08
# Component 3: min=2.53e-06, max=3.17e-05, mean=1.53e-05, std=6.66e-06
# Component 4: min=-1.97e-05, max=-4.63e-06, mean=-1.12e-05, std=4.39e-06
# Component 5: min=1.07e-06, max=3.21e-05, mean=6.16e-06, std=7.91e-06
#
# Ground Truth per component:
# Component 0: min=1.62e-04, max=5.48e-04, mean=3.04e-04, std=9.81e-05
# Component 1: min=-4.25e-05, max=4.70e-05, mean=-1.67e-06, std=2.24e-05
# Component 2: min=1.67e-04, max=4.85e-04, mean=3.20e-04, std=9.22e-05
# Component 3: min=-1.88e-05, max=4.25e-05, mean=1.49e-05, std=1.61e-05
# Component 4: min=-6.59e-05, max=2.80e-05, mean=-1.14e-05, std=2.10e-05
# Component 5: min=1.43e-04, max=4.65e-04, mean=2.95e-04, std=8.37e-05
#
# Relative Error per component:
# Component 0: 9.99e-01
# Component 1: 4.75e+00
# Component 2: 1.00e+00
# Component 3: 3.22e+00
# Component 4: 1.53e+00
# Component 5: 9.78e-01
# Epoch 1/10, Loss: 27396.968474
#
# Epoch 2 Statistics:
#
# Predictions per component:
# Component 0: min=5.57e-07, max=3.80e-05, mean=8.14e-06, std=9.03e-06
# Component 1: min=-1.89e-05, max=-1.25e-06, mean=-7.55e-06, std=3.51e-06
# Component 2: min=2.05e-08, max=3.25e-06, mean=5.76e-07, std=7.57e-07
# Component 3: min=5.01e-06, max=2.91e-05, mean=1.44e-05, std=6.13e-06
# Component 4: min=-1.61e-05, max=7.11e-06, mean=-9.75e-06, std=6.33e-06
# Component 5: min=4.46e-05, max=7.07e-04, mean=2.29e-04, std=1.67e-04
#
# Ground Truth per component:
# Component 0: min=1.62e-04, max=5.48e-04, mean=3.04e-04, std=9.81e-05
# Component 1: min=-4.25e-05, max=4.70e-05, mean=-1.67e-06, std=2.24e-05
# Component 2: min=1.67e-04, max=4.85e-04, mean=3.20e-04, std=9.22e-05
# Component 3: min=-1.88e-05, max=4.25e-05, mean=1.49e-05, std=1.61e-05
# Component 4: min=-6.59e-05, max=2.80e-05, mean=-1.14e-05, std=2.10e-05
# Component 5: min=1.43e-04, max=4.65e-04, mean=2.95e-04, std=8.37e-05
#
# Relative Error per component:
# Component 0: 9.72e-01
# Component 1: 1.69e+00
# Component 2: 9.98e-01
# Component 3: 6.76e+00
# Component 4: 1.87e+00
# Component 5: 5.73e-01
# Epoch 2/10, Loss: 0.526574
#
# Epoch 3 Statistics:
#
# Predictions per component:
# Component 0: min=2.81e-04, max=3.27e-04, mean=3.02e-04, std=1.09e-05
# Component 1: min=-1.37e-06, max=4.62e-06, mean=2.37e-06, std=1.40e-06
# Component 2: min=2.90e-04, max=3.33e-04, mean=3.20e-04, std=9.90e-06
# Component 3: min=1.46e-05, max=2.41e-05, mean=1.94e-05, std=2.26e-06
# Component 4: min=-1.74e-05, max=-7.44e-06, mean=-1.26e-05, std=2.45e-06
# Component 5: min=2.73e-04, max=3.18e-04, mean=2.93e-04, std=1.07e-05
#
# Ground Truth per component:
# Component 0: min=1.62e-04, max=5.48e-04, mean=3.04e-04, std=9.81e-05
# Component 1: min=-4.25e-05, max=4.70e-05, mean=-1.67e-06, std=2.24e-05
# Component 2: min=1.67e-04, max=4.85e-04, mean=3.20e-04, std=9.22e-05
# Component 3: min=-1.88e-05, max=4.25e-05, mean=1.49e-05, std=1.61e-05
# Component 4: min=-6.59e-05, max=2.80e-05, mean=-1.14e-05, std=2.10e-05
# Component 5: min=1.43e-04, max=4.65e-04, mean=2.95e-04, std=8.37e-05
#
# Relative Error per component:
# Component 0: 3.15e-01
# Component 1: 1.02e+00
# Component 2: 2.88e-01
# Component 3: 1.06e+01
# Component 4: 1.78e+00
# Component 5: 2.84e-01
# Epoch 3/10, Loss: 0.291020
#
# Epoch 4 Statistics:
#
# Predictions per component:
# Component 0: min=2.91e-04, max=3.05e-04, mean=3.00e-04, std=3.14e-06
# Component 1: min=-5.58e-06, max=2.28e-06, mean=-2.09e-07, std=1.60e-06
# Component 2: min=3.09e-04, max=3.22e-04, mean=3.17e-04, std=2.80e-06
# Component 3: min=1.22e-05, max=1.88e-05, mean=1.59e-05, std=1.51e-06
# Component 4: min=-1.30e-05, max=-9.87e-06, mean=-1.17e-05, std=6.18e-07
# Component 5: min=2.82e-04, max=2.98e-04, mean=2.92e-04, std=3.79e-06
#
# Ground Truth per component:
# Component 0: min=1.62e-04, max=5.48e-04, mean=3.04e-04, std=9.81e-05
# Component 1: min=-4.25e-05, max=4.70e-05, mean=-1.67e-06, std=2.24e-05
# Component 2: min=1.67e-04, max=4.85e-04, mean=3.20e-04, std=9.22e-05
# Component 3: min=-1.88e-05, max=4.25e-05, mean=1.49e-05, std=1.61e-05
# Component 4: min=-6.59e-05, max=2.80e-05, mean=-1.14e-05, std=2.10e-05
# Component 5: min=1.43e-04, max=4.65e-04, mean=2.95e-04, std=8.37e-05
#
# Relative Error per component:
# Component 0: 3.05e-01
# Component 1: 9.76e-01
# Component 2: 2.80e-01
# Component 3: 8.50e+00
# Component 4: 1.72e+00
# Component 5: 2.74e-01
# Epoch 4/10, Loss: 0.065469
#
# Epoch 5 Statistics:
#
# Predictions per component:
# Component 0: min=2.87e-04, max=3.18e-04, mean=3.05e-04, std=8.82e-06
# Component 1: min=-6.15e-07, max=1.04e-06, mean=2.03e-07, std=5.15e-07
# Component 2: min=3.03e-04, max=3.34e-04, mean=3.21e-04, std=8.44e-06
# Component 3: min=1.37e-05, max=2.25e-05, mean=1.72e-05, std=2.25e-06
# Component 4: min=-1.09e-05, max=-8.89e-06, mean=-1.04e-05, std=6.26e-07
# Component 5: min=2.77e-04, max=3.08e-04, mean=2.96e-04, std=8.88e-06
#
# Ground Truth per component:
# Component 0: min=1.62e-04, max=5.48e-04, mean=3.04e-04, std=9.81e-05
# Component 1: min=-4.25e-05, max=4.70e-05, mean=-1.67e-06, std=2.24e-05
# Component 2: min=1.67e-04, max=4.85e-04, mean=3.20e-04, std=9.22e-05
# Component 3: min=-1.88e-05, max=4.25e-05, mean=1.49e-05, std=1.61e-05
# Component 4: min=-6.59e-05, max=2.80e-05, mean=-1.14e-05, std=2.10e-05
# Component 5: min=1.43e-04, max=4.65e-04, mean=2.95e-04, std=8.37e-05
#
# Relative Error per component:
# Component 0: 3.21e-01
# Component 1: 9.78e-01
# Component 2: 2.90e-01
# Component 3: 9.01e+00
# Component 4: 1.61e+00
# Component 5: 2.81e-01
# Epoch 5/10, Loss: 0.062932
#
# Epoch 6 Statistics:
#
# Predictions per component:
# Component 0: min=2.92e-04, max=3.04e-04, mean=3.00e-04, std=2.51e-06
# Component 1: min=-2.18e-06, max=-1.25e-06, mean=-1.66e-06, std=1.63e-07
# Component 2: min=3.08e-04, max=3.20e-04, mean=3.16e-04, std=2.61e-06
# Component 3: min=1.29e-05, max=1.54e-05, mean=1.50e-05, std=4.66e-07
# Component 4: min=-1.23e-05, max=-8.97e-06, mean=-1.10e-05, std=6.72e-07
# Component 5: min=2.85e-04, max=2.96e-04, mean=2.93e-04, std=2.79e-06
#
# Ground Truth per component:
# Component 0: min=1.62e-04, max=5.48e-04, mean=3.04e-04, std=9.81e-05
# Component 1: min=-4.25e-05, max=4.70e-05, mean=-1.67e-06, std=2.24e-05
# Component 2: min=1.67e-04, max=4.85e-04, mean=3.20e-04, std=9.22e-05
# Component 3: min=-1.88e-05, max=4.25e-05, mean=1.49e-05, std=1.61e-05
# Component 4: min=-6.59e-05, max=2.80e-05, mean=-1.14e-05, std=2.10e-05
# Component 5: min=1.43e-04, max=4.65e-04, mean=2.95e-04, std=8.37e-05
#
# Relative Error per component:
# Component 0: 3.06e-01
# Component 1: 1.07e+00
# Component 2: 2.80e-01
# Component 3: 7.66e+00
# Component 4: 1.60e+00
# Component 5: 2.74e-01
# Epoch 6/10, Loss: 0.068233
#
# Epoch 7 Statistics:
#
# Predictions per component:
# Component 0: min=3.00e-04, max=3.12e-04, mean=3.04e-04, std=2.36e-06
# Component 1: min=-1.64e-06, max=-1.39e-06, mean=-1.44e-06, std=5.28e-08
# Component 2: min=3.17e-04, max=3.26e-04, mean=3.20e-04, std=2.00e-06
# Component 3: min=1.49e-05, max=1.55e-05, mean=1.51e-05, std=1.33e-07
# Component 4: min=-1.23e-05, max=-1.12e-05, mean=-1.16e-05, std=2.63e-07
# Component 5: min=2.91e-04, max=3.00e-04, mean=2.94e-04, std=1.95e-06
#
# Ground Truth per component:
# Component 0: min=1.62e-04, max=5.48e-04, mean=3.04e-04, std=9.81e-05
# Component 1: min=-4.25e-05, max=4.70e-05, mean=-1.67e-06, std=2.24e-05
# Component 2: min=1.67e-04, max=4.85e-04, mean=3.20e-04, std=9.22e-05
# Component 3: min=-1.88e-05, max=4.25e-05, mean=1.49e-05, std=1.61e-05
# Component 4: min=-6.59e-05, max=2.80e-05, mean=-1.14e-05, std=2.10e-05
# Component 5: min=1.43e-04, max=4.65e-04, mean=2.95e-04, std=8.37e-05
#
# Relative Error per component:
# Component 0: 3.07e-01
# Component 1: 1.06e+00
# Component 2: 2.81e-01
# Component 3: 7.99e+00
# Component 4: 1.71e+00
# Component 5: 2.72e-01
# Epoch 7/10, Loss: 0.062445
#
# Epoch 8 Statistics:
#
# Predictions per component:
# Component 0: min=3.01e-04, max=3.12e-04, mean=3.09e-04, std=2.87e-06
# Component 1: min=-1.31e-06, max=-1.07e-06, mean=-1.11e-06, std=4.81e-08
# Component 2: min=3.20e-04, max=3.30e-04, mean=3.27e-04, std=2.88e-06
# Component 3: min=1.43e-05, max=1.47e-05, mean=1.45e-05, std=9.26e-08
# Component 4: min=-1.18e-05, max=-1.14e-05, mean=-1.16e-05, std=9.95e-08
# Component 5: min=2.92e-04, max=3.04e-04, mean=3.00e-04, std=3.08e-06
#
# Ground Truth per component:
# Component 0: min=1.62e-04, max=5.48e-04, mean=3.04e-04, std=9.81e-05
# Component 1: min=-4.25e-05, max=4.70e-05, mean=-1.67e-06, std=2.24e-05
# Component 2: min=1.67e-04, max=4.85e-04, mean=3.20e-04, std=9.22e-05
# Component 3: min=-1.88e-05, max=4.25e-05, mean=1.49e-05, std=1.61e-05
# Component 4: min=-6.59e-05, max=2.80e-05, mean=-1.14e-05, std=2.10e-05
# Component 5: min=1.43e-04, max=4.65e-04, mean=2.95e-04, std=8.37e-05
#
# Relative Error per component:
# Component 0: 3.12e-01
# Component 1: 1.04e+00
# Component 2: 2.86e-01
# Component 3: 7.63e+00
# Component 4: 1.70e+00
# Component 5: 2.77e-01
# Epoch 8/10, Loss: 0.062150
#
# Epoch 9 Statistics:
#
# Predictions per component:
# Component 0: min=2.90e-04, max=3.35e-04, mean=3.04e-04, std=7.83e-06
# Component 1: min=-1.20e-06, max=-7.40e-07, mean=-9.94e-07, std=1.07e-07
# Component 2: min=3.07e-04, max=3.53e-04, mean=3.21e-04, std=7.91e-06
# Component 3: min=1.35e-05, max=1.42e-05, mean=1.39e-05, std=1.11e-07
# Component 4: min=-1.23e-05, max=-1.09e-05, mean=-1.12e-05, std=2.29e-07
# Component 5: min=2.80e-04, max=3.27e-04, mean=2.95e-04, std=8.23e-06
#
# Ground Truth per component:
# Component 0: min=1.62e-04, max=5.48e-04, mean=3.04e-04, std=9.81e-05
# Component 1: min=-4.25e-05, max=4.70e-05, mean=-1.67e-06, std=2.24e-05
# Component 2: min=1.67e-04, max=4.85e-04, mean=3.20e-04, std=9.22e-05
# Component 3: min=-1.88e-05, max=4.25e-05, mean=1.49e-05, std=1.61e-05
# Component 4: min=-6.59e-05, max=2.80e-05, mean=-1.14e-05, std=2.10e-05
# Component 5: min=1.43e-04, max=4.65e-04, mean=2.95e-04, std=8.37e-05
#
# Relative Error per component:
# Component 0: 3.10e-01
# Component 1: 1.02e+00
# Component 2: 2.86e-01
# Component 3: 7.37e+00
# Component 4: 1.65e+00
# Component 5: 2.75e-01
# Epoch 9/10, Loss: 0.066893
#
# Epoch 10 Statistics:
#
# Predictions per component:
# Component 0: min=2.73e-04, max=2.96e-04, mean=2.92e-04, std=3.64e-06
# Component 1: min=-1.36e-06, max=-8.10e-07, mean=-1.22e-06, std=8.83e-08
# Component 2: min=2.93e-04, max=3.12e-04, mean=3.08e-04, std=2.99e-06
# Component 3: min=1.48e-05, max=1.51e-05, mean=1.49e-05, std=5.22e-08
# Component 4: min=-1.15e-05, max=-1.11e-05, mean=-1.13e-05, std=6.01e-08
# Component 5: min=2.68e-04, max=2.88e-04, mean=2.84e-04, std=3.26e-06
#
# Ground Truth per component:
# Component 0: min=1.62e-04, max=5.48e-04, mean=3.04e-04, std=9.81e-05
# Component 1: min=-4.25e-05, max=4.70e-05, mean=-1.67e-06, std=2.24e-05
# Component 2: min=1.67e-04, max=4.85e-04, mean=3.20e-04, std=9.22e-05
# Component 3: min=-1.88e-05, max=4.25e-05, mean=1.49e-05, std=1.61e-05
# Component 4: min=-6.59e-05, max=2.80e-05, mean=-1.14e-05, std=2.10e-05
# Component 5: min=1.43e-04, max=4.65e-04, mean=2.95e-04, std=8.37e-05
#
# Relative Error per component:
# Component 0: 3.00e-01
# Component 1: 1.04e+00
# Component 2: 2.72e-01
# Component 3: 7.89e+00
# Component 4: 1.67e+00
# Component 5: 2.67e-01
# Epoch 10/10, Loss: 0.062744
#
# Training Values Statistics:
#
# Component 0:
# Predictions:
# Min: 0.000000
# Max: 0.000335
# Mean: 0.000242
# 1st percentile: 0.000000
# 99th percentile: 0.000321
# Ground Truth:
# Min: 0.000162
# Max: 0.000548
# Mean: 0.000304
# 1st percentile: 0.000162
# 99th percentile: 0.000548
#
# Component 1:
# Predictions:
# Min: -0.000019
# Max: 0.000042
# Mean: 0.000002
# 1st percentile: -0.000012
# 99th percentile: 0.000039
# Ground Truth:
# Min: -0.000042
# Max: 0.000047
# Mean: -0.000002
# 1st percentile: -0.000042
# 99th percentile: 0.000047
#
# Component 2:
# Predictions:
# Min: 0.000000
# Max: 0.000353
# Mean: 0.000255
# 1st percentile: 0.000000
# 99th percentile: 0.000333
# Ground Truth:
# Min: 0.000167
# Max: 0.000485
# Mean: 0.000320
# 1st percentile: 0.000167
# 99th percentile: 0.000485
#
# Component 3:
# Predictions:
# Min: 0.000003
# Max: 0.000032
# Mean: 0.000016
# 1st percentile: 0.000005
# 99th percentile: 0.000026
# Ground Truth:
# Min: -0.000019
# Max: 0.000043
# Mean: 0.000015
# 1st percentile: -0.000019
# 99th percentile: 0.000043
#
# Component 4:
# Predictions:
# Min: -0.000020
# Max: 0.000007
# Mean: -0.000011
# 1st percentile: -0.000019
# 99th percentile: 0.000002
# Ground Truth:
# Min: -0.000066
# Max: 0.000028
# Mean: -0.000011
# 1st percentile: -0.000066
# 99th percentile: 0.000028
#
# Component 5:
# Predictions:
# Min: 0.000001
# Max: 0.000707
# Mean: 0.000258
# 1st percentile: 0.000002
# 99th percentile: 0.000444
# Ground Truth:
# Min: 0.000143
# Max: 0.000465
# Mean: 0.000295
# 1st percentile: 0.000143
# 99th percentile: 0.000465
#
# Final Evaluation...
#
# Final Test Results:
# Average test loss: 0.004422
#
# Test Set Component Analysis:
#
# Component 0:
# Predictions - min: 1.86e-04, max: 3.39e-04, mean: 3.11e-04, std: 4.04e-06
# Ground Truth - min: 1.62e-04, max: 5.48e-04, mean: 3.04e-04, std: 9.81e-05
# Relative Error: 3.16e-01
#
# Component 1:
# Predictions - min: -1.82e-06, max: -7.72e-07, mean: -1.51e-06, std: 1.15e-07
# Ground Truth - min: -4.25e-05, max: 4.70e-05, mean: -1.67e-06, std: 2.24e-05
# Relative Error: 1.06e+00
#
# Component 2:
# Predictions - min: 1.95e-04, max: 3.54e-04, mean: 3.27e-04, std: 3.66e-06
# Ground Truth - min: 1.67e-04, max: 4.85e-04, mean: 3.20e-04, std: 9.22e-05
# Relative Error: 2.89e-01
#
# Component 3:
# Predictions - min: 1.15e-05, max: 1.54e-05, mean: 1.50e-05, std: 1.09e-07
# Ground Truth - min: -1.88e-05, max: 4.25e-05, mean: 1.49e-05, std: 1.61e-05
# Relative Error: 7.93e+00
#
# Component 4:
# Predictions - min: -1.22e-05, max: -8.58e-06, mean: -1.14e-05, std: 1.32e-07
# Ground Truth - min: -6.59e-05, max: 2.80e-05, mean: -1.14e-05, std: 2.10e-05
# Relative Error: 1.67e+00
#
# Component 5:
# Predictions - min: 1.81e-04, max: 3.28e-04, mean: 3.01e-04, std: 3.69e-06
# Ground Truth - min: 1.43e-04, max: 4.65e-04, mean: 2.95e-04, std: 8.37e-05
# Relative Error: 2.79e-01
#
# Example predictions vs ground truth:
#
# Sample 1:
# Predicted: [ 3.1089847e-04 -1.5578271e-06  3.2734452e-04  1.5062087e-05
#  -1.1425735e-05  3.0116885e-04]
# Actual: [ 3.42187734e-04  1.31983290e-06  4.01540019e-04  1.36792605e-05
#  -6.59069919e-05  3.47799185e-04]
#
# Sample 2:
# Predicted: [ 3.18801205e-04 -1.73238425e-06  3.34641460e-04  1.52456505e-05
#  -1.17380641e-05  3.08403338e-04]
# Actual: [ 2.5550034e-04  6.5357231e-06  2.6182135e-04  2.3852454e-05
#  -2.1309179e-05  2.4634704e-04]
#
# Sample 3:
# Predicted: [ 3.1004453e-04 -1.4866869e-06  3.2683997e-04  1.4984213e-05
#  -1.1342634e-05  3.0069231e-04]
# Actual: [ 3.4041627e-04  3.0247827e-05  4.0526260e-04  2.0505873e-05
#  -2.3044380e-05  3.2322097e-04]
#
# Sample 4:
# Predicted: [ 3.1115854e-04 -1.6840471e-06  3.2701765e-04  1.5178450e-05
#  -1.1544602e-05  3.0086696e-04]
# Actual: [ 3.2003969e-04  2.5391944e-06  2.9587495e-04 -1.2636971e-05
#  -1.8239340e-05  2.5570000e-04]
#
# Sample 5:
# Predicted: [ 3.0994817e-04 -1.4722563e-06  3.2680723e-04  1.4968313e-05
#  -1.1326362e-05  3.0068771e-04]
# Actual: [4.4417652e-04 3.1836440e-05 4.1473150e-04 3.3327033e-05 8.7260141e-06
#  3.8360446e-04]

# %%
# print("Original Ground Truth Tensor Analysis:")
# print("\nComponent-wise statistics:")
# for i in range(6):
#     comp = ground_truth_tensors[:, i]
#     print(f"\nComponent {i}:")
#     print(f"Min: {np.min(comp):.2e}")
#     print(f"Max: {np.max(comp):.2e}")
#     print(f"Mean: {np.mean(comp):.2e}")
#     print(f"Std: {np.std(comp):.2e}")
