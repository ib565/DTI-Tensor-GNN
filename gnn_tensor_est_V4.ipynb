# %%
import numpy as np
import nibabel as nib
from dipy.io import read_bvals_bvecs
from dipy.core.gradients import gradient_table

# %%
subject_id = "100206"
subject_path = f"diffusion_data/{subject_id}/T1w/Diffusion"
dwi_img = nib.load(f'{subject_path}/data.nii.gz')
mask_img = nib.load(f'{subject_path}/nodif_brain_mask.nii.gz')

# %%
dwi_data = dwi_img.get_fdata()
original_mask = mask_img.get_fdata() > 0

# %%
# store original indices before any voxel filtering 
original_idx = np.where(original_mask)

# %%
# Map (x,y,z) to original linear index
coord_to_gtt = {}
for i in range(len(original_idx[0])):
    x, y, z = original_idx[0][i], original_idx[1][i], original_idx[2][i]
    coord_to_gtt[(x,y,z)] = i  # i is the index in ground_truth_tensors

# %%
print(f"DWI data shape: {dwi_data.shape}")  # (X, Y, Z, num_volumes)
# Out:
# DWI data shape: (145, 174, 145, 288)

# %%
bvals, bvecs = read_bvals_bvecs(f'{subject_path}/bvals', 
                               f'{subject_path}/bvecs')
gtab = gradient_table(bvals, bvecs)

# %%
# get b0 data and b0_avg
b0_mask = gtab.b0s_mask
b0_data = dwi_data[..., b0_mask]
print(f"B0 data shape: {b0_data.shape}")
b0_avg = np.mean(b0_data, axis=-1)

# b1000 images mask
b1000_mask = (bvals >= 990) & (bvals <= 1010)
print(f"Number of b=1000 volumes: {np.sum(b1000_mask)}")
# Out:
# B0 data shape: (145, 174, 145, 18)
# Number of b=1000 volumes: 90

# %%
# Get all b1000 scans
dwi_vols = dwi_data[..., b1000_mask]
print(f"DWI volumes shape: {dwi_vols.shape}")
# Out:
# DWI volumes shape: (145, 174, 145, 90)

# %%
# mask out voxels with very low b0 signal
b0_threshold = 250
valid_b0_mask = b0_avg > b0_threshold
mask = original_mask & valid_b0_mask  # Combine with brain mask

# %%
# Find valid voxels using the brain mask
valid_idx = np.where(mask) # shape: 3 x num_valid_voxels
print(f"\nNumber of valid voxels in mask: {len(valid_idx[0])}")
# Out:
# Number of valid voxels in mask: 926671

# %%
# Sample random voxels for training
n_samples = 100000
sample_idx = np.random.choice(len(valid_idx[0]), 
                            min(n_samples, len(valid_idx[0])), 
                            replace=False)

# %%
# Extract features (signal intensities) from sampled voxels
features = []
gtt_indices = [] # store ground truth tensor indices 

for idx in sample_idx:
    x, y, z = valid_idx[0][idx], valid_idx[1][idx], valid_idx[2][idx]
    signal = dwi_vols[x, y, z, :]
    b0_ref = b0_avg[x, y, z]
    normalized_signal = signal / (b0_ref)
    features.append(normalized_signal)
    gtt_indices.append(coord_to_gtt[(x, y, z)])

# %%
gtt_indices[:10]
# Out:
# [562793, 201823, 866778, 795546, 16446, 493057, 574195, 883643, 589013, 213797]

# %%
features = np.array(features)
gtt_indices = np.array(gtt_indices)
gradient_directions = bvecs[b1000_mask]  # Only keep directions for DWI volumes

# %%
# print("\nFinal data shapes:")
# print(f"Features shape: {features.shape}")           # Should be (n_samples, n_directions)
# print(f"Gradient directions shape: {gradient_directions.shape}")  # Should be (n_directions, 3)

# # Basic sanity checks
# print("\nSanity checks:")
# print(f"Max normalized value: {np.max(features)}")
# print(f"Min normalized value: {np.min(features)}")
# print(f"Gradient directions magnitude close to 1: {np.allclose(np.linalg.norm(gradient_directions, axis=1), 1, atol=1e-3)}")

# %%
print("Loading ground truth data...")
gt_data = np.load('ground_truth_v2.npz')
ground_truth_tensors = gt_data['tensors']
# ground_truth_tensors = torch.tensor(ground_truth_tensors, dtype=torch.float32)
# valid_coordinates = gt_data['coordinates']
# print(f"Ground truth tensors shape: {ground_truth_tensors.shape}")
# print(f"Valid coordinates shape: {valid_coordinates.shape}")
# Out:
# Loading ground truth data...

# %%
# Number of directions to use for sparse estimation
n_directions = 21  # We can adjust this number

def create_graph_data(batch_idx, direction_indices, batch_size = 32, threshold_angle = 60):
    """
    Create graph data for a batch of samples, including ground tensor
    """
    
    batch_nodes = []
    batch_edges = []
    batch_tensors = []
    batch_edge_weights = []  

    current_directions = gradient_directions[direction_indices]
    for idx in batch_idx:
        signals = features[idx, direction_indices]
        # Create edges acc. to angle
        directions_norm = current_directions / np.linalg.norm(current_directions, axis=1, keepdims=True)
        cos_sim = np.dot(directions_norm, directions_norm.T)
        angles = np.arccos(np.clip(cos_sim, -1.0, 1.0)) * 180/np.pi
        
        src, dst = np.where(angles < threshold_angle)
        mask = src != dst
        edges = np.column_stack([src[mask], dst[mask]])

        weights = cos_sim[src[mask], dst[mask]]

        nodes = np.zeros((len(signals), 4))  # Shape: [n_directions, 4]

        for i in range(len(signals)):
            nodes[i, 0] = signals[i]
            nodes[i, 1:4] = current_directions[i]
            # print(f"voxel {idx}, dir {i} = {nodes[i, 1:4]} ")

        batch_nodes.append(nodes)
        batch_edges.append(edges)
        batch_edge_weights.append(weights)
        batch_tensors.append(ground_truth_tensors[gtt_indices[idx]])
    return batch_nodes, batch_edges, batch_edge_weights, batch_tensors

# nodes, edges, gt_tensors = create_graph_data(features, gradient_directions, n_directions)
# # Print info for verification
# print("\nBatch statistics:")
# print(f"Number of samples in batch: {len(nodes)}")
# print(f"Number of nodes per graph: {nodes[0].shape[0]}")
# print(f"Node feature dimensionality: {nodes[0].shape[1]}")
# print(f"Ground truth tensors: {len(gt_tensors)}")

# # Print example for first sample
# print("\nFirst sample in batch:")
# print(f"Number of nodes: {nodes[0].shape[0]}")
# print(f"Number of edges: {edges[0].shape[0]}")
# print(f"Ground truth tensor components: {gt_tensors[0]}")

# %%
def select_diverse_directions(all_directions, n_select=21):
    selected = [0]  # Start with first direction
    while len(selected) < n_select:
        # Calculate angles with all selected directions
        angles = []
        for i in range(len(all_directions)):
            if i in selected:
                continue
            min_angle = float('inf')
            for s in selected:
                # Cosine similarity
                angle = np.arccos(np.clip(
                    np.dot(all_directions[i], all_directions[s]), -1.0, 1.0))
                min_angle = min(min_angle, angle)
            angles.append((i, min_angle))
        # Select direction with largest minimum angle
        next_idx = max(angles, key=lambda x: x[1])[0]
        selected.append(next_idx)
    return selected

# %%
def initialize_direction_sets(all_directions, n_sets=3, n_directions=21):
    base_sets = []
    n_total = len(all_directions)
    
    for i in range(n_sets):
        # Create a shuffled index array for this set
        shuffled_indices = np.random.permutation(n_total)
        # Use select_diverse_directions on the shuffled indices
        selected = select_diverse_directions(all_directions[shuffled_indices], n_directions)
        # Map back to original indices
        original_indices = shuffled_indices[selected]
        base_sets.append(original_indices)
    
    return base_sets

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import MessagePassing
from torch_geometric.nn import global_mean_pool
import torch.optim as optim
from torch_geometric.data import Data, Batch
from sklearn.model_selection import train_test_split

# %%
class DiffusionGNN(torch.nn.Module):
    def __init__(self, node_features = 4, hidden_dim = 128):
        super(DiffusionGNN, self).__init__()
    
        # Layers
        self.conv1 = DiffusionConv(node_features, hidden_dim)
        self.conv2 = DiffusionConv(hidden_dim, hidden_dim)

        # MLP for tensor prediction
        self.mlp = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 6),
        )

        # self.scale_net = nn.Sequential(
        #     nn.Linear(hidden_dim, 1),
        #     nn.Sigmoid()
        # )

        self.scale_net = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 6),
            nn.Softplus()
        )

        self.register_buffer('loss_weights',
            torch.tensor([10, 100, 10, 100, 100, 10]))

    
    def forward(self, x, edge_index, edge_attr, batch):
        """
        x: node_features
        edge_index = graph conn info [2, num_edges]
        batch: batch assignment for nodes
        """
        # print("pre conv", x.shape)
        # pass through gnn layers
        # print(x.shape)
        # print(x[0:5])
        x = self.conv1(x, edge_index, edge_attr)
        x = F.relu(x)
        x = self.conv2(x, edge_index, edge_attr)
        x = F.relu(x)

        # print("after conv", x.shape)

        # combine node features for graph
        x = global_mean_pool(x, batch)  # [batch_size, hidden_dim]
        
        # print("after pool", x.shape)

        # raw predictions
        out = self.mlp(x)

        # scales = self.scale_net(x)
        # out = out * scales
        
        diag_idx = [0, 2, 5]
        offdiag_idx = [1, 3, 4]

        # Diagonal elements: [0,1] using sigmoid
        diag = torch.sigmoid(out[:, diag_idx])
        
        # Off-diagonal elements: [-1,1] using tanh
        offdiag = torch.tanh(out[:, offdiag_idx])

        out_reordered = torch.zeros_like(out)
        out_reordered[:, diag_idx] = diag
        out_reordered[:, offdiag_idx] = offdiag
        
        return out_reordered
    
    def weighted_mse_loss(self, pred, target):
        squared_diff = (pred - target) ** 2  # [batch_size, 6]
        weighted_diff = squared_diff * self.loss_weights
        return torch.mean(weighted_diff)


class DiffusionConv(MessagePassing):
    def __init__(self, in_channels, out_channels):
        super(DiffusionConv, self).__init__(aggr="mean")
        
        # MLP to process messages
        self.mlp = nn.Sequential(
            nn.Linear(2 * in_channels, out_channels),
            nn.ReLU(),
            nn.Linear(out_channels, out_channels)
        )
    
    def forward(self, x, edge_index, edge_weight):
        return self.propagate(edge_index, x=x, edge_weight = edge_weight)
    
    def message(self, x_i, x_j, edge_weight):
        """
        x_i: features of target nodes
        x_j: features of source nodes
        Returns: messages to be aggregated
        """
        tmp = torch.cat([x_i, x_j], dim = 1)
        return self.mlp(tmp) * edge_weight.view(-1,1)

# %%
def convert_to_torch_geometric(nodes, edges, edge_weights, tensors):
    data_list = []
    for i in range(len(nodes)):
        # Ensure tensor is properly shaped [6] not flattened
        tensor = tensors[i].reshape(-1, 6) if len(tensors[i].shape) == 1 else tensors[i]
        
        data = Data(
            x=torch.FloatTensor(nodes[i]),          # [n_nodes]
            edge_index=torch.LongTensor(edges[i].T), # [2, n_edges]
            edge_attr=torch.FloatTensor(edge_weights[i]),
            y=torch.FloatTensor(tensor)             # [1, 6]
        )
        data_list.append(data)
    return data_list

# %%
train_idx, test_idx = train_test_split(np.arange(len(features)), test_size=0.2, random_state=42)
print(f"Training with {len(train_idx)} voxels, testing with {len(test_idx)} voxels")
# Out:
# Training with 80000 voxels, testing with 20000 voxels

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
n_sets = 3
direction_sets = initialize_direction_sets(gradient_directions, n_sets)

# %%
# Training
model = DiffusionGNN(hidden_dim=64).to(device)
optimizer = optim.Adam(model.parameters(), lr=0.0005)
batch_size = 32
epochs = 20

all_pred_values = [[] for _ in range(6)]
all_gt_values = [[] for _ in range(6)]

print("Starting training...")
for epoch in range(epochs):
    direction_indices = direction_sets[epoch % n_sets]
    model.train()
    epoch_loss = 0
    n_batches = 0

    # Shuffle training indices
    np.random.shuffle(train_idx)
    
    # Process batches
    for start in range(0, len(train_idx), batch_size):
        batch_idx = train_idx[start:start + batch_size]
        # Create graphs for batch
        nodes, edges, edge_weights, tensors = create_graph_data(
            batch_idx, direction_indices
        )
        # print("Before PyG:", nodes[0][:5])
        # Convert to PyG and process
        data_list = convert_to_torch_geometric(nodes, edges, edge_weights, tensors)
        # print("After PyG:", data_list[0].x[:5])
        batch_data = Batch.from_data_list(data_list).to(device)
        # print("After batch:", batch_data.x[:5])
        # Training step
        optimizer.zero_grad()
        # print("in train loop", batch_data.x.shape)
        pred = model(batch_data.x, batch_data.edge_index, batch_data.edge_attr, batch_data.batch)
        y_true = batch_data.y

        # loss = F.mse_loss(pred, y_true) * 1e6
        loss = model.weighted_mse_loss(pred, y_true) * 1e6

        loss.backward()
        optimizer.step()
        
        epoch_loss += loss.item()
        n_batches += 1
    
    for i in range(6):
        all_pred_values[i].extend(pred[:, i].detach().cpu().numpy())
        all_gt_values[i].extend(batch_data.y[:, i].cpu().numpy())

    if epoch % 1 == 0:  # Print every epoch
        # Move entire tensors to CPU once
        pred_cpu = pred.detach().cpu().numpy()
        gt_cpu = batch_data.y.cpu().numpy()
        
        print(f"\nEpoch {epoch+1} Statistics:")
        # Component-wise prediction stats
        print("\nPredictions per component:")
        for i in range(6):
            print(f"Component {i}: min={np.min(pred_cpu[:,i]):.2e}, "
                f"max={np.max(pred_cpu[:,i]):.2e}, "
                f"mean={np.mean(pred_cpu[:,i]):.2e}, "
                f"std={np.std(pred_cpu[:,i]):.2e}")
        
        # Component-wise ground truth stats
        print("\nGround Truth per component:")
        for i in range(6):
            print(f"Component {i}: min={np.min(gt_cpu[:,i]):.2e}, "
                f"max={np.max(gt_cpu[:,i]):.2e}, "
                f"mean={np.mean(gt_cpu[:,i]):.2e}, "
                f"std={np.std(gt_cpu[:,i]):.2e}")
        
        # Relative error per component
        print("\nRelative Error per component:")
        for i in range(6):
            rel_error = np.mean(np.abs(pred_cpu[:,i] - gt_cpu[:,i]) / 
                            (np.abs(gt_cpu[:,i]) + 1e-10))
            print(f"Component {i}: {rel_error:.2e}")
    
    avg_loss = epoch_loss / n_batches
    print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.6f}")
    

print("\nTraining Values Statistics:")
for i in range(6):
    pred_vals = np.array(all_pred_values[i])
    gt_vals = np.array(all_gt_values[i])
    print(f"\nComponent {i}:")
    print("Predictions:")
    print(f"Min: {np.min(pred_vals):.6f}")
    print(f"Max: {np.max(pred_vals):.6f}")
    print(f"Mean: {np.mean(pred_vals):.6f}")
    print(f"1st percentile: {np.percentile(pred_vals, 1):.6f}")
    print(f"99th percentile: {np.percentile(pred_vals, 99):.6f}")
    print("Ground Truth:")
    print(f"Min: {np.min(gt_vals):.6f}")
    print(f"Max: {np.max(gt_vals):.6f}")
    print(f"Mean: {np.mean(gt_vals):.6f}")
    print(f"1st percentile: {np.percentile(gt_vals, 1):.6f}")
    print(f"99th percentile: {np.percentile(gt_vals, 99):.6f}")

# Final evaluation on full test set
print("\nFinal Evaluation...")
model.eval()
test_losses = []
all_test_preds = []
all_test_gts = []

with torch.no_grad():
    for start in range(0, len(test_idx), batch_size):
        batch_idx = test_idx[start:start + batch_size]
        if len(batch_idx) < batch_size:
            continue
            
        nodes, edges, edge_weights, tensors = create_graph_data(
            batch_idx, direction_indices
        )
        data_list = convert_to_torch_geometric(nodes, edges, edge_weights, tensors)
        batch_data = Batch.from_data_list(data_list).to(device)
        
        pred = model(batch_data.x, batch_data.edge_index, batch_data.edge_attr, batch_data.batch)

        
        # test_loss = F.mse_loss(pred, batch_data.y) * 1e6
        test_loss = model.weighted_mse_loss(pred, batch_data.y) * 1e6
        test_losses.append(test_loss.item())
        
        
        pred = pred.cpu()
        batch_data = batch_data.cpu()

        # Store predictions and ground truths
        all_test_preds.append(pred.detach().numpy())
        all_test_gts.append(batch_data.y.numpy())

# Combine all batches
all_test_preds = np.concatenate(all_test_preds, axis=0)
all_test_gts = np.concatenate(all_test_gts, axis=0)

# Print overall test loss
avg_test_loss = np.mean(test_losses)
print(f"\nFinal Test Results:")
print(f"Average test loss: {avg_test_loss:.6f}")

# Component-wise analysis
print("\nTest Set Component Analysis:")
for i in range(6):
    pred_comp = all_test_preds[:, i]
    gt_comp = all_test_gts[:, i]
    
    # Stats
    print(f"\nComponent {i}:")
    print(f"Predictions - min: {np.min(pred_comp):.2e}, max: {np.max(pred_comp):.2e}, "
          f"mean: {np.mean(pred_comp):.2e}, std: {np.std(pred_comp):.2e}")
    print(f"Ground Truth - min: {np.min(gt_comp):.2e}, max: {np.max(gt_comp):.2e}, "
          f"mean: {np.mean(gt_comp):.2e}, std: {np.std(gt_comp):.2e}")
    
    # Relative Error
    rel_error = np.mean(np.abs(pred_comp - gt_comp) / (np.abs(gt_comp) + 1e-10))
    print(f"Relative Error: {rel_error:.2e}")


# Print some example predictions vs ground truth
print("\nExample predictions vs ground truth:")
for i in range(5):
    print(f"\nSample {i+1}:")
    print(f"Predicted: {pred[i].numpy()}")
    print(f"Actual: {batch_data.y[i].numpy()}")
# Out:
# Starting training...
#
# Epoch 1 Statistics:
#
# Predictions per component:
# Component 0: min=1.35e-03, max=1.60e-03, mean=1.50e-03, std=6.24e-05
# Component 1: min=3.92e-03, max=4.18e-03, mean=4.00e-03, std=6.05e-05
# Component 2: min=2.93e-03, max=3.43e-03, mean=3.22e-03, std=1.22e-04
# Component 3: min=-2.00e-03, max=-1.61e-03, mean=-1.67e-03, std=7.95e-05
# Component 4: min=2.52e-03, max=3.17e-03, mean=3.03e-03, std=1.30e-04
# Component 5: min=1.18e-03, max=1.40e-03, mean=1.31e-03, std=5.55e-05
#
# Ground Truth per component:
# Component 0: min=4.91e-04, max=3.18e-03, mean=1.01e-03, std=5.10e-04
# Component 1: min=-2.30e-04, max=7.96e-05, mean=-3.11e-05, std=6.57e-05
# Component 2: min=3.25e-04, max=3.33e-03, mean=1.03e-03, std=5.64e-04
# Component 3: min=-2.05e-04, max=1.68e-04, mean=-1.25e-05, std=6.84e-05
# Component 4: min=-5.59e-05, max=2.46e-04, mean=1.42e-05, std=6.93e-05
# Component 5: min=5.89e-04, max=3.20e-03, mean=1.03e-03, std=5.42e-04
#
# Relative Error per component:
# Component 0: 7.38e-01
# Component 1: 1.49e+02
# Component 2: 2.73e+00
# Component 3: 2.81e+02
# Component 4: 2.46e+02
# Component 5: 5.59e-01
# Epoch 1/20, Loss: 28015.280903
#
# Epoch 2 Statistics:
#
# Predictions per component:
# Component 0: min=9.95e-04, max=1.25e-03, mean=1.15e-03, std=6.79e-05
# Component 1: min=5.11e-04, max=8.08e-04, mean=5.87e-04, std=6.75e-05
# Component 2: min=1.67e-03, max=2.07e-03, mean=1.91e-03, std=1.08e-04
# Component 3: min=-1.06e-03, max=-7.31e-04, mean=-8.04e-04, std=6.92e-05
# Component 4: min=-1.10e-04, max=5.33e-04, mean=3.61e-04, std=1.54e-04
# Component 5: min=1.30e-03, max=1.62e-03, mean=1.50e-03, std=8.55e-05
#
# Ground Truth per component:
# Component 0: min=3.00e-04, max=3.18e-03, mean=1.06e-03, std=5.39e-04
# Component 1: min=-5.45e-04, max=1.66e-04, mean=-6.01e-05, std=1.58e-04
# Component 2: min=2.42e-04, max=3.25e-03, mean=9.93e-04, std=5.61e-04
# Component 3: min=-2.31e-04, max=5.34e-04, mean=3.20e-05, std=1.47e-04
# Component 4: min=-4.01e-04, max=2.58e-04, mean=-2.70e-05, std=1.37e-04
# Component 5: min=2.11e-04, max=3.23e-03, mean=9.91e-04, std=5.77e-04
#
# Relative Error per component:
# Component 0: 4.36e-01
# Component 1: 1.97e+01
# Component 2: 1.45e+00
# Component 3: 4.47e+01
# Component 4: 1.17e+01
# Component 5: 1.03e+00
# Epoch 2/20, Loss: 126.118910
#
# Epoch 3 Statistics:
#
# Predictions per component:
# Component 0: min=1.09e-03, max=1.51e-03, mean=1.28e-03, std=1.13e-04
# Component 1: min=-3.59e-06, max=9.02e-05, mean=4.72e-05, std=1.96e-05
# Component 2: min=1.49e-03, max=2.06e-03, mean=1.76e-03, std=1.52e-04
# Component 3: min=-3.80e-04, max=-2.34e-04, mean=-3.09e-04, std=2.95e-05
# Component 4: min=1.06e-04, max=3.67e-04, mean=2.40e-04, std=4.95e-05
# Component 5: min=1.22e-03, max=1.68e-03, mean=1.44e-03, std=1.25e-04
#
# Ground Truth per component:
# Component 0: min=3.73e-04, max=3.12e-03, mean=1.06e-03, std=6.91e-04
# Component 1: min=-2.08e-04, max=2.83e-04, mean=4.14e-06, std=1.04e-04
# Component 2: min=5.85e-04, max=3.19e-03, mean=1.11e-03, std=7.00e-04
# Component 3: min=-1.94e-04, max=2.43e-04, mean=2.22e-05, std=1.04e-04
# Component 4: min=-2.56e-04, max=2.61e-04, mean=-2.66e-05, std=1.02e-04
# Component 5: min=4.36e-04, max=3.37e-03, mean=1.11e-03, std=7.21e-04
#
# Relative Error per component:
# Component 0: 6.74e-01
# Component 1: 2.79e+00
# Component 2: 1.00e+00
# Component 3: 1.11e+01
# Component 4: 1.32e+01
# Component 5: 7.08e-01
# Epoch 3/20, Loss: 51.626467
#
# Epoch 4 Statistics:
#
# Predictions per component:
# Component 0: min=8.20e-04, max=1.74e-03, mean=1.31e-03, std=1.71e-04
# Component 1: min=5.41e-04, max=6.21e-04, mean=5.89e-04, std=2.09e-05
# Component 2: min=1.02e-03, max=2.15e-03, mean=1.62e-03, std=2.12e-04
# Component 3: min=-5.65e-04, max=-5.03e-04, mean=-5.25e-04, std=1.52e-05
# Component 4: min=7.95e-04, max=9.77e-04, mean=8.84e-04, std=4.45e-05
# Component 5: min=8.74e-04, max=1.85e-03, mean=1.39e-03, std=1.82e-04
#
# Ground Truth per component:
# Component 0: min=6.98e-05, max=2.96e-03, mean=8.97e-04, std=4.94e-04
# Component 1: min=-2.40e-04, max=1.95e-04, mean=1.02e-05, std=8.74e-05
# Component 2: min=2.56e-04, max=2.96e-03, mean=9.08e-04, std=5.34e-04
# Component 3: min=-4.02e-04, max=4.62e-04, mean=-1.29e-05, std=1.31e-04
# Component 4: min=-4.16e-04, max=1.15e-04, mean=-3.08e-05, std=1.09e-04
# Component 5: min=1.21e-04, max=2.84e-03, mean=9.55e-04, std=5.19e-04
#
# Relative Error per component:
# Component 0: 9.88e-01
# Component 1: 2.82e+01
# Component 2: 1.23e+00
# Component 3: 6.95e+01
# Component 4: 1.39e+02
# Component 5: 9.19e-01
# Epoch 4/20, Loss: 41.715489
#
# Epoch 5 Statistics:
#
# Predictions per component:
# Component 0: min=8.84e-04, max=1.75e-03, mean=1.14e-03, std=1.98e-04
# Component 1: min=-3.61e-04, max=-2.49e-04, mean=-3.02e-04, std=2.75e-05
# Component 2: min=1.03e-03, max=2.05e-03, mean=1.33e-03, std=2.34e-04
# Component 3: min=-2.29e-04, max=-1.40e-04, mean=-1.83e-04, std=2.44e-05
# Component 4: min=-5.40e-04, max=-2.92e-04, mean=-3.97e-04, std=6.56e-05
# Component 5: min=9.09e-04, max=1.80e-03, mean=1.17e-03, std=2.05e-04
#
# Ground Truth per component:
# Component 0: min=5.13e-04, max=2.00e-03, mean=8.94e-04, std=3.32e-04
# Component 1: min=-6.19e-04, max=1.80e-04, mean=-3.14e-05, std=1.41e-04
# Component 2: min=3.74e-04, max=2.06e-03, mean=8.54e-04, std=3.48e-04
# Component 3: min=-3.66e-04, max=3.92e-04, mean=3.35e-06, std=1.17e-04
# Component 4: min=-3.66e-04, max=4.08e-04, mean=-2.62e-05, std=1.39e-04
# Component 5: min=2.81e-04, max=1.99e-03, mean=8.67e-04, std=3.63e-04
#
# Relative Error per component:
# Component 0: 4.00e-01
# Component 1: 1.38e+01
# Component 2: 6.94e-01
# Component 3: 1.65e+01
# Component 4: 1.04e+01
# Component 5: 4.98e-01
# Epoch 5/20, Loss: 21.584506
#
# Epoch 6 Statistics:
#
# Predictions per component:
# Component 0: min=6.13e-04, max=2.27e-03, mean=1.04e-03, std=3.79e-04
# Component 1: min=-1.55e-04, max=3.11e-05, mean=-1.11e-04, std=3.35e-05
# Component 2: min=6.79e-04, max=2.56e-03, mean=1.16e-03, std=4.30e-04
# Component 3: min=-2.18e-04, max=-4.78e-05, mean=-9.34e-05, std=3.36e-05
# Component 4: min=-8.10e-04, max=-3.79e-04, mean=-4.63e-04, std=8.69e-05
# Component 5: min=6.18e-04, max=2.32e-03, mean=1.06e-03, std=3.88e-04
#
# Ground Truth per component:
# Component 0: min=4.41e-04, max=3.31e-03, mean=9.85e-04, std=5.67e-04
# Component 1: min=-1.11e-04, max=5.45e-04, mean=5.10e-05, std=1.14e-04
# Component 2: min=3.81e-04, max=3.21e-03, mean=9.46e-04, std=5.44e-04
# Component 3: min=-3.89e-04, max=1.53e-04, mean=-2.76e-05, std=1.17e-04
# Component 4: min=-4.36e-04, max=1.54e-04, mean=-1.50e-05, std=1.04e-04
# Component 5: min=4.08e-04, max=3.47e-03, mean=9.75e-04, std=5.90e-04
#
# Relative Error per component:
# Component 0: 2.36e-01
# Component 1: 5.31e+00
# Component 2: 3.43e-01
# Component 3: 1.40e+01
# Component 4: 1.89e+01
# Component 5: 2.26e-01
# Epoch 6/20, Loss: 11.521408
#
# Epoch 7 Statistics:
#
# Predictions per component:
# Component 0: min=6.61e-04, max=2.45e-03, mean=1.14e-03, std=4.70e-04
# Component 1: min=7.19e-06, max=1.42e-04, mean=7.05e-05, std=2.79e-05
# Component 2: min=7.05e-04, max=2.68e-03, mean=1.23e-03, std=5.17e-04
# Component 3: min=1.62e-04, max=2.42e-04, mean=2.02e-04, std=1.93e-05
# Component 4: min=-5.58e-04, max=-3.25e-04, mean=-4.28e-04, std=5.77e-05
# Component 5: min=6.64e-04, max=2.50e-03, mean=1.15e-03, std=4.82e-04
#
# Ground Truth per component:
# Component 0: min=5.62e-04, max=2.77e-03, mean=1.04e-03, std=5.43e-04
# Component 1: min=-4.32e-04, max=3.95e-04, mean=8.26e-06, std=1.48e-04
# Component 2: min=5.08e-04, max=3.07e-03, mean=1.07e-03, std=5.82e-04
# Component 3: min=-2.32e-04, max=2.18e-04, mean=9.96e-06, std=8.66e-05
# Component 4: min=-2.13e-04, max=2.67e-04, mean=-5.20e-06, std=9.01e-05
# Component 5: min=4.98e-04, max=3.20e-03, mean=1.01e-03, std=5.87e-04
#
# Relative Error per component:
# Component 0: 1.83e-01
# Component 1: 2.22e+00
# Component 2: 2.10e-01
# Component 3: 3.41e+01
# Component 4: 1.29e+01
# Component 5: 2.24e-01
# Epoch 7/20, Loss: 8.987641
#
# Epoch 8 Statistics:
#
# Predictions per component:
# Component 0: min=5.50e-04, max=2.30e-03, mean=9.78e-04, std=4.17e-04
# Component 1: min=-2.02e-04, max=-9.66e-05, mean=-1.43e-04, std=2.32e-05
# Component 2: min=5.69e-04, max=2.44e-03, mean=1.02e-03, std=4.46e-04
# Component 3: min=9.85e-05, max=1.60e-04, mean=1.27e-04, std=1.43e-05
# Component 4: min=-4.98e-04, max=-3.03e-04, mean=-4.07e-04, std=4.48e-05
# Component 5: min=5.47e-04, max=2.33e-03, mean=9.81e-04, std=4.25e-04
#
# Ground Truth per component:
# Component 0: min=4.77e-04, max=2.63e-03, mean=9.76e-04, std=4.69e-04
# Component 1: min=-2.89e-04, max=3.13e-04, mean=8.88e-06, std=1.14e-04
# Component 2: min=5.05e-04, max=2.75e-03, mean=1.03e-03, std=5.23e-04
# Component 3: min=-2.78e-04, max=3.30e-04, mean=1.29e-05, std=9.94e-05
# Component 4: min=-2.80e-04, max=2.27e-04, mean=-1.26e-06, std=8.97e-05
# Component 5: min=4.06e-04, max=3.00e-03, mean=9.43e-04, std=5.71e-04
#
# Relative Error per component:
# Component 0: 9.91e-02
# Component 1: 6.63e+00
# Component 2: 1.53e-01
# Component 3: 1.24e+01
# Component 4: 1.90e+01
# Component 5: 1.87e-01
# Epoch 8/20, Loss: 5.425443
#
# Epoch 9 Statistics:
#
# Predictions per component:
# Component 0: min=3.31e-04, max=2.47e-03, mean=1.12e-03, std=5.53e-04
# Component 1: min=1.36e-05, max=2.74e-04, mean=1.23e-04, std=4.74e-05
# Component 2: min=3.43e-04, max=2.62e-03, mean=1.17e-03, std=5.88e-04
# Component 3: min=-3.79e-04, max=-2.12e-04, mean=-2.66e-04, std=3.60e-05
# Component 4: min=-3.43e-04, max=1.63e-04, mean=-8.55e-05, std=9.35e-05
# Component 5: min=3.31e-04, max=2.53e-03, mean=1.14e-03, std=5.68e-04
#
# Ground Truth per component:
# Component 0: min=2.55e-04, max=2.66e-03, mean=1.05e-03, std=5.96e-04
# Component 1: min=-2.67e-04, max=2.50e-04, mean=-1.23e-05, std=1.12e-04
# Component 2: min=2.40e-04, max=2.95e-03, mean=1.13e-03, std=5.96e-04
# Component 3: min=-2.45e-04, max=1.25e-04, mean=-6.36e-06, std=7.50e-05
# Component 4: min=-2.83e-04, max=3.20e-04, mean=7.63e-06, std=1.15e-04
# Component 5: min=2.46e-04, max=2.83e-03, mean=1.09e-03, std=6.09e-04
#
# Relative Error per component:
# Component 0: 1.87e-01
# Component 1: 3.41e+00
# Component 2: 1.72e-01
# Component 3: 1.70e+01
# Component 4: 1.99e+01
# Component 5: 1.18e-01
# Epoch 9/20, Loss: 3.379821
#
# Epoch 10 Statistics:
#
# Predictions per component:
# Component 0: min=3.43e-04, max=2.56e-03, mean=9.90e-04, std=5.35e-04
# Component 1: min=3.02e-05, max=2.69e-04, mean=1.53e-04, std=5.46e-05
# Component 2: min=3.52e-04, max=2.65e-03, mean=1.02e-03, std=5.56e-04
# Component 3: min=4.17e-05, max=1.83e-04, mean=1.12e-04, std=3.51e-05
# Component 4: min=-4.29e-05, max=2.58e-04, mean=1.29e-04, std=6.15e-05
# Component 5: min=3.41e-04, max=2.62e-03, mean=1.00e-03, std=5.51e-04
#
# Ground Truth per component:
# Component 0: min=1.83e-04, max=3.29e-03, mean=9.76e-04, std=6.85e-04
# Component 1: min=-1.47e-04, max=2.64e-04, mean=-1.32e-06, std=8.46e-05
# Component 2: min=2.87e-04, max=3.50e-03, mean=1.01e-03, std=6.93e-04
# Component 3: min=-2.49e-04, max=3.56e-04, mean=1.96e-05, std=1.15e-04
# Component 4: min=-2.19e-04, max=1.56e-04, mean=-3.90e-05, std=8.21e-05
# Component 5: min=1.49e-04, max=3.35e-03, mean=1.11e-03, std=6.53e-04
#
# Relative Error per component:
# Component 0: 1.78e-01
# Component 1: 6.59e+00
# Component 2: 1.71e-01
# Component 3: 6.04e+00
# Component 4: 2.70e+01
# Component 5: 1.85e-01
# Epoch 10/20, Loss: 2.468973
#
# Epoch 11 Statistics:
#
# Predictions per component:
# Component 0: min=4.04e-04, max=2.55e-03, mean=1.02e-03, std=5.19e-04
# Component 1: min=-2.17e-06, max=4.22e-04, mean=1.87e-04, std=1.02e-04
# Component 2: min=4.22e-04, max=2.63e-03, mean=1.05e-03, std=5.34e-04
# Component 3: min=-3.99e-04, max=-1.00e-04, mean=-2.24e-04, std=5.87e-05
# Component 4: min=-2.80e-04, max=3.15e-04, mean=7.70e-05, std=1.25e-04
# Component 5: min=3.97e-04, max=2.60e-03, mean=1.02e-03, std=5.31e-04
#
# Ground Truth per component:
# Component 0: min=3.54e-04, max=2.86e-03, mean=1.04e-03, std=5.45e-04
# Component 1: min=-2.33e-04, max=3.79e-04, mean=4.47e-05, std=1.38e-04
# Component 2: min=3.85e-04, max=2.85e-03, mean=1.05e-03, std=5.38e-04
# Component 3: min=-2.51e-04, max=2.16e-04, mean=9.21e-06, std=1.07e-04
# Component 4: min=-5.27e-04, max=2.79e-04, mean=-2.21e-05, std=1.60e-04
# Component 5: min=4.28e-04, max=2.87e-03, mean=9.85e-04, std=5.36e-04
#
# Relative Error per component:
# Component 0: 1.50e-01
# Component 1: 1.07e+01
# Component 2: 1.47e-01
# Component 3: 2.23e+01
# Component 4: 3.16e+00
# Component 5: 1.25e-01
# Epoch 11/20, Loss: 1.619035
#
# Epoch 12 Statistics:
#
# Predictions per component:
# Component 0: min=5.61e-04, max=2.72e-03, mean=1.26e-03, std=7.21e-04
# Component 1: min=-1.74e-04, max=1.38e-04, mean=-3.00e-05, std=6.33e-05
# Component 2: min=5.88e-04, max=2.79e-03, mean=1.30e-03, std=7.35e-04
# Component 3: min=-2.05e-05, max=1.93e-04, mean=7.00e-05, std=4.80e-05
# Component 4: min=-8.17e-05, max=2.49e-04, mean=1.09e-04, std=6.96e-05
# Component 5: min=5.63e-04, max=2.81e-03, mean=1.29e-03, std=7.52e-04
#
# Ground Truth per component:
# Component 0: min=4.82e-04, max=3.01e-03, mean=1.27e-03, std=7.38e-04
# Component 1: min=-1.93e-04, max=2.20e-04, mean=1.09e-05, std=9.12e-05
# Component 2: min=4.61e-04, max=3.21e-03, mean=1.29e-03, std=7.81e-04
# Component 3: min=-1.98e-04, max=1.30e-04, mean=-1.19e-05, std=6.36e-05
# Component 4: min=-2.84e-04, max=1.08e-04, mean=-3.99e-05, std=8.46e-05
# Component 5: min=4.43e-04, max=3.25e-03, mean=1.27e-03, std=7.89e-04
#
# Relative Error per component:
# Component 0: 7.36e-02
# Component 1: 1.67e+00
# Component 2: 6.62e-02
# Component 3: 4.08e+00
# Component 4: 3.26e+00
# Component 5: 8.48e-02
# Epoch 12/20, Loss: 1.164997
#
# Epoch 13 Statistics:
#
# Predictions per component:
# Component 0: min=4.56e-04, max=2.58e-03, mean=1.00e-03, std=5.34e-04
# Component 1: min=-2.86e-04, max=7.74e-05, mean=-8.61e-05, std=7.58e-05
# Component 2: min=4.81e-04, max=2.64e-03, mean=1.04e-03, std=5.43e-04
# Component 3: min=-2.01e-04, max=9.92e-05, mean=-1.71e-05, std=6.65e-05
# Component 4: min=-2.89e-04, max=2.63e-04, mean=-5.32e-05, std=1.06e-04
# Component 5: min=4.55e-04, max=2.66e-03, mean=1.02e-03, std=5.55e-04
#
# Ground Truth per component:
# Component 0: min=3.64e-04, max=2.65e-03, mean=9.74e-04, std=5.49e-04
# Component 1: min=-2.99e-04, max=1.51e-04, mean=-1.29e-05, std=9.86e-05
# Component 2: min=3.63e-04, max=2.80e-03, mean=1.06e-03, std=5.55e-04
# Component 3: min=-1.87e-04, max=2.80e-04, mean=1.67e-05, std=9.42e-05
# Component 4: min=-2.72e-04, max=4.06e-04, mean=-6.09e-06, std=1.28e-04
# Component 5: min=4.12e-04, max=2.59e-03, mean=9.78e-04, std=5.59e-04
#
# Relative Error per component:
# Component 0: 1.21e-01
# Component 1: 7.52e+00
# Component 2: 8.82e-02
# Component 3: 6.10e+00
# Component 4: 2.05e+00
# Component 5: 1.25e-01
# Epoch 13/20, Loss: 1.004282
#
# Epoch 14 Statistics:
#
# Predictions per component:
# Component 0: min=6.19e-04, max=2.49e-03, mean=1.12e-03, std=5.26e-04
# Component 1: min=-1.72e-04, max=1.45e-04, mean=-3.93e-05, std=6.55e-05
# Component 2: min=6.46e-04, max=2.53e-03, mean=1.15e-03, std=5.31e-04
# Component 3: min=-1.40e-04, max=1.26e-04, mean=-3.07e-05, std=6.29e-05
# Component 4: min=-2.65e-04, max=1.34e-04, mean=-4.20e-05, std=6.81e-05
# Component 5: min=6.11e-04, max=2.53e-03, mean=1.12e-03, std=5.37e-04
#
# Ground Truth per component:
# Component 0: min=3.63e-04, max=2.42e-03, mean=1.12e-03, std=5.36e-04
# Component 1: min=-1.33e-04, max=2.21e-04, mean=7.13e-06, std=7.39e-05
# Component 2: min=3.65e-04, max=2.30e-03, mean=1.10e-03, std=5.16e-04
# Component 3: min=-2.35e-04, max=2.02e-04, mean=2.12e-05, std=8.20e-05
# Component 4: min=-2.87e-04, max=2.37e-04, mean=-7.68e-06, std=8.37e-05
# Component 5: min=5.92e-04, max=2.52e-03, mean=1.15e-03, std=5.11e-04
#
# Relative Error per component:
# Component 0: 7.42e-02
# Component 1: 2.03e+00
# Component 2: 1.17e-01
# Component 3: 5.02e+00
# Component 4: 2.11e+00
# Component 5: 9.62e-02
# Epoch 14/20, Loss: 0.879144
#
# Epoch 15 Statistics:
#
# Predictions per component:
# Component 0: min=1.80e-04, max=2.81e-03, mean=1.07e-03, std=6.44e-04
# Component 1: min=-1.34e-04, max=3.03e-04, mean=1.04e-05, std=8.74e-05
# Component 2: min=1.92e-04, max=2.84e-03, mean=1.10e-03, std=6.48e-04
# Component 3: min=-3.34e-04, max=2.51e-04, mean=3.87e-05, std=1.05e-04
# Component 4: min=-3.24e-04, max=1.68e-04, mean=-1.45e-05, std=8.98e-05
# Component 5: min=1.75e-04, max=2.87e-03, mean=1.07e-03, std=6.62e-04
#
# Ground Truth per component:
# Component 0: min=1.00e-09, max=3.17e-03, mean=1.07e-03, std=6.89e-04
# Component 1: min=-1.14e-04, max=3.30e-04, mean=2.28e-05, std=1.02e-04
# Component 2: min=1.00e-09, max=3.07e-03, mean=1.07e-03, std=7.02e-04
# Component 3: min=-3.92e-04, max=2.46e-04, mean=-4.63e-06, std=1.12e-04
# Component 4: min=-3.67e-04, max=2.68e-04, mean=-2.11e-05, std=1.10e-04
# Component 5: min=1.00e-09, max=3.09e-03, mean=1.05e-03, std=7.32e-04
#
# Relative Error per component:
# Component 0: 5.11e+03
# Component 1: 4.20e+04
# Component 2: 5.46e+03
# Component 3: 5.65e+04
# Component 4: 2.77e+04
# Component 5: 4.95e+03
# Epoch 15/20, Loss: 0.779387
#
# Epoch 16 Statistics:
#
# Predictions per component:
# Component 0: min=4.26e-04, max=2.71e-03, mean=1.00e-03, std=5.48e-04
# Component 1: min=-3.87e-04, max=-4.28e-05, mean=-2.30e-04, std=8.09e-05
# Component 2: min=4.50e-04, max=2.77e-03, mean=1.04e-03, std=5.56e-04
# Component 3: min=-2.07e-04, max=2.01e-04, mean=7.32e-05, std=1.02e-04
# Component 4: min=-3.59e-04, max=2.80e-04, mean=-7.66e-05, std=1.23e-04
# Component 5: min=4.23e-04, max=2.78e-03, mean=1.01e-03, std=5.67e-04
#
# Ground Truth per component:
# Component 0: min=4.13e-04, max=2.89e-03, mean=9.71e-04, std=6.02e-04
# Component 1: min=-1.59e-04, max=3.26e-04, mean=3.29e-05, std=9.28e-05
# Component 2: min=3.01e-04, max=3.00e-03, mean=1.03e-03, std=6.23e-04
# Component 3: min=-3.15e-04, max=1.43e-04, mean=-3.46e-05, std=1.03e-04
# Component 4: min=-3.32e-04, max=3.60e-04, mean=-3.04e-05, std=1.38e-04
# Component 5: min=2.24e-04, max=2.95e-03, mean=1.01e-03, std=6.35e-04
#
# Relative Error per component:
# Component 0: 1.87e-01
# Component 1: 1.55e+01
# Component 2: 1.51e-01
# Component 3: 3.72e+00
# Component 4: 2.25e+00
# Component 5: 1.74e-01
# Epoch 16/20, Loss: 0.756243
#
# Epoch 17 Statistics:
#
# Predictions per component:
# Component 0: min=5.97e-05, max=2.72e-03, mean=1.01e-03, std=5.43e-04
# Component 1: min=-3.46e-04, max=1.09e-04, mean=-6.74e-05, std=9.23e-05
# Component 2: min=6.61e-05, max=2.76e-03, mean=1.04e-03, std=5.50e-04
# Component 3: min=-2.31e-04, max=2.07e-04, mean=-9.60e-05, std=8.64e-05
# Component 4: min=-3.04e-04, max=1.14e-04, mean=-1.63e-04, std=7.87e-05
# Component 5: min=5.80e-05, max=2.78e-03, mean=1.02e-03, std=5.58e-04
#
# Ground Truth per component:
# Component 0: min=1.00e-09, max=2.74e-03, mean=1.05e-03, std=5.61e-04
# Component 1: min=-3.41e-04, max=2.66e-04, mean=-1.81e-05, std=1.29e-04
# Component 2: min=1.00e-09, max=3.01e-03, mean=1.01e-03, std=5.98e-04
# Component 3: min=-2.05e-04, max=3.96e-04, mean=2.87e-05, std=1.12e-04
# Component 4: min=-2.16e-04, max=3.19e-04, mean=-2.65e-05, std=9.79e-05
# Component 5: min=1.00e-09, max=3.05e-03, mean=9.61e-04, std=5.99e-04
#
# Relative Error per component:
# Component 0: 1.69e+03
# Component 1: 3.41e+04
# Component 2: 1.88e+03
# Component 3: 2.62e+04
# Component 4: 4.74e+04
# Component 5: 1.65e+03
# Epoch 17/20, Loss: 0.700534
#
# Epoch 18 Statistics:
#
# Predictions per component:
# Component 0: min=6.03e-04, max=2.84e-03, mean=1.05e-03, std=5.76e-04
# Component 1: min=-1.55e-04, max=5.25e-04, mean=1.39e-04, std=1.15e-04
# Component 2: min=6.29e-04, max=2.88e-03, mean=1.08e-03, std=5.80e-04
# Component 3: min=-8.14e-05, max=2.83e-04, mean=8.34e-05, std=7.60e-05
# Component 4: min=-4.72e-04, max=1.27e-04, mean=-8.10e-05, std=1.15e-04
# Component 5: min=6.04e-04, max=2.92e-03, mean=1.06e-03, std=5.99e-04
#
# Ground Truth per component:
# Component 0: min=4.01e-04, max=3.17e-03, mean=1.05e-03, std=5.99e-04
# Component 1: min=-3.44e-04, max=2.39e-04, mean=-1.84e-05, std=1.25e-04
# Component 2: min=4.93e-04, max=3.20e-03, mean=1.11e-03, std=6.33e-04
# Component 3: min=-1.69e-04, max=2.16e-04, mean=9.34e-06, std=8.75e-05
# Component 4: min=-4.05e-04, max=1.46e-04, mean=-2.88e-05, std=1.12e-04
# Component 5: min=3.01e-04, max=3.14e-03, mean=1.05e-03, std=6.82e-04
#
# Relative Error per component:
# Component 0: 1.19e-01
# Component 1: 6.06e+00
# Component 2: 1.05e-01
# Component 3: 2.74e+00
# Component 4: 4.09e+00
# Component 5: 1.21e-01
# Epoch 18/20, Loss: 0.626918
#
# Epoch 19 Statistics:
#
# Predictions per component:
# Component 0: min=3.46e-04, max=2.47e-03, mean=1.02e-03, std=5.54e-04
# Component 1: min=-2.70e-05, max=2.86e-04, mean=7.04e-05, std=7.90e-05
# Component 2: min=3.67e-04, max=2.53e-03, mean=1.05e-03, std=5.63e-04
# Component 3: min=-4.93e-05, max=3.44e-04, mean=9.53e-05, std=7.74e-05
# Component 4: min=-4.80e-04, max=1.65e-04, mean=-1.06e-04, std=1.05e-04
# Component 5: min=3.42e-04, max=2.52e-03, mean=1.02e-03, std=5.71e-04
#
# Ground Truth per component:
# Component 0: min=1.51e-04, max=2.40e-03, mean=1.02e-03, std=5.44e-04
# Component 1: min=-3.34e-04, max=3.59e-04, mean=4.37e-05, std=1.14e-04
# Component 2: min=2.22e-04, max=2.59e-03, mean=1.06e-03, std=5.71e-04
# Component 3: min=-1.83e-04, max=2.78e-04, mean=2.00e-05, std=8.91e-05
# Component 4: min=-5.51e-04, max=3.04e-04, mean=-3.02e-05, std=1.37e-04
# Component 5: min=2.11e-04, max=2.58e-03, mean=9.62e-04, std=5.88e-04
#
# Relative Error per component:
# Component 0: 1.34e-01
# Component 1: 9.82e-01
# Component 2: 1.19e-01
# Component 3: 1.61e+01
# Component 4: 2.81e+00
# Component 5: 1.37e-01
# Epoch 19/20, Loss: 0.639156
#
# Epoch 20 Statistics:
#
# Predictions per component:
# Component 0: min=5.16e-04, max=2.77e-03, mean=9.28e-04, std=4.87e-04
# Component 1: min=-3.47e-04, max=1.39e-04, mean=-5.18e-05, std=9.67e-05
# Component 2: min=5.41e-04, max=2.81e-03, mean=9.61e-04, std=4.92e-04
# Component 3: min=-2.56e-04, max=2.00e-04, mean=-4.45e-05, std=9.32e-05
# Component 4: min=-2.29e-04, max=1.77e-04, mean=-2.38e-05, std=9.68e-05
# Component 5: min=5.18e-04, max=2.85e-03, mean=9.43e-04, std=5.05e-04
#
# Ground Truth per component:
# Component 0: min=4.32e-04, max=2.63e-03, mean=8.96e-04, std=4.74e-04
# Component 1: min=-4.53e-04, max=2.24e-04, mean=-2.91e-05, std=1.28e-04
# Component 2: min=4.96e-04, max=2.88e-03, mean=9.61e-04, std=5.10e-04
# Component 3: min=-2.61e-04, max=2.82e-04, mean=3.50e-06, std=9.79e-05
# Component 4: min=-2.58e-04, max=1.25e-04, mean=-3.23e-05, std=9.59e-05
# Component 5: min=3.92e-04, max=2.75e-03, mean=9.09e-04, std=5.33e-04
#
# Relative Error per component:
# Component 0: 1.28e-01
# Component 1: 1.48e+00
# Component 2: 1.29e-01
# Component 3: 4.94e+01
# Component 4: 1.21e+00
# Component 5: 1.74e-01
# Epoch 20/20, Loss: 0.613112
#
# Training Values Statistics:
#
# Component 0:
# Predictions:
# Min: 0.000060
# Max: 0.002837
# Mean: 0.001105
# 1st percentile: 0.000408
# 99th percentile: 0.002690
# Ground Truth:
# Min: 0.000000
# Max: 0.003314
# Mean: 0.001020
# 1st percentile: 0.000264
# 99th percentile: 0.003079
#
# Component 1:
# Predictions:
# Min: -0.000387
# Max: 0.004175
# Mean: 0.000246
# 1st percentile: -0.000341
# 99th percentile: 0.004031
# Ground Truth:
# Min: -0.000619
# Max: 0.000545
# Mean: 0.000001
# 1st percentile: -0.000342
# 99th percentile: 0.000321
#
# Component 2:
# Predictions:
# Min: 0.000066
# Max: 0.003428
# Mean: 0.001314
# 1st percentile: 0.000429
# 99th percentile: 0.003332
# Ground Truth:
# Min: 0.000000
# Max: 0.003504
# Mean: 0.001042
# 1st percentile: 0.000262
# 99th percentile: 0.003141
#
# Component 3:
# Predictions:
# Min: -0.001998
# Max: 0.000344
# Mean: -0.000173
# 1st percentile: -0.001685
# 99th percentile: 0.000235
# Ground Truth:
# Min: -0.000402
# Max: 0.000534
# Mean: 0.000005
# 1st percentile: -0.000308
# 99th percentile: 0.000331
#
# Component 4:
# Predictions:
# Min: -0.000810
# Max: 0.003173
# Mean: 0.000124
# 1st percentile: -0.000538
# 99th percentile: 0.003109
# Ground Truth:
# Min: -0.000551
# Max: 0.000408
# Mean: -0.000020
# 1st percentile: -0.000378
# 99th percentile: 0.000275
#
# Component 5:
# Predictions:
# Min: 0.000058
# Max: 0.002924
# Mean: 0.001136
# 1st percentile: 0.000403
# 99th percentile: 0.002761
# Ground Truth:
# Min: 0.000000
# Max: 0.003468
# Mean: 0.001021
# 1st percentile: 0.000216
# 99th percentile: 0.003177
#
# Final Evaluation...
#
# Final Test Results:
# Average test loss: 0.392834
#
# Test Set Component Analysis:
#
# Component 0:
# Predictions - min: 3.22e-05, max: 3.02e-03, mean: 9.94e-04, std: 5.18e-04
# Ground Truth - min: 1.00e-09, max: 4.63e-03, mean: 9.83e-04, std: 5.40e-04
# Relative Error: 2.43e+02
#
# Component 1:
# Predictions - min: -5.61e-04, max: 5.24e-04, mean: -2.91e-05, std: 9.58e-05
# Ground Truth - min: -1.75e-03, max: 7.33e-04, mean: -1.70e-07, std: 1.15e-04
# Relative Error: 8.09e+02
#
# Component 2:
# Predictions - min: 3.60e-05, max: 3.06e-03, mean: 1.03e-03, std: 5.24e-04
# Ground Truth - min: 1.00e-09, max: 5.15e-03, mean: 1.02e-03, std: 5.48e-04
# Relative Error: 2.61e+02
#
# Component 3:
# Predictions - min: -5.31e-04, max: 5.07e-04, mean: 2.73e-05, std: 9.75e-05
# Ground Truth - min: -7.46e-04, max: 1.81e-03, mean: 3.92e-06, std: 1.17e-04
# Relative Error: 1.10e+03
#
# Component 4:
# Predictions - min: -5.66e-04, max: 5.58e-04, mean: 5.38e-05, std: 1.02e-04
# Ground Truth - min: -2.37e-03, max: 7.94e-04, mean: -2.18e-05, std: 1.21e-04
# Relative Error: 1.07e+03
#
# Component 5:
# Predictions - min: 3.11e-05, max: 3.11e-03, mean: 1.01e-03, std: 5.38e-04
# Ground Truth - min: 1.00e-09, max: 5.85e-03, mean: 9.97e-04, std: 5.54e-04
# Relative Error: 2.49e+02
#
# Example predictions vs ground truth:
#
# Sample 1:
# Predicted: [ 6.1012374e-04 -7.1266666e-05  6.3856487e-04 -1.2814999e-05
#  -8.1781298e-05  6.1539095e-04]
# Actual: [ 8.8329043e-04 -9.4204370e-05  4.8919022e-04 -7.7191027e-05
#  -1.9814237e-04  4.1950148e-04]
#
# Sample 2:
# Predicted: [ 1.9002472e-03 -4.9700961e-05  1.9485618e-03  3.7379563e-05
#   5.2839518e-05  1.9521308e-03]
# Actual: [ 1.84791605e-03 -1.01476784e-04  2.00163131e-03  9.53549534e-05
#  -3.30266921e-05  1.94777781e-03]
#
# Sample 3:
# Predicted: [ 1.1465041e-03 -7.2609633e-05  1.1855486e-03  1.0349229e-04
#   1.3860688e-04  1.1677281e-03]
# Actual: [ 1.1933902e-03  9.0978487e-05  1.1261550e-03 -3.5815749e-05
#   2.4479130e-04  7.8240543e-04]
#
# Sample 4:
# Predicted: [ 0.00074005 -0.00041741  0.00077234  0.00028381 -0.0001868   0.00075136]
# Actual: [ 0.0012316  -0.00064777  0.00069807  0.00041633 -0.00037283  0.00042876]
#
# Sample 5:
# Predicted: [ 6.5439596e-04 -5.9511513e-05  6.8413746e-04  2.2273511e-04
#   2.2985041e-04  6.6087063e-04]
# Actual: [8.5542019e-04 4.1105563e-05 4.2791379e-04 2.5988524e-04 1.7657696e-04
#  8.5970754e-04]

# %%
# print("Original Ground Truth Tensor Analysis:")
# print("\nComponent-wise statistics:")
# for i in range(6):
#     comp = ground_truth_tensors[:, i]
#     print(f"\nComponent {i}:")
#     print(f"Min: {np.min(comp):.2e}")
#     print(f"Max: {np.max(comp):.2e}")
#     print(f"Mean: {np.mean(comp):.2e}")
#     print(f"Std: {np.std(comp):.2e}")

# %%
# print("Loading ground truth data 2...")
# gt_data_v2 = np.load('ground_truth_v2.npz')
# ground_truth_tensors_v2 = gt_data_v2['tensors']
# print(f"Ground truth tensors shape: {ground_truth_tensors_v2.shape}")

# %%
# print("V2 Original Ground Truth Tensor Analysis:")
# print("\nComponent-wise statistics:")
# for i in range(6):
#     comp = ground_truth_tensors_v2[:, i]
#     print(f"\nComponent {i}:")
#     print(f"Min: {np.min(comp):.2e}")
#     print(f"Max: {np.max(comp):.2e}")
#     print(f"Mean: {np.mean(comp):.2e}")
#     print(f"Std: {np.std(comp):.2e}")
