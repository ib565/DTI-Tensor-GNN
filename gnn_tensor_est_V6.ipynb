# %%
import numpy as np
import nibabel as nib
from dipy.io import read_bvals_bvecs
from dipy.core.gradients import gradient_table
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import MessagePassing
from torch_geometric.nn import global_mean_pool
import torch.optim as optim
from torch_geometric.data import Data, Batch
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import datetime

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
subject_id = "100206"
subject_path = f"diffusion_data/{subject_id}/T1w/Diffusion"
dwi_img = nib.load(f'{subject_path}/data.nii.gz')
mask_img = nib.load(f'{subject_path}/nodif_brain_mask.nii.gz')

# %%
dwi_data = dwi_img.get_fdata()
original_mask = mask_img.get_fdata() > 0

print(f"DWI data shape: {dwi_data.shape}")  # (X, Y, Z, num_volumes)
# Out:
# DWI data shape: (145, 174, 145, 288)

# %%
gt_data = np.load('ground_truth_v2.npz')
ground_truth_tensors = gt_data['tensors'] # shape 936256(all voxels) x 6
ground_truth_gpu = torch.from_numpy(ground_truth_tensors).to(device)

# %%
# store original indices before any voxel filtering 
original_idx = np.where(original_mask)

# %%
original_idx
# Out:
# (array([ 12,  12,  12, ..., 130, 130, 130], dtype=int64),
#  array([84, 84, 84, ..., 91, 91, 91], dtype=int64),
#  array([55, 56, 57, ..., 45, 46, 47], dtype=int64))

# %%
# Map (x,y,z) to original linear index
coord_to_gtt = {}
for i in range(len(original_idx[0])):
    x, y, z = original_idx[0][i], original_idx[1][i], original_idx[2][i]
    coord_to_gtt[(x,y,z)] = i  # i is the index in ground_truth_tensors

# %%
bvals, bvecs = read_bvals_bvecs(f'{subject_path}/bvals', 
                               f'{subject_path}/bvecs')
gtab = gradient_table(bvals, bvecs)

# get b0 data and b0_avg
b0_mask = gtab.b0s_mask
b0_data = dwi_data[..., b0_mask]
print(f"B0 data shape: {b0_data.shape}")
b0_avg = np.mean(b0_data, axis=-1)

# b1000 images mask
b1000_mask = (bvals >= 990) & (bvals <= 1010)
print(f"Number of b=1000 volumes: {np.sum(b1000_mask)}")

# Get all b1000 scans
dwi_vols = dwi_data[..., b1000_mask]
print(f"DWI volumes shape: {dwi_vols.shape}")
# Out:
# B0 data shape: (145, 174, 145, 18)
# Number of b=1000 volumes: 90
# DWI volumes shape: (145, 174, 145, 90)

# %%
# mask out voxels with very low b0 signal
b0_threshold = 250
valid_b0_mask = b0_avg > b0_threshold
mask = original_mask & valid_b0_mask  # Combine with brain mask

# %%
# Find valid voxels using the brain mask
valid_idx = np.where(mask) # shape: 3 x num_valid_voxels
print(f"\nNumber of valid voxels in mask: {len(valid_idx[0])}")
# Out:
# Number of valid voxels in mask: 926671

# %%
# Sample n random voxels for training
n_samples = 100000
sample_idx = np.random.choice(len(valid_idx[0]), 
                            min(n_samples, len(valid_idx[0])), 
                            replace=False)

# %%
# Extract features (signal intensities) from sampled voxels. 90 image signals per voxel
features = []
gtt_indices = [] # store ground truth tensor indices. gtt_indices[i] gives index of feature[i] in original number of voxels (93XXXX)

for idx in sample_idx:
    x, y, z = valid_idx[0][idx], valid_idx[1][idx], valid_idx[2][idx]
    signal = dwi_vols[x, y, z, :]
    b0_ref = b0_avg[x, y, z]
    normalized_signal = signal / (b0_ref)
    features.append(normalized_signal)
    gtt_indices.append(coord_to_gtt[(x, y, z)])

# gtt_indices shape = num_voxel_samples x 1
# features shape = num_voxel_samples x 90 x 1

# %%
features = np.array(features)
gtt_indices = np.array(gtt_indices)
features_gpu = torch.from_numpy(features).to(device)
gtt_indices_gpu = torch.from_numpy(gtt_indices).to(device)
gradient_directions = bvecs[b1000_mask]  # Only keep directions for DWI volumes, shape = 90 x 3

# %%
def select_diverse_directions(all_directions, n_select=21):
    """" Get n random directions with high coverage """
    
    selected = [0]  # Start with first direction
    while len(selected) < n_select:
        # Calculate angles with all selected directions
        angles = []
        for i in range(len(all_directions)):
            if i in selected:
                continue
            min_angle = float('inf')
            for s in selected:
                # Cosine similarity
                angle = np.arccos(np.clip(
                    np.dot(all_directions[i], all_directions[s]), -1.0, 1.0))
                min_angle = min(min_angle, angle)
            angles.append((i, min_angle))
        # Select direction with largest minimum angle
        next_idx = max(angles, key=lambda x: x[1])[0]
        selected.append(next_idx)
    return selected

# %%
def initialize_direction_sets(all_directions, n_sets=3, n_directions=21):
    """ Create sets of sparse directions """
    base_sets = []
    n_total = len(all_directions)
    
    for i in range(n_sets):
        # Create a shuffled index array for this set
        shuffled_indices = np.random.permutation(n_total)
        # Use select_diverse_directions on the shuffled indices
        selected = select_diverse_directions(all_directions[shuffled_indices], n_directions)
        # Map back to original indices
        original_indices = shuffled_indices[selected]
        base_sets.append(original_indices)
    
    return base_sets

# %%
class DiffusionGNN(torch.nn.Module):
    def __init__(self, node_features = 4, hidden_dim = 128):
        super(DiffusionGNN, self).__init__()
    
        # Layers
        self.conv1 = DiffusionConv(node_features, hidden_dim)
        self.conv2 = DiffusionConv(hidden_dim, hidden_dim)

        # MLP for tensor prediction
        self.mlp = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 6),
        )

        self.register_buffer('loss_weights',
            torch.tensor([10, 1000, 10, 1000, 1000, 10]))

    
    def forward(self, x, edge_index, edge_attr, batch):
        """
        x: node_features
        edge_index = graph conn info [2, num_edges]
        batch: batch assignment for nodes
        """
        # x shape = 672 (batch_size*num_directions) x 4
        x = self.conv1(x, edge_index, edge_attr)
        x = F.relu(x)
        x = self.conv2(x, edge_index, edge_attr)
        x = F.relu(x)
        # x shape = 672 x hidden_dim(64)

        # combine node features for graph
        x = global_mean_pool(x, batch)  # [batch_size, hidden_dim]. 1 representation for each voxel/graph

        # raw predictions
        out = self.mlp(x) # shape = 32 x 6

        diag_idx = [0, 2, 5]
        offdiag_idx = [1, 3, 4]

        # Diagonal elements: [0,1] using sigmoid
        diag = torch.sigmoid(out[:, diag_idx])
        
        # Off-diagonal elements: [-1,1] using tanh
        offdiag = torch.tanh(out[:, offdiag_idx])

        out_reordered = torch.zeros_like(out)
        out_reordered[:, diag_idx] = diag
        out_reordered[:, offdiag_idx] = offdiag

        return out_reordered # shape = 32 x 6
    
    def weighted_mse_loss(self, pred, target):
        squared_diff = (pred - target) ** 2  # [batch_size, 6]
        weighted_diff = squared_diff * self.loss_weights
        return torch.mean(weighted_diff)


class DiffusionConv(MessagePassing):
    def __init__(self, in_channels, out_channels):
        super(DiffusionConv, self).__init__(aggr="mean")
        
        # MLP to process messages
        self.mlp = nn.Sequential(
            nn.Linear(2 * in_channels, out_channels),
            nn.ReLU(),
            nn.Linear(out_channels, out_channels)
        )
    
    def forward(self, x, edge_index, edge_weight):
        return self.propagate(edge_index, x=x, edge_weight = edge_weight)
    
    def message(self, x_i, x_j, edge_weight):
        """
        x_i: features of target nodes
        x_j: features of source nodes
        Returns: messages to be aggregated
        """
        tmp = torch.cat([x_i, x_j], dim = 1)
        return self.mlp(tmp) * edge_weight.view(-1,1)

# %%
def convert_to_torch_geometric(nodes, edges, edge_weights, tensors):
    """ convert graph to geometric object"""
    data_list = []
    device = nodes.device
    
    for i in range(len(nodes)):
        tensor = tensors[i].reshape(-1, 6) if len(tensors[i].shape) == 1 else tensors[i]
        data = Data(
            x=nodes[i],
            edge_index = edges[i].clone().detach().to(dtype=torch.long, device=device).T,
            edge_attr=edge_weights[i].clone().detach().to(dtype=torch.float, device=device),
            y=tensor
        )
        data_list.append(data)
    
    return data_list

# %%
train_idx, test_idx = train_test_split(np.arange(len(features)), test_size=0.2, random_state=42)
print(f"Training with {len(train_idx)} voxels, testing with {len(test_idx)} voxels")
# Out:
# Training with 80000 voxels, testing with 20000 voxels

# %%
def calculate_MD(tensor):
    """Calculate Mean Diffusivity: (Dxx + Dyy + Dzz)/3"""
    return np.mean(tensor[:,[0,2,5]], axis=1)

def calculate_FA_approx(tensor):
    """Calculate Fractional Anisotropy using characteristic equation approximation"""

    Dxx, Dxy, Dyy, Dxz, Dyz, Dzz = [tensor[:,i] for i in range(6)]
    md = calculate_MD(tensor)
    
    var_terms = ((Dxx - md)**2 + (Dyy - md)**2 + (Dzz - md)**2 + 6 * (Dxy**2 + Dxz**2 + Dyz**2)) / 3
    tensor_norm = Dxx**2 + Dyy**2 + Dzz**2 + 2*(Dxy**2 + Dxz**2 + Dyz**2)

    fa = np.sqrt(3 * var_terms / (2 * (tensor_norm + 1e-10)))
    return fa

def principal_eigenvector_angle_error(pred, gt, fa_threshold=0.2):
    """
    Compute angle between principal eigenvectors for a batch of tensors.
    Args:
        pred: predictions array (n_samples x 6)
        gt: ground truth array (n_samples x 6)
        fa_threshold: minimum FA value to consider (default 0.2)
    Returns:
        angles: array of angle errors in degrees for samples above FA threshold
        mask: boolean array indicating which samples were used
    """
    # Calculate FA using existing function
    fa = calculate_FA_approx(gt)
    
    # Create mask for high FA voxels
    # [NEW] Create mask instead of single threshold
    mask = fa > fa_threshold
    
    # [NEW] Early return if no valid voxels
    if not np.any(mask):
        return np.array([]), mask
    
    # [NEW] Filter tensors based on mask
    pred_valid = pred[mask]
    gt_valid = gt[mask]
    
    # [NEW] Preallocate arrays for batch processing
    n_valid = np.sum(mask)
    angles = np.zeros(n_valid)
    
    # [NEW] Reshape tensors for batch processing
    pred_matrices = np.zeros((n_valid, 3, 3))
    gt_matrices = np.zeros((n_valid, 3, 3))
    
    # Construct matrices for all valid tensors
    pred_matrices[:, 0, 0] = pred_valid[:, 0]  # Dxx
    pred_matrices[:, 0, 1] = pred_matrices[:, 1, 0] = pred_valid[:, 1]  # Dxy
    pred_matrices[:, 1, 1] = pred_valid[:, 2]  # Dyy
    pred_matrices[:, 0, 2] = pred_matrices[:, 2, 0] = pred_valid[:, 3]  # Dxz
    pred_matrices[:, 1, 2] = pred_matrices[:, 2, 1] = pred_valid[:, 4]  # Dyz
    pred_matrices[:, 2, 2] = pred_valid[:, 5]  # Dzz
    
    gt_matrices[:, 0, 0] = gt_valid[:, 0]
    gt_matrices[:, 0, 1] = gt_matrices[:, 1, 0] = gt_valid[:, 1]
    gt_matrices[:, 1, 1] = gt_valid[:, 2]
    gt_matrices[:, 0, 2] = gt_matrices[:, 2, 0] = gt_valid[:, 3]
    gt_matrices[:, 1, 2] = gt_matrices[:, 2, 1] = gt_valid[:, 4]
    gt_matrices[:, 2, 2] = gt_valid[:, 5]
    
    # [NEW] Vectorized eigenvalue computation
    for i in range(n_valid):
        pred_evals, pred_evecs = np.linalg.eigh(pred_matrices[i])
        gt_evals, gt_evecs = np.linalg.eigh(gt_matrices[i])
        
        v1_pred = pred_evecs[:, np.argmax(pred_evals)]
        v1_gt = gt_evecs[:, np.argmax(gt_evals)]
        
        cos_theta = np.abs(np.dot(v1_pred, v1_gt))
        cos_theta = np.clip(cos_theta, -1.0, 1.0)
        angles[i] = np.degrees(np.arccos(cos_theta))
    
    return angles, mask

# %%
def evaluate_model(pred, gt, epoch, print_results=True):
    """
    Compute and optionally print evaluation metrics
    Args:
        pred: predictions array (n_samples x 6)
        gt: ground truth array (n_samples x 6)
        epoch: current epoch number
        print_results: whether to print metrics
    Returns:
        Dictionary of metrics
    """
    metrics = {}
    metrics['epoch'] = epoch
    
    # Component-wise statistics and relative errors
    for i in range(6):
        # Relative error
        rel_error = np.mean(np.abs(pred[:,i] - gt[:,i]) / (np.abs(gt[:,i]) + 1e-10))
        metrics[f'rel_error_{i}'] = rel_error
        
        # Statistics for monitoring distribution
        metrics[f'pred_mean_{i}'] = np.mean(pred[:,i])
        metrics[f'pred_std_{i}'] = np.std(pred[:,i])
        metrics[f'gt_mean_{i}'] = np.mean(gt[:,i])
        metrics[f'gt_std_{i}'] = np.std(gt[:,i])
    
    # Mean Diffusivity error
    pred_md = calculate_MD(pred)
    gt_md = calculate_MD(gt)
    metrics['md_error'] = np.mean(np.abs(pred_md - gt_md))

    # FA absolute error
    pred_fa = calculate_FA_approx(pred)
    gt_fa = calculate_FA_approx(gt)
    metrics['fa_error'] = np.mean(np.abs(pred_fa - gt_fa))

    angles, mask = principal_eigenvector_angle_error(pred, gt)

    metrics['angular_error'] = np.mean(angles)

    if print_results:
        print(f"\nEpoch {epoch+1} Statistics:")
        print("\nRelative Errors per component:")
        for i in range(6):
            print(f"Component {i}: {metrics[f'rel_error_{i}']:.2e}")
        print(f"Mean Diffusivity Absolute Error: {metrics['md_error']:.2e}")
        print(f"FA Absolute Error: {metrics['fa_error']:.2e}")
        print(f"Angular Error: {metrics['angular_error']:.2e}")
        
        print("\nPrediction Statistics:")
        for i in range(6):
            print(f"Component {i}: mean={metrics[f'pred_mean_{i}']:.2e}, std={metrics[f'pred_std_{i}']:.2e}")
        
        print("\nGround Truth Statistics:")
        for i in range(6):
            print(f"Component {i}: mean={metrics[f'gt_mean_{i}']:.2e}, std={metrics[f'gt_std_{i}']:.2e}")
    
    return metrics

# %%
def evaluate_model(pred, gt, epoch, print_results=True):
    """
    Compute and optionally print evaluation metrics
    Args:
        pred: predictions array (n_samples x 6)
        gt: ground truth array (n_samples x 6)
        epoch: current epoch number
        print_results: whether to print metrics
    Returns:
        Dictionary of metrics
    """
    metrics = {}
    metrics['epoch'] = epoch
    
    # Component-wise statistics and relative errors
    for i in range(6):
        # Relative error
        rel_error = np.mean(np.abs(pred[:,i] - gt[:,i]) / (np.abs(gt[:,i]) + 1e-10))
        metrics[f'rel_error_{i}'] = rel_error
        
        # Abs error
        abs_error = np.mean(np.abs(pred[:,i] - gt[:, i]))
        metrics[f'abs_error_{i}'] = abs_error

        # Statistics for monitoring distribution
        metrics[f'pred_mean_{i}'] = np.mean(pred[:,i])
        metrics[f'pred_std_{i}'] = np.std(pred[:,i])
        metrics[f'gt_mean_{i}'] = np.mean(gt[:,i])
        metrics[f'gt_std_{i}'] = np.std(gt[:,i])
    
    # Mean Diffusivity error
    pred_md = calculate_MD(pred)
    gt_md = calculate_MD(gt)
    metrics['md_error'] = np.mean(np.abs(pred_md - gt_md))

    # FA absolute error
    pred_fa = calculate_FA_approx(pred)
    gt_fa = calculate_FA_approx(gt)
    metrics['fa_error'] = np.mean(np.abs(pred_fa - gt_fa))

    angles, mask = principal_eigenvector_angle_error(pred, gt)

    metrics['angular_error'] = np.mean(angles)

    if print_results:
        print(f"\nEpoch {epoch+1} Statistics:")
        # print("\nRelative Errors per component:")
        # for i in range(6):
        #     print(f"Component {i}: {metrics[f'rel_error_{i}']:.2e}")
        print("\nAbsolute Errors per component:")
        for i in range(6):
            print(f"Component {i}: {metrics[f'abs_error_{i}']:.2e}")
        print(f"Mean Diffusivity Absolute Error: {metrics['md_error']:.2e}")
        print(f"FA Absolute Error: {metrics['fa_error']:.2e}")
        print(f"Angular Error: {metrics['angular_error']}")
        
        print("\nPrediction Statistics:")
        for i in range(6):
            print(f"Component {i}: mean={metrics[f'pred_mean_{i}']:.2e}, std={metrics[f'pred_std_{i}']:.2e}")
        
        print("\nGround Truth Statistics:")
        for i in range(6):
            print(f"Component {i}: mean={metrics[f'gt_mean_{i}']:.2e}, std={metrics[f'gt_std_{i}']:.2e}")
    
    return metrics

# %%
def precompute_direction_structures(direction_indices, threshold_angle=60):
    """
    Precompute direction-based graph structures that remain constant across batches.
    """
    current_directions = gradient_directions[direction_indices]  # Shape (21, 3)
    directions_norm = current_directions / np.linalg.norm(current_directions, axis=1, keepdims=True)
    
    cos_sim = np.dot(directions_norm, directions_norm.T)
    angles = np.arccos(np.clip(cos_sim, -1.0, 1.0)) * 180/np.pi
    src, dst = np.where(angles < threshold_angle)
    mask = src != dst
    
    return {
        'edge_template': np.column_stack([src[mask], dst[mask]]),
        'edge_weights': cos_sim[src[mask], dst[mask]],
        'directions': current_directions,
        'direction_indices': direction_indices
    }


def create_batch_data(batch_indices, direction_structures, features_gpu, ground_truth_gpu):
    """
    Create graph data for a batch using GPU tensors.
    
    Args:
        batch_indices: array of indices for this batch, shape (batch_size,)
        direction_structures: dict of precomputed direction structures
        features_gpu: GPU tensor of all features, shape (n_samples, 90)
        ground_truth_gpu: GPU tensor of ground truth, shape (n_samples, 6)
    
    Returns:
        batch_nodes: [batch_size, n_directions, 4] node features (GPU)
        batch_edges: list of [E, 2] edge indices for each graph
        batch_edge_weights: list of [E] edge weights for each graph
        batch_tensors: [batch_size, 6] ground truth tensors (GPU)
    """
    n_directions = direction_structures['directions'].shape[0]  # Should be 21
    
    # Convert batch_indices to GPU tensor if not already
    if not isinstance(batch_indices, torch.Tensor):
        batch_indices = torch.tensor(batch_indices, device=features_gpu.device)
    
    # Get batch of signals and select directions
    # features_gpu shape: (n_samples, 90)
    # batch_features shape: (batch_size, 90)
    batch_features = features_gpu[batch_indices]
    
    # Select specific directions
    # direction_indices shape: (21,)
    
    direction_indices = torch.tensor(direction_structures['direction_indices'], 
                               device=features_gpu.device)
    
    # batch_signals shape: (batch_size, 21)
    batch_signals = batch_features[:, direction_indices]
    
    # Create node features on GPU
    # batch_nodes shape: (batch_size, n_directions, 4)
    batch_nodes = torch.zeros((batch_indices.shape[0], n_directions, 4), 
                            device=features_gpu.device)
    batch_nodes[..., 0] = batch_signals
    batch_nodes[..., 1:4] = direction_structures['directions'].unsqueeze(0)
    
    # Edge structures (already on GPU from direction_structures_gpu)
    batch_edges = [direction_structures['edge_template'] 
                  for _ in range(batch_indices.shape[0])]
    batch_edge_weights = [direction_structures['edge_weights'] 
                         for _ in range(batch_indices.shape[0])]
    
    # Get ground truth tensors directly from GPU tensor
    # gtt_indices maps from batch_indices to ground truth indices
    # batch_tensors shape: (batch_size, 6)
    batch_tensors = ground_truth_gpu[gtt_indices_gpu[batch_indices]]

    return batch_nodes, batch_edges, batch_edge_weights, batch_tensors

# %%
n_sets = 3
direction_sets = initialize_direction_sets(gradient_directions, n_sets)
direction_structures = {}
for set_idx, direction_set in enumerate(direction_sets):
    direction_structures[set_idx] = precompute_direction_structures(direction_set)
batch_size = 32
learning_rate = 0.0005

# %%
# Convert direction structures once
direction_structures_gpu = {}
for idx, struct in direction_structures.items():
    direction_structures_gpu[idx] = {
        'edge_template': torch.from_numpy(struct['edge_template']).to(device),
        'edge_weights': torch.from_numpy(struct['edge_weights']).to(device),
        'directions': torch.from_numpy(struct['directions']).to(device),
        'direction_indices': struct['direction_indices']
    }

# %%
# Training
model = DiffusionGNN(hidden_dim=128).to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

epochs = 130
losses = []
all_metrics = []
print("Starting training...")
for epoch in range(epochs):
    # Select direction set for this epoch
    direction_set_idx = epoch % len(direction_sets)
    current_structures = direction_structures_gpu[direction_set_idx]
    model.train()
    epoch_loss = 0
    n_batches = 0
    
    # Store epoch predictions and ground truth
    epoch_pred_values = []
    epoch_gt_values = []
    
    # Shuffle training indices
    np.random.shuffle(train_idx)
    
    # Process batches
    for start in range(0, len(train_idx), batch_size):
        batch_indices = train_idx[start:start + batch_size]
        
        # Create graph data using precomputed structures
        nodes, edges, edge_weights, tensors = create_batch_data(
            batch_indices,
            current_structures,
            features_gpu,
            ground_truth_gpu
        )

        data_list = convert_to_torch_geometric(nodes, edges, edge_weights, tensors)
        batch_data = Batch.from_data_list(data_list).to(device)
        
        # Training step
        optimizer.zero_grad()
        pred = model(batch_data.x, batch_data.edge_index, batch_data.edge_attr, batch_data.batch)
        loss = model.weighted_mse_loss(pred, batch_data.y) * 1e6
        loss.backward()
        optimizer.step()
        
        # Store batch results
        epoch_loss += loss.item()
        epoch_pred_values.append(pred.detach().cpu().numpy())
        epoch_gt_values.append(batch_data.y.cpu().numpy())
        n_batches += 1
    
    # Combine all batches
    epoch_pred = np.concatenate(epoch_pred_values, axis=0)
    epoch_gt = np.concatenate(epoch_gt_values, axis=0)
    
    # Print epoch results
    avg_loss = epoch_loss / n_batches
    losses.append(avg_loss)
    print("\nxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
    print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.6f}")
    
    # Evaluate epoch performance
    if (epoch + 1) % 5 == 0:
        metrics = evaluate_model(epoch_pred, epoch_gt, epoch)
        all_metrics.append(metrics)
# Out:
# Starting training...
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 1/130, Loss: 37245.980580
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 2/130, Loss: 694.732468
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 3/130, Loss: 344.283426
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 4/130, Loss: 173.692905
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 5/130, Loss: 97.083622
#
# Epoch 5 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.23e-03
# Component 1: 3.54e-04
# Component 2: 9.80e-04
# Component 3: 3.23e-04
# Component 4: 2.97e-04
# Component 5: 1.04e-03
# Mean Diffusivity Absolute Error: 1.08e-03
# FA Absolute Error: 1.80e-01
# Angular Error: 5.46e+01
#
# Prediction Statistics:
# Component 0: mean=2.21e-03, std=3.18e-04
# Component 1: mean=-3.06e-07, std=4.52e-04
# Component 2: mean=1.97e-03, std=2.93e-04
# Component 3: mean=3.21e-06, std=4.19e-04
# Component 4: mean=-2.27e-05, std=3.82e-04
# Component 5: mean=2.01e-03, std=2.99e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 6/130, Loss: 64.033936
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 7/130, Loss: 37.495835
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 8/130, Loss: 22.718728
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 9/130, Loss: 16.093454
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 10/130, Loss: 12.536993
#
# Epoch 10 Statistics:
#
# Absolute Errors per component:
# Component 0: 2.40e-04
# Component 1: 1.29e-04
# Component 2: 2.32e-04
# Component 3: 1.17e-04
# Component 4: 1.20e-04
# Component 5: 2.38e-04
# Mean Diffusivity Absolute Error: 2.10e-04
# FA Absolute Error: 1.17e-01
# Angular Error: 3.82e+01
#
# Prediction Statistics:
# Component 0: mean=1.09e-03, std=3.16e-04
# Component 1: mean=-5.29e-07, std=1.75e-04
# Component 2: mean=1.12e-03, std=3.48e-04
# Component 3: mean=3.42e-06, std=1.68e-04
# Component 4: mean=-2.25e-05, std=1.68e-04
# Component 5: mean=1.10e-03, std=3.41e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 11/130, Loss: 10.078799
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 12/130, Loss: 8.667162
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 13/130, Loss: 7.929191
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 14/130, Loss: 7.351424
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 15/130, Loss: 6.474934
#
# Epoch 15 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.71e-04
# Component 1: 9.26e-05
# Component 2: 1.74e-04
# Component 3: 8.64e-05
# Component 4: 8.20e-05
# Component 5: 1.70e-04
# Mean Diffusivity Absolute Error: 1.27e-04
# FA Absolute Error: 8.73e-02
# Angular Error: 3.26e+01
#
# Prediction Statistics:
# Component 0: mean=1.04e-03, std=3.87e-04
# Component 1: mean=-5.24e-07, std=1.40e-04
# Component 2: mean=1.07e-03, std=4.10e-04
# Component 3: mean=3.43e-06, std=1.39e-04
# Component 4: mean=-2.24e-05, std=1.43e-04
# Component 5: mean=1.05e-03, std=4.11e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 16/130, Loss: 6.093260
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 17/130, Loss: 5.825518
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 18/130, Loss: 5.265776
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 19/130, Loss: 5.072630
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 20/130, Loss: 4.945606
#
# Epoch 20 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.26e-04
# Component 1: 7.73e-05
# Component 2: 1.34e-04
# Component 3: 7.66e-05
# Component 4: 7.68e-05
# Component 5: 1.29e-04
# Mean Diffusivity Absolute Error: 7.07e-05
# FA Absolute Error: 7.78e-02
# Angular Error: 3.09e+01
#
# Prediction Statistics:
# Component 0: mean=1.02e-03, std=4.60e-04
# Component 1: mean=-5.11e-07, std=1.28e-04
# Component 2: mean=1.06e-03, std=4.70e-04
# Component 3: mean=3.38e-06, std=1.31e-04
# Component 4: mean=-2.24e-05, std=1.35e-04
# Component 5: mean=1.03e-03, std=4.78e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 21/130, Loss: 4.673754
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 22/130, Loss: 4.508038
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 23/130, Loss: 4.382473
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 24/130, Loss: 4.144964
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 25/130, Loss: 4.134948
#
# Epoch 25 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.03e-04
# Component 1: 7.05e-05
# Component 2: 1.24e-04
# Component 3: 6.84e-05
# Component 4: 7.17e-05
# Component 5: 1.15e-04
# Mean Diffusivity Absolute Error: 4.95e-05
# FA Absolute Error: 7.25e-02
# Angular Error: 2.96e+01
#
# Prediction Statistics:
# Component 0: mean=1.01e-03, std=5.01e-04
# Component 1: mean=-5.18e-07, std=1.24e-04
# Component 2: mean=1.04e-03, std=5.04e-04
# Component 3: mean=3.34e-06, std=1.26e-04
# Component 4: mean=-2.24e-05, std=1.30e-04
# Component 5: mean=1.02e-03, std=5.17e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 26/130, Loss: 3.912934
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 27/130, Loss: 3.756406
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 28/130, Loss: 3.732000
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 29/130, Loss: 3.821104
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 30/130, Loss: 3.519841
#
# Epoch 30 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.05e-04
# Component 1: 6.78e-05
# Component 2: 1.12e-04
# Component 3: 6.50e-05
# Component 4: 6.01e-05
# Component 5: 1.04e-04
# Mean Diffusivity Absolute Error: 3.51e-05
# FA Absolute Error: 6.85e-02
# Angular Error: 2.86e+01
#
# Prediction Statistics:
# Component 0: mean=9.99e-04, std=5.14e-04
# Component 1: mean=-5.27e-07, std=1.21e-04
# Component 2: mean=1.04e-03, std=5.20e-04
# Component 3: mean=3.40e-06, std=1.23e-04
# Component 4: mean=-2.24e-05, std=1.27e-04
# Component 5: mean=1.01e-03, std=5.31e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 31/130, Loss: 3.661470
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 32/130, Loss: 3.499557
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 33/130, Loss: 3.352315
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 34/130, Loss: 3.278499
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 35/130, Loss: 3.421005
#
# Epoch 35 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.06e-04
# Component 1: 6.53e-05
# Component 2: 1.07e-04
# Component 3: 6.21e-05
# Component 4: 6.13e-05
# Component 5: 1.02e-04
# Mean Diffusivity Absolute Error: 3.19e-05
# FA Absolute Error: 6.71e-02
# Angular Error: 2.84e+01
#
# Prediction Statistics:
# Component 0: mean=9.97e-04, std=5.17e-04
# Component 1: mean=-5.51e-07, std=1.21e-04
# Component 2: mean=1.04e-03, std=5.26e-04
# Component 3: mean=3.38e-06, std=1.22e-04
# Component 4: mean=-2.24e-05, std=1.25e-04
# Component 5: mean=1.01e-03, std=5.36e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 36/130, Loss: 3.250396
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 37/130, Loss: 3.249569
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 38/130, Loss: 3.063764
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 39/130, Loss: 3.093981
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 40/130, Loss: 3.158531
#
# Epoch 40 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.01e-04
# Component 1: 6.21e-05
# Component 2: 1.11e-04
# Component 3: 6.06e-05
# Component 4: 5.97e-05
# Component 5: 1.02e-04
# Mean Diffusivity Absolute Error: 3.23e-05
# FA Absolute Error: 6.51e-02
# Angular Error: 2.80e+01
#
# Prediction Statistics:
# Component 0: mean=9.97e-04, std=5.20e-04
# Component 1: mean=-5.23e-07, std=1.20e-04
# Component 2: mean=1.04e-03, std=5.28e-04
# Component 3: mean=3.38e-06, std=1.22e-04
# Component 4: mean=-2.24e-05, std=1.23e-04
# Component 5: mean=1.01e-03, std=5.39e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 41/130, Loss: 2.981937
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 42/130, Loss: 2.952424
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 43/130, Loss: 2.867713
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 44/130, Loss: 2.965266
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 45/130, Loss: 2.692079
#
# Epoch 45 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.05e-04
# Component 1: 6.10e-05
# Component 2: 1.05e-04
# Component 3: 5.56e-05
# Component 4: 5.03e-05
# Component 5: 9.96e-05
# Mean Diffusivity Absolute Error: 2.87e-05
# FA Absolute Error: 6.08e-02
# Angular Error: 2.74e+01
#
# Prediction Statistics:
# Component 0: mean=9.95e-04, std=5.23e-04
# Component 1: mean=-5.24e-07, std=1.17e-04
# Component 2: mean=1.04e-03, std=5.33e-04
# Component 3: mean=3.40e-06, std=1.17e-04
# Component 4: mean=-2.24e-05, std=1.22e-04
# Component 5: mean=1.01e-03, std=5.42e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 46/130, Loss: 2.785733
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 47/130, Loss: 2.832287
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 48/130, Loss: 2.654367
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 49/130, Loss: 2.688658
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 50/130, Loss: 2.672776
#
# Epoch 50 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.05e-04
# Component 1: 5.84e-05
# Component 2: 1.04e-04
# Component 3: 5.42e-05
# Component 4: 5.37e-05
# Component 5: 1.02e-04
# Mean Diffusivity Absolute Error: 2.94e-05
# FA Absolute Error: 6.04e-02
# Angular Error: 2.74e+01
#
# Prediction Statistics:
# Component 0: mean=9.96e-04, std=5.21e-04
# Component 1: mean=-5.21e-07, std=1.16e-04
# Component 2: mean=1.04e-03, std=5.32e-04
# Component 3: mean=3.41e-06, std=1.16e-04
# Component 4: mean=-2.24e-05, std=1.21e-04
# Component 5: mean=1.01e-03, std=5.39e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 51/130, Loss: 2.503978
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 52/130, Loss: 2.558379
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 53/130, Loss: 2.536413
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 54/130, Loss: 2.402285
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 55/130, Loss: 2.530319
#
# Epoch 55 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.02e-04
# Component 1: 5.60e-05
# Component 2: 1.08e-04
# Component 3: 5.22e-05
# Component 4: 5.36e-05
# Component 5: 1.04e-04
# Mean Diffusivity Absolute Error: 3.14e-05
# FA Absolute Error: 5.93e-02
# Angular Error: 2.69e+01
#
# Prediction Statistics:
# Component 0: mean=9.96e-04, std=5.21e-04
# Component 1: mean=-4.85e-07, std=1.15e-04
# Component 2: mean=1.04e-03, std=5.30e-04
# Component 3: mean=3.40e-06, std=1.16e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.01e-03, std=5.39e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 56/130, Loss: 2.400082
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 57/130, Loss: 2.303134
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 58/130, Loss: 2.290416
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 59/130, Loss: 2.356839
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 60/130, Loss: 2.225274
#
# Epoch 60 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.05e-04
# Component 1: 5.47e-05
# Component 2: 1.06e-04
# Component 3: 4.94e-05
# Component 4: 4.61e-05
# Component 5: 1.01e-04
# Mean Diffusivity Absolute Error: 2.99e-05
# FA Absolute Error: 5.62e-02
# Angular Error: 2.64e+01
#
# Prediction Statistics:
# Component 0: mean=9.95e-04, std=5.22e-04
# Component 1: mean=-5.28e-07, std=1.13e-04
# Component 2: mean=1.03e-03, std=5.31e-04
# Component 3: mean=3.38e-06, std=1.14e-04
# Component 4: mean=-2.24e-05, std=1.19e-04
# Component 5: mean=1.01e-03, std=5.40e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 61/130, Loss: 2.209642
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 62/130, Loss: 2.260014
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 63/130, Loss: 2.101667
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 64/130, Loss: 2.178791
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 65/130, Loss: 2.172936
#
# Epoch 65 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.04e-04
# Component 1: 5.19e-05
# Component 2: 1.04e-04
# Component 3: 4.73e-05
# Component 4: 4.85e-05
# Component 5: 1.01e-04
# Mean Diffusivity Absolute Error: 2.83e-05
# FA Absolute Error: 5.64e-02
# Angular Error: 2.64e+01
#
# Prediction Statistics:
# Component 0: mean=9.94e-04, std=5.23e-04
# Component 1: mean=-5.23e-07, std=1.12e-04
# Component 2: mean=1.04e-03, std=5.32e-04
# Component 3: mean=3.40e-06, std=1.12e-04
# Component 4: mean=-2.24e-05, std=1.18e-04
# Component 5: mean=1.01e-03, std=5.40e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 66/130, Loss: 2.082204
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 67/130, Loss: 2.076932
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 68/130, Loss: 2.126829
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 69/130, Loss: 2.010343
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 70/130, Loss: 2.054417
#
# Epoch 70 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.01e-04
# Component 1: 4.90e-05
# Component 2: 1.07e-04
# Component 3: 4.60e-05
# Component 4: 4.86e-05
# Component 5: 1.02e-04
# Mean Diffusivity Absolute Error: 2.91e-05
# FA Absolute Error: 5.53e-02
# Angular Error: 2.60e+01
#
# Prediction Statistics:
# Component 0: mean=9.94e-04, std=5.24e-04
# Component 1: mean=-5.06e-07, std=1.11e-04
# Component 2: mean=1.03e-03, std=5.31e-04
# Component 3: mean=3.39e-06, std=1.13e-04
# Component 4: mean=-2.24e-05, std=1.17e-04
# Component 5: mean=1.01e-03, std=5.40e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 71/130, Loss: 2.066070
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 72/130, Loss: 1.953388
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 73/130, Loss: 1.978667
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 74/130, Loss: 2.016619
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 75/130, Loss: 1.933892
#
# Epoch 75 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.03e-04
# Component 1: 4.96e-05
# Component 2: 1.05e-04
# Component 3: 4.59e-05
# Component 4: 4.33e-05
# Component 5: 9.99e-05
# Mean Diffusivity Absolute Error: 2.79e-05
# FA Absolute Error: 5.38e-02
# Angular Error: 2.57e+01
#
# Prediction Statistics:
# Component 0: mean=9.94e-04, std=5.25e-04
# Component 1: mean=-5.43e-07, std=1.10e-04
# Component 2: mean=1.03e-03, std=5.33e-04
# Component 3: mean=3.42e-06, std=1.12e-04
# Component 4: mean=-2.24e-05, std=1.18e-04
# Component 5: mean=1.01e-03, std=5.42e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 76/130, Loss: 1.984078
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 77/130, Loss: 1.989232
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 78/130, Loss: 1.886221
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 79/130, Loss: 1.914685
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 80/130, Loss: 1.977392
#
# Epoch 80 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.02e-04
# Component 1: 4.80e-05
# Component 2: 1.05e-04
# Component 3: 4.61e-05
# Component 4: 4.63e-05
# Component 5: 1.02e-04
# Mean Diffusivity Absolute Error: 2.89e-05
# FA Absolute Error: 5.46e-02
# Angular Error: 2.57e+01
#
# Prediction Statistics:
# Component 0: mean=9.94e-04, std=5.24e-04
# Component 1: mean=-5.42e-07, std=1.10e-04
# Component 2: mean=1.03e-03, std=5.32e-04
# Component 3: mean=3.41e-06, std=1.12e-04
# Component 4: mean=-2.24e-05, std=1.17e-04
# Component 5: mean=1.01e-03, std=5.41e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 81/130, Loss: 1.870249
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 82/130, Loss: 1.910923
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 83/130, Loss: 1.946926
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 84/130, Loss: 1.860049
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 85/130, Loss: 1.889572
#
# Epoch 85 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.01e-04
# Component 1: 4.73e-05
# Component 2: 1.07e-04
# Component 3: 4.32e-05
# Component 4: 4.65e-05
# Component 5: 1.01e-04
# Mean Diffusivity Absolute Error: 2.86e-05
# FA Absolute Error: 5.40e-02
# Angular Error: 2.57e+01
#
# Prediction Statistics:
# Component 0: mean=9.94e-04, std=5.25e-04
# Component 1: mean=-5.15e-07, std=1.11e-04
# Component 2: mean=1.03e-03, std=5.33e-04
# Component 3: mean=3.39e-06, std=1.12e-04
# Component 4: mean=-2.24e-05, std=1.16e-04
# Component 5: mean=1.01e-03, std=5.42e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 86/130, Loss: 1.928808
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 87/130, Loss: 1.836587
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 88/130, Loss: 1.843581
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 89/130, Loss: 1.898175
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 90/130, Loss: 1.856141
#
# Epoch 90 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.02e-04
# Component 1: 4.82e-05
# Component 2: 1.05e-04
# Component 3: 4.48e-05
# Component 4: 4.26e-05
# Component 5: 9.88e-05
# Mean Diffusivity Absolute Error: 2.73e-05
# FA Absolute Error: 5.31e-02
# Angular Error: 2.55e+01
#
# Prediction Statistics:
# Component 0: mean=9.93e-04, std=5.25e-04
# Component 1: mean=-5.40e-07, std=1.10e-04
# Component 2: mean=1.03e-03, std=5.34e-04
# Component 3: mean=3.40e-06, std=1.11e-04
# Component 4: mean=-2.24e-05, std=1.18e-04
# Component 5: mean=1.01e-03, std=5.43e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 91/130, Loss: 1.911288
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 92/130, Loss: 1.877331
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 93/130, Loss: 1.793448
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 94/130, Loss: 1.840161
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 95/130, Loss: 1.888628
#
# Epoch 95 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.01e-04
# Component 1: 4.79e-05
# Component 2: 1.05e-04
# Component 3: 4.45e-05
# Component 4: 4.45e-05
# Component 5: 1.01e-04
# Mean Diffusivity Absolute Error: 2.77e-05
# FA Absolute Error: 5.38e-02
# Angular Error: 2.56e+01
#
# Prediction Statistics:
# Component 0: mean=9.93e-04, std=5.25e-04
# Component 1: mean=-5.26e-07, std=1.11e-04
# Component 2: mean=1.03e-03, std=5.33e-04
# Component 3: mean=3.39e-06, std=1.11e-04
# Component 4: mean=-2.24e-05, std=1.16e-04
# Component 5: mean=1.01e-03, std=5.42e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 96/130, Loss: 1.787357
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 97/130, Loss: 1.828550
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 98/130, Loss: 1.887175
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 99/130, Loss: 1.721771
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 100/130, Loss: 1.795726
#
# Epoch 100 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.01e-04
# Component 1: 4.55e-05
# Component 2: 1.07e-04
# Component 3: 4.27e-05
# Component 4: 4.49e-05
# Component 5: 1.00e-04
# Mean Diffusivity Absolute Error: 2.91e-05
# FA Absolute Error: 5.35e-02
# Angular Error: 2.54e+01
#
# Prediction Statistics:
# Component 0: mean=9.93e-04, std=5.26e-04
# Component 1: mean=-5.24e-07, std=1.10e-04
# Component 2: mean=1.03e-03, std=5.34e-04
# Component 3: mean=3.40e-06, std=1.12e-04
# Component 4: mean=-2.23e-05, std=1.16e-04
# Component 5: mean=1.01e-03, std=5.43e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 101/130, Loss: 1.863788
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 102/130, Loss: 1.733493
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 103/130, Loss: 1.785361
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 104/130, Loss: 1.813680
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 105/130, Loss: 1.771321
#
# Epoch 105 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.02e-04
# Component 1: 4.66e-05
# Component 2: 1.05e-04
# Component 3: 4.42e-05
# Component 4: 4.14e-05
# Component 5: 9.82e-05
# Mean Diffusivity Absolute Error: 2.74e-05
# FA Absolute Error: 5.27e-02
# Angular Error: 2.53e+01
#
# Prediction Statistics:
# Component 0: mean=9.93e-04, std=5.25e-04
# Component 1: mean=-5.22e-07, std=1.09e-04
# Component 2: mean=1.03e-03, std=5.34e-04
# Component 3: mean=3.40e-06, std=1.11e-04
# Component 4: mean=-2.24e-05, std=1.17e-04
# Component 5: mean=1.01e-03, std=5.43e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 106/130, Loss: 1.758004
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 107/130, Loss: 1.794625
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 108/130, Loss: 1.718292
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 109/130, Loss: 1.759107
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 110/130, Loss: 1.849230
#
# Epoch 110 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.01e-04
# Component 1: 4.72e-05
# Component 2: 1.04e-04
# Component 3: 4.42e-05
# Component 4: 4.43e-05
# Component 5: 1.00e-04
# Mean Diffusivity Absolute Error: 2.77e-05
# FA Absolute Error: 5.35e-02
# Angular Error: 2.54e+01
#
# Prediction Statistics:
# Component 0: mean=9.93e-04, std=5.26e-04
# Component 1: mean=-5.17e-07, std=1.10e-04
# Component 2: mean=1.03e-03, std=5.34e-04
# Component 3: mean=3.38e-06, std=1.11e-04
# Component 4: mean=-2.23e-05, std=1.16e-04
# Component 5: mean=1.01e-03, std=5.42e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 111/130, Loss: 1.696218
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 112/130, Loss: 1.729753
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 113/130, Loss: 1.783000
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 114/130, Loss: 1.696816
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 115/130, Loss: 1.755241
#
# Epoch 115 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.01e-04
# Component 1: 4.46e-05
# Component 2: 1.07e-04
# Component 3: 4.23e-05
# Component 4: 4.48e-05
# Component 5: 9.86e-05
# Mean Diffusivity Absolute Error: 2.92e-05
# FA Absolute Error: 5.31e-02
# Angular Error: 2.51e+01
#
# Prediction Statistics:
# Component 0: mean=9.94e-04, std=5.26e-04
# Component 1: mean=-5.29e-07, std=1.09e-04
# Component 2: mean=1.03e-03, std=5.34e-04
# Component 3: mean=3.36e-06, std=1.11e-04
# Component 4: mean=-2.24e-05, std=1.16e-04
# Component 5: mean=1.01e-03, std=5.43e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 116/130, Loss: 1.776716
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 117/130, Loss: 1.678847
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 118/130, Loss: 1.712633
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 119/130, Loss: 1.763470
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 120/130, Loss: 1.685751
#
# Epoch 120 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.00e-04
# Component 1: 4.63e-05
# Component 2: 1.06e-04
# Component 3: 4.24e-05
# Component 4: 3.98e-05
# Component 5: 9.55e-05
# Mean Diffusivity Absolute Error: 2.83e-05
# FA Absolute Error: 5.20e-02
# Angular Error: 2.47e+01
#
# Prediction Statistics:
# Component 0: mean=9.93e-04, std=5.26e-04
# Component 1: mean=-5.36e-07, std=1.09e-04
# Component 2: mean=1.03e-03, std=5.33e-04
# Component 3: mean=3.40e-06, std=1.10e-04
# Component 4: mean=-2.24e-05, std=1.17e-04
# Component 5: mean=1.01e-03, std=5.44e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 121/130, Loss: 1.700923
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 122/130, Loss: 1.761846
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 123/130, Loss: 1.679982
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 124/130, Loss: 1.723039
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 125/130, Loss: 1.725165
#
# Epoch 125 Statistics:
#
# Absolute Errors per component:
# Component 0: 9.99e-05
# Component 1: 4.53e-05
# Component 2: 1.05e-04
# Component 3: 4.25e-05
# Component 4: 4.28e-05
# Component 5: 9.48e-05
# Mean Diffusivity Absolute Error: 2.89e-05
# FA Absolute Error: 5.28e-02
# Angular Error: 2.45e+01
#
# Prediction Statistics:
# Component 0: mean=9.93e-04, std=5.26e-04
# Component 1: mean=-5.36e-07, std=1.09e-04
# Component 2: mean=1.03e-03, std=5.32e-04
# Component 3: mean=3.40e-06, std=1.10e-04
# Component 4: mean=-2.24e-05, std=1.15e-04
# Component 5: mean=1.01e-03, std=5.42e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 126/130, Loss: 1.674306
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 127/130, Loss: 1.664148
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 128/130, Loss: 1.746337
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 129/130, Loss: 1.649910
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 130/130, Loss: 1.701987
#
# Epoch 130 Statistics:
#
# Absolute Errors per component:
# Component 0: 9.74e-05
# Component 1: 4.43e-05
# Component 2: 1.07e-04
# Component 3: 4.20e-05
# Component 4: 4.35e-05
# Component 5: 8.83e-05
# Mean Diffusivity Absolute Error: 3.12e-05
# FA Absolute Error: 5.22e-02
# Angular Error: 2.33e+01
#
# Prediction Statistics:
# Component 0: mean=9.93e-04, std=5.27e-04
# Component 1: mean=-5.15e-07, std=1.09e-04
# Component 2: mean=1.03e-03, std=5.34e-04
# Component 3: mean=3.39e-06, std=1.11e-04
# Component 4: mean=-2.24e-05, std=1.15e-04
# Component 5: mean=1.01e-03, std=5.43e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.90e-04, std=5.51e-04
# Component 1: mean=-5.28e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.63e-04
# Component 3: mean=3.40e-06, std=1.15e-04
# Component 4: mean=-2.24e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.66e-04

# %%
plt.figure(figsize=(10, 6))
plt.semilogy(range(1, len(losses) + 1), losses)  # Using log scale for y-axis 
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.title('Training Loss Over Time')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.semilogy(range(20, len(losses) + 1), losses[19:])  # Using log scale for y-axis
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.title('Training Loss Over Time')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(60, len(losses) + 1), losses[59:])  # Using log scale for y-axis
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.title('Training Loss Over Time')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(90, len(losses) + 1), losses[89:])  # Using log scale for y-axis
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.title('Training Loss Over Time')
plt.grid(True)
plt.show()

# %%
# Plot FA error
plt.figure(figsize=(10, 6))
plt.plot([m['epoch'] for m in all_metrics if m['epoch'] >= 40], 
         [m['fa_error'] for m in all_metrics if m['epoch'] >= 40])
plt.xlabel('Epoch')
plt.ylabel('FA Error')
plt.title('FA Error Over Time')
plt.grid(True)
plt.show()

# Plot MD error
plt.figure(figsize=(10, 6))
plt.plot([m['epoch'] for m in all_metrics], [m['md_error'] for m in all_metrics])
plt.xlabel('Epoch')
plt.ylabel('MD Error')
plt.title('MD Error Over Time')
plt.grid(True)
plt.show()

# Ang error
plt.figure(figsize=(10, 6))
plt.plot([m['epoch'] for m in all_metrics if m['epoch'] >= 30], [m['angular_error'] for m in all_metrics if m['epoch'] >= 30])
plt.ylim(ymin=10)
plt.xlabel('Epoch')
plt.ylabel('Angular Error in degrees')
plt.title('Angular Error Over Time')
plt.grid(True)
plt.show()

# %%
print("\nStarting Final Evaluation...")
model.eval()
test_losses = []
test_preds = []
test_gts = []

with torch.no_grad():
    # Process all batches, including last partial batch
    for start in range(0, len(test_idx), batch_size):
        end = min(start + batch_size, len(test_idx))
        batch_indices = test_idx[start:end]
        
        # Create graph data using precomputed structures
        nodes, edges, edge_weights, tensors = create_batch_data(
            batch_indices,
            direction_structures_gpu[direction_set_idx],
            features_gpu,
            ground_truth_gpu
        )

        data_list = convert_to_torch_geometric(nodes, edges, edge_weights, tensors)
        batch_data = Batch.from_data_list(data_list).to(device)
        
        # Get predictions
        pred = model(batch_data.x, batch_data.edge_index, batch_data.edge_attr, batch_data.batch)
        
        # Calculate loss
        test_loss = model.weighted_mse_loss(pred, batch_data.y) * 1e6
        test_losses.append(test_loss.item())
        
        # Store predictions and ground truth
        test_preds.append(pred.cpu().numpy())
        test_gts.append(batch_data.y.cpu().numpy())

# Combine results
all_test_preds = np.concatenate(test_preds, axis=0)
all_test_gts = np.concatenate(test_gts, axis=0)
avg_test_loss = np.mean(test_losses)

print(f"\nFinal Test Results:")
print(f"Average test loss: {avg_test_loss:.6f}")

# Use same evaluation function as training
metrics = evaluate_model(all_test_preds, all_test_gts, epoch=-2)

with open('results.txt', 'a') as f:
    f.write(f"\nTest Results {datetime.datetime.now()}:\n")
    f.write(f"Epochs = {epochs}, voxels trained on = {n_samples}, Batch_size = {batch_size}, Learning Rate = {learning_rate}\n")  # whatever hyperparams you care about
    f.write(f"Test loss={avg_test_loss:.6f}\n")
    f.write(f"MD Abs err = {metrics["md_error"]}, FA Abs err = {metrics["fa_error"]}, Ang err = {metrics["angular_error"]}\n")
    f.write("-" * 60 + "\n")

# Print random examples from full test set
print("\nExample predictions vs ground truth (randomly sampled):")
n_examples = 5
rand_indices = np.random.choice(len(all_test_preds), n_examples, replace=False)
for i, idx in enumerate(rand_indices):
    print(f"\nSample {i+1}:")
    print(f"Predicted: {all_test_preds[idx]}")
    print(f"Actual:    {all_test_gts[idx]}")
# Out:
# <>:48: SyntaxWarning: invalid escape sequence '\,'
# <>:48: SyntaxWarning: invalid escape sequence '\,'
# C:\Users\ishui\AppData\Local\Temp\ipykernel_22124\2788675739.py:48: SyntaxWarning: invalid escape sequence '\,'
#   f.write(f"Epochs = {epochs}, voxels trained on = {n_samples}, Batch_size = {batch_size}\, Learning Rate = {learning_rate}n")  # whatever hyperparams you care about
# Starting Final Evaluation...
#
# Final Test Results:
# Average test loss: 1.513820
#
# Epoch -1 Statistics:
#
# Absolute Errors per component:
# Component 0: 9.59e-05
# Component 1: 4.16e-05
# Component 2: 1.06e-04
# Component 3: 4.25e-05
# Component 4: 3.93e-05
# Component 5: 8.82e-05
# Mean Diffusivity Absolute Error: 3.33e-05
# FA Absolute Error: 5.20e-02
# Angular Error: 2.28e+01
#
# Prediction Statistics:
# Component 0: mean=1.00e-03, std=5.35e-04
# Component 1: mean=2.49e-05, std=9.89e-05
# Component 2: mean=1.04e-03, std=5.41e-04
# Component 3: mean=3.35e-05, std=1.07e-04
# Component 4: mean=-4.62e-05, std=1.07e-04
# Component 5: mean=1.03e-03, std=5.48e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.88e-04, std=5.49e-04
# Component 1: mean=3.07e-07, std=1.17e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=2.81e-06, std=1.17e-04
# Component 4: mean=-2.30e-05, std=1.19e-04
# Component 5: mean=1.00e-03, std=5.65e-04
#
# Example predictions vs ground truth (randomly sampled):
#
# Sample 1:
# Predicted: [ 6.8463734e-04  8.9544919e-06  7.2806841e-04  1.7898798e-05
#  -4.9580587e-05  7.0696621e-04]
# Actual:    [ 8.14774066e-04 -3.73983973e-05  6.72387558e-04 -1.02619663e-05
#  -1.99785219e-05  6.55195081e-04]
#
# Sample 2:
# Predicted: [ 6.6030427e-04  3.5079429e-05  7.0244714e-04  9.0871647e-05
#  -9.9397381e-05  6.7818043e-04]
# Actual:    [ 6.48775909e-04  2.29231144e-05  7.00411458e-04  2.35725774e-05
#  -8.31697253e-05  6.15397703e-04]
#
# Sample 3:
# Predicted: [ 3.6243073e-04  8.5250940e-07  3.9101986e-04  2.2707449e-05
#  -3.6491663e-05  3.7229148e-04]
# Actual:    [ 2.50050903e-04  1.94663108e-05  2.56256509e-04 -1.57590548e-05
#  -7.59019311e-05  3.90669982e-04]
#
# Sample 4:
# Predicted: [ 1.1367194e-03  1.9218132e-05  1.1816353e-03  4.5910652e-05
#  -1.3133744e-05  1.1564724e-03]
# Actual:    [1.12969250e-03 5.53875621e-06 1.09674818e-03 3.27797487e-05
#  3.93214162e-05 1.14833422e-03]
#
# Sample 5:
# Predicted: [ 5.7564280e-04 -3.1108968e-05  6.0934707e-04 -1.0332093e-05
#   2.8555747e-05  5.8683252e-04]
# Actual:    [ 5.27056102e-04 -3.65735274e-05  5.70276189e-04 -2.60207752e-05
#   1.08306418e-05  5.95468448e-04]

# %%
# def count_parameters(model):
#     return sum(p.numel() for p in model.parameters() if p.requires_grad)

# total_params = count_parameters(model)
# print(f'Total trainable parameters: {total_params:,}')
