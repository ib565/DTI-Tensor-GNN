# %%
import numpy as np
import nibabel as nib
from dipy.io import read_bvals_bvecs
from dipy.core.gradients import gradient_table
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import MessagePassing
from torch_geometric.nn import global_mean_pool
import torch.optim as optim
from torch_geometric.data import Data, Batch
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import datetime

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
subject_id = "100206"
subject_path = f"diffusion_data/{subject_id}/T1w/Diffusion"
dwi_img = nib.load(f'{subject_path}/data.nii.gz')
mask_img = nib.load(f'{subject_path}/nodif_brain_mask.nii.gz')

# %%
dwi_data = dwi_img.get_fdata()
original_mask = mask_img.get_fdata() > 0

print(f"DWI data shape: {dwi_data.shape}")  # (X, Y, Z, num_volumes)
# Out:
# DWI data shape: (145, 174, 145, 288)

# %%
gt_data = np.load('ground_truth_v2.npz')
ground_truth_tensors = gt_data['tensors'] # shape 936256(all voxels) x 6
ground_truth_gpu = torch.from_numpy(ground_truth_tensors).to(device)

# %%
# store original indices before any voxel filtering 
original_idx = np.where(original_mask)

# %%
original_idx
# Out:
# (array([ 12,  12,  12, ..., 130, 130, 130], dtype=int64),
#  array([84, 84, 84, ..., 91, 91, 91], dtype=int64),
#  array([55, 56, 57, ..., 45, 46, 47], dtype=int64))

# %%
# Map (x,y,z) to original linear index
coord_to_gtt = {}
for i in range(len(original_idx[0])):
    x, y, z = original_idx[0][i], original_idx[1][i], original_idx[2][i]
    coord_to_gtt[(x,y,z)] = i  # i is the index in ground_truth_tensors

# %%
bvals, bvecs = read_bvals_bvecs(f'{subject_path}/bvals', 
                               f'{subject_path}/bvecs')
gtab = gradient_table(bvals, bvecs)

# get b0 data and b0_avg
b0_mask = gtab.b0s_mask
b0_data = dwi_data[..., b0_mask]
print(f"B0 data shape: {b0_data.shape}")
b0_avg = np.mean(b0_data, axis=-1)

# b1000 images mask
b1000_mask = (bvals >= 990) & (bvals <= 1010)
print(f"Number of b=1000 volumes: {np.sum(b1000_mask)}")

# Get all b1000 scans
dwi_vols = dwi_data[..., b1000_mask]
print(f"DWI volumes shape: {dwi_vols.shape}")
# Out:
# B0 data shape: (145, 174, 145, 18)
# Number of b=1000 volumes: 90
# DWI volumes shape: (145, 174, 145, 90)

# %%
# mask out voxels with very low b0 signal
b0_threshold = 250
valid_b0_mask = b0_avg > b0_threshold
mask = original_mask & valid_b0_mask  # Combine with brain mask

# %%
# Find valid voxels using the brain mask
valid_idx = np.where(mask) # shape: 3 x num_valid_voxels
print(f"\nNumber of valid voxels in mask: {len(valid_idx[0])}")
# Out:
# Number of valid voxels in mask: 926671

# %%
# Sample n random voxels for training
n_samples = 100000
sample_idx = np.random.choice(len(valid_idx[0]), 
                            min(n_samples, len(valid_idx[0])), 
                            replace=False)

# %%
# Extract features (signal intensities) from sampled voxels. 90 image signals per voxel
features = []
gtt_indices = [] # store ground truth tensor indices. gtt_indices[i] gives index of feature[i] in original number of voxels (93XXXX)

for idx in sample_idx:
    x, y, z = valid_idx[0][idx], valid_idx[1][idx], valid_idx[2][idx]
    signal = dwi_vols[x, y, z, :]
    b0_ref = b0_avg[x, y, z]
    normalized_signal = signal / (b0_ref)
    features.append(normalized_signal)
    gtt_indices.append(coord_to_gtt[(x, y, z)])

# gtt_indices shape = num_voxel_samples x 1
# features shape = num_voxel_samples x 90 x 1

# %%
features = np.array(features)
gtt_indices = np.array(gtt_indices)
features_gpu = torch.from_numpy(features).to(device)
gtt_indices_gpu = torch.from_numpy(gtt_indices).to(device)
gradient_directions = bvecs[b1000_mask]  # Only keep directions for DWI volumes, shape = 90 x 3

# %%
def select_diverse_directions(all_directions, n_select=21):
    """" Get n random directions with high coverage """
    
    selected = [0]  # Start with first direction
    while len(selected) < n_select:
        # Calculate angles with all selected directions
        angles = []
        for i in range(len(all_directions)):
            if i in selected:
                continue
            min_angle = float('inf')
            for s in selected:
                # Cosine similarity
                angle = np.arccos(np.clip(
                    np.dot(all_directions[i], all_directions[s]), -1.0, 1.0))
                min_angle = min(min_angle, angle)
            angles.append((i, min_angle))
        # Select direction with largest minimum angle
        next_idx = max(angles, key=lambda x: x[1])[0]
        selected.append(next_idx)
    return selected

# %%
def initialize_direction_sets(all_directions, n_sets=3, n_directions=21):
    """ Create sets of sparse directions """
    base_sets = []
    n_total = len(all_directions)
    
    for i in range(n_sets):
        # Create a shuffled index array for this set
        shuffled_indices = np.random.permutation(n_total)
        # Use select_diverse_directions on the shuffled indices
        selected = select_diverse_directions(all_directions[shuffled_indices], n_directions)
        # Map back to original indices
        original_indices = shuffled_indices[selected]
        base_sets.append(original_indices)
    
    return base_sets

# %%
class DiffusionGNN(torch.nn.Module):
    def __init__(self, node_features = 4, hidden_dim = 128):
        super(DiffusionGNN, self).__init__()
    
        # Layers
        self.conv1 = DiffusionConv(node_features, hidden_dim)
        self.conv2 = DiffusionConv(hidden_dim, hidden_dim)

        # MLP for tensor prediction
        self.mlp = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim),
            nn.SiLU(),
            nn.Linear(hidden_dim, hidden_dim),
            nn.SiLU(),
            nn.Linear(hidden_dim, 6),
        )

        self.register_buffer('loss_weights',
            torch.tensor([10, 100, 10, 100, 100, 10]))

    
    def forward(self, x, edge_index, edge_attr, batch):
        """
        x: node_features
        edge_index = graph conn info [2, num_edges]
        batch: batch assignment for nodes
        """
        # x shape = 672 (batch_size*num_directions) x 4
        x = self.conv1(x, edge_index, edge_attr)
        x = F.silu(x)
        x = self.conv2(x, edge_index, edge_attr)
        x = F.silu(x)
        # x shape = 672 x hidden_dim(64)

        # combine node features for graph
        x = global_mean_pool(x, batch)  # [batch_size, hidden_dim]. 1 representation for each voxel/graph

        # raw predictions
        out = self.mlp(x) # shape = 32 x 6

        diag_idx = [0, 2, 5]
        offdiag_idx = [1, 3, 4]

        # Diagonal elements: [0,1] using sigmoid
        diag = torch.sigmoid(out[:, diag_idx])
        
        # Off-diagonal elements: [-1,1] using tanh
        offdiag = torch.tanh(out[:, offdiag_idx])

        out_reordered = torch.zeros_like(out)
        out_reordered[:, diag_idx] = diag
        out_reordered[:, offdiag_idx] = offdiag

        return out_reordered # shape = 32 x 6
    
    def weighted_mse_loss(self, pred, target):
        squared_diff = (pred - target) ** 2  # [batch_size, 6]
        weighted_diff = squared_diff * self.loss_weights
        return torch.mean(weighted_diff)

    def weighted_mae_loss(self, pred, target):
        diff = torch.abs(pred - target)
        weighted_diff = diff * self.loss_weights
        return torch.mean(weighted_diff)

class DiffusionConv(MessagePassing):
    def __init__(self, in_channels, out_channels):
        super(DiffusionConv, self).__init__(aggr="mean")
        
        # MLP to process messages
        self.mlp = nn.Sequential(
            nn.Linear(2 * in_channels, out_channels),
            nn.SiLU(),
            nn.Linear(out_channels, out_channels)
        )
    
    def forward(self, x, edge_index, edge_weight):
        return self.propagate(edge_index, x=x, edge_weight = edge_weight)
    
    def message(self, x_i, x_j, edge_weight):
        """
        x_i: features of target nodes
        x_j: features of source nodes
        Returns: messages to be aggregated
        """
        tmp = torch.cat([x_i, x_j], dim = 1)
        return self.mlp(tmp) * edge_weight.view(-1,1)

# %%
def convert_to_torch_geometric(nodes, edges, edge_weights, tensors):
    """ convert graph to geometric object"""
    data_list = []
    device = nodes.device
    
    for i in range(len(nodes)):
        tensor = tensors[i].reshape(-1, 6) if len(tensors[i].shape) == 1 else tensors[i]
        data = Data(
            x=nodes[i],
            edge_index = edges[i].clone().detach().to(dtype=torch.long, device=device).T,
            edge_attr=edge_weights[i].clone().detach().to(dtype=torch.float, device=device),
            y=tensor
        )
        data_list.append(data)
    
    return data_list

# %%
train_idx, test_idx = train_test_split(np.arange(len(features)), test_size=0.2, random_state=42)
print(f"Training with {len(train_idx)} voxels, testing with {len(test_idx)} voxels")
# Out:
# Training with 80000 voxels, testing with 20000 voxels

# %%
def calculate_MD(tensor):
    """Calculate Mean Diffusivity: (Dxx + Dyy + Dzz)/3"""
    return np.mean(tensor[:,[0,2,5]], axis=1)

def calculate_FA_approx(tensor):
    """Calculate Fractional Anisotropy using characteristic equation approximation"""

    Dxx, Dxy, Dyy, Dxz, Dyz, Dzz = [tensor[:,i] for i in range(6)]
    md = calculate_MD(tensor)
    
    var_terms = ((Dxx - md)**2 + (Dyy - md)**2 + (Dzz - md)**2 + 6 * (Dxy**2 + Dxz**2 + Dyz**2)) / 3
    tensor_norm = Dxx**2 + Dyy**2 + Dzz**2 + 2*(Dxy**2 + Dxz**2 + Dyz**2)

    fa = np.sqrt(3 * var_terms / (2 * (tensor_norm + 1e-10)))
    return fa

def principal_eigenvector_angle_error(pred, gt, fa_threshold=0.2):
    """
    Compute angle between principal eigenvectors for a batch of tensors.
    Args:
        pred: predictions array (n_samples x 6)
        gt: ground truth array (n_samples x 6)
        fa_threshold: minimum FA value to consider (default 0.2)
    Returns:
        angles: array of angle errors in degrees for samples above FA threshold
        mask: boolean array indicating which samples were used
    """
    # Calculate FA using existing function
    fa = calculate_FA_approx(gt)
    
    # Create mask for high FA voxels
    # [NEW] Create mask instead of single threshold
    mask = fa > fa_threshold
    
    # [NEW] Early return if no valid voxels
    if not np.any(mask):
        return np.array([]), mask
    
    # [NEW] Filter tensors based on mask
    pred_valid = pred[mask]
    gt_valid = gt[mask]
    
    # [NEW] Preallocate arrays for batch processing
    n_valid = np.sum(mask)
    angles = np.zeros(n_valid)
    
    # [NEW] Reshape tensors for batch processing
    pred_matrices = np.zeros((n_valid, 3, 3))
    gt_matrices = np.zeros((n_valid, 3, 3))
    
    # Construct matrices for all valid tensors
    pred_matrices[:, 0, 0] = pred_valid[:, 0]  # Dxx
    pred_matrices[:, 0, 1] = pred_matrices[:, 1, 0] = pred_valid[:, 1]  # Dxy
    pred_matrices[:, 1, 1] = pred_valid[:, 2]  # Dyy
    pred_matrices[:, 0, 2] = pred_matrices[:, 2, 0] = pred_valid[:, 3]  # Dxz
    pred_matrices[:, 1, 2] = pred_matrices[:, 2, 1] = pred_valid[:, 4]  # Dyz
    pred_matrices[:, 2, 2] = pred_valid[:, 5]  # Dzz
    
    gt_matrices[:, 0, 0] = gt_valid[:, 0]
    gt_matrices[:, 0, 1] = gt_matrices[:, 1, 0] = gt_valid[:, 1]
    gt_matrices[:, 1, 1] = gt_valid[:, 2]
    gt_matrices[:, 0, 2] = gt_matrices[:, 2, 0] = gt_valid[:, 3]
    gt_matrices[:, 1, 2] = gt_matrices[:, 2, 1] = gt_valid[:, 4]
    gt_matrices[:, 2, 2] = gt_valid[:, 5]
    
    # [NEW] Vectorized eigenvalue computation
    for i in range(n_valid):
        pred_evals, pred_evecs = np.linalg.eigh(pred_matrices[i])
        gt_evals, gt_evecs = np.linalg.eigh(gt_matrices[i])
        
        v1_pred = pred_evecs[:, np.argmax(pred_evals)]
        v1_gt = gt_evecs[:, np.argmax(gt_evals)]
        
        cos_theta = np.abs(np.dot(v1_pred, v1_gt))
        cos_theta = np.clip(cos_theta, -1.0, 1.0)
        angles[i] = np.degrees(np.arccos(cos_theta))
    
    return angles, mask

# %%
def evaluate_model(pred, gt, epoch, print_results=True):
    """
    Compute and optionally print evaluation metrics
    Args:
        pred: predictions array (n_samples x 6)
        gt: ground truth array (n_samples x 6)
        epoch: current epoch number
        print_results: whether to print metrics
    Returns:
        Dictionary of metrics
    """
    metrics = {}
    metrics['epoch'] = epoch
    
    # Component-wise statistics and relative errors
    for i in range(6):
        # Relative error
        rel_error = np.mean(np.abs(pred[:,i] - gt[:,i]) / (np.abs(gt[:,i]) + 1e-10))
        metrics[f'rel_error_{i}'] = rel_error
        
        # Abs error
        abs_error = np.mean(np.abs(pred[:,i] - gt[:, i]))
        metrics[f'abs_error_{i}'] = abs_error

        # Statistics for monitoring distribution
        metrics[f'pred_mean_{i}'] = np.mean(pred[:,i])
        metrics[f'pred_std_{i}'] = np.std(pred[:,i])
        metrics[f'gt_mean_{i}'] = np.mean(gt[:,i])
        metrics[f'gt_std_{i}'] = np.std(gt[:,i])
    
    # Mean Diffusivity error
    pred_md = calculate_MD(pred)
    gt_md = calculate_MD(gt)
    metrics['md_error'] = np.mean(np.abs(pred_md - gt_md))

    # FA absolute error
    pred_fa = calculate_FA_approx(pred)
    gt_fa = calculate_FA_approx(gt)
    metrics['fa_error'] = np.mean(np.abs(pred_fa - gt_fa))

    angles, mask = principal_eigenvector_angle_error(pred, gt, 0.0)

    metrics['angular_error'] = np.mean(angles)

    if print_results:
        print(f"\nEpoch {epoch+1} Statistics:")
        # print("\nRelative Errors per component:")
        # for i in range(6):
        #     print(f"Component {i}: {metrics[f'rel_error_{i}']:.2e}")
        print("\nAbsolute Errors per component:")
        for i in range(6):
            print(f"Component {i}: {metrics[f'abs_error_{i}']:.2e}")
        print(f"Mean Diffusivity Absolute Error: {metrics['md_error']:.2e}")
        print(f"FA Absolute Error: {metrics['fa_error']:.2e}")
        print(f"Angular Error: {metrics['angular_error']}")
        
        print("\nPrediction Statistics:")
        for i in range(6):
            print(f"Component {i}: mean={metrics[f'pred_mean_{i}']:.2e}, std={metrics[f'pred_std_{i}']:.2e}")
        
        print("\nGround Truth Statistics:")
        for i in range(6):
            print(f"Component {i}: mean={metrics[f'gt_mean_{i}']:.2e}, std={metrics[f'gt_std_{i}']:.2e}")
    
    return metrics

# %%
def precompute_direction_structures(direction_indices, threshold_angle=60):
    """
    Precompute direction-based graph structures that remain constant across batches.
    """
    current_directions = gradient_directions[direction_indices]  # Shape (21, 3)
    directions_norm = current_directions / np.linalg.norm(current_directions, axis=1, keepdims=True)
    
    cos_sim = np.dot(directions_norm, directions_norm.T)
    angles = np.arccos(np.clip(cos_sim, -1.0, 1.0)) * 180/np.pi
    src, dst = np.where(angles < threshold_angle)
    mask = src != dst
    
    return {
        'edge_template': np.column_stack([src[mask], dst[mask]]),
        'edge_weights': cos_sim[src[mask], dst[mask]],
        'directions': current_directions,
        'direction_indices': direction_indices
    }


def create_batch_data(batch_indices, direction_structures, features_gpu, ground_truth_gpu):
    """
    Create graph data for a batch using GPU tensors.
    
    Args:
        batch_indices: array of indices for this batch, shape (batch_size,)
        direction_structures: dict of precomputed direction structures
        features_gpu: GPU tensor of all features, shape (n_samples, 90)
        ground_truth_gpu: GPU tensor of ground truth, shape (n_samples, 6)
    
    Returns:
        batch_nodes: [batch_size, n_directions, 4] node features (GPU)
        batch_edges: list of [E, 2] edge indices for each graph
        batch_edge_weights: list of [E] edge weights for each graph
        batch_tensors: [batch_size, 6] ground truth tensors (GPU)
    """
    n_directions = direction_structures['directions'].shape[0]  # Should be 21
    
    # Convert batch_indices to GPU tensor if not already
    if not isinstance(batch_indices, torch.Tensor):
        batch_indices = torch.tensor(batch_indices, device=features_gpu.device)
    
    # Get batch of signals and select directions
    # features_gpu shape: (n_samples, 90)
    # batch_features shape: (batch_size, 90)
    batch_features = features_gpu[batch_indices]
    
    # Select specific directions
    # direction_indices shape: (21,)
    
    direction_indices = torch.tensor(direction_structures['direction_indices'], 
                               device=features_gpu.device)
    
    # batch_signals shape: (batch_size, 21)
    batch_signals = batch_features[:, direction_indices]
    
    # Create node features on GPU
    # batch_nodes shape: (batch_size, n_directions, 4)
    batch_nodes = torch.zeros((batch_indices.shape[0], n_directions, 4), 
                            device=features_gpu.device)
    batch_nodes[..., 0] = batch_signals
    batch_nodes[..., 1:4] = direction_structures['directions'].unsqueeze(0)
    
    # Edge structures (already on GPU from direction_structures_gpu)
    batch_edges = [direction_structures['edge_template'] 
                  for _ in range(batch_indices.shape[0])]
    batch_edge_weights = [direction_structures['edge_weights'] 
                         for _ in range(batch_indices.shape[0])]
    
    # Get ground truth tensors directly from GPU tensor
    # gtt_indices maps from batch_indices to ground truth indices
    # batch_tensors shape: (batch_size, 6)
    batch_tensors = ground_truth_gpu[gtt_indices_gpu[batch_indices]]

    return batch_nodes, batch_edges, batch_edge_weights, batch_tensors

# %%
n_sets = 3
direction_sets = initialize_direction_sets(gradient_directions, n_sets)
direction_structures = {}
for set_idx, direction_set in enumerate(direction_sets):
    direction_structures[set_idx] = precompute_direction_structures(direction_set)
batch_size = 32
learning_rate = 0.0005

# %%
# Convert direction structures once
direction_structures_gpu = {}
for idx, struct in direction_structures.items():
    direction_structures_gpu[idx] = {
        'edge_template': torch.from_numpy(struct['edge_template']).to(device),
        'edge_weights': torch.from_numpy(struct['edge_weights']).to(device),
        'directions': torch.from_numpy(struct['directions']).to(device),
        'direction_indices': struct['direction_indices']
    }

# %%
# Training
model = DiffusionGNN(hidden_dim=128).to(device)
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

epochs = 200
losses = []
all_metrics = []
print("Starting training...")
for epoch in range(epochs):
    # Select direction set for this epoch
    direction_set_idx = epoch % len(direction_sets)
    current_structures = direction_structures_gpu[direction_set_idx]
    model.train()
    epoch_loss = 0
    n_batches = 0
    
    # Store epoch predictions and ground truth
    epoch_pred_values = []
    epoch_gt_values = []
    
    # Shuffle training indices
    np.random.shuffle(train_idx)
    
    # Process batches
    for start in range(0, len(train_idx), batch_size):
        batch_indices = train_idx[start:start + batch_size]
        
        # Create graph data using precomputed structures
        nodes, edges, edge_weights, tensors = create_batch_data(
            batch_indices,
            current_structures,
            features_gpu,
            ground_truth_gpu
        )

        data_list = convert_to_torch_geometric(nodes, edges, edge_weights, tensors)
        batch_data = Batch.from_data_list(data_list).to(device)
        
        # Training step
        optimizer.zero_grad()
        pred = model(batch_data.x, batch_data.edge_index, batch_data.edge_attr, batch_data.batch)
        # loss = model.weighted_mse_loss(pred, batch_data.y) * 1e6
        loss = model.weighted_mae_loss(pred, batch_data.y) * 1e5
        loss.backward()
        optimizer.step()
        
        # Store batch results
        epoch_loss += loss.item()
        epoch_pred_values.append(pred.detach().cpu().numpy())
        epoch_gt_values.append(batch_data.y.cpu().numpy())
        n_batches += 1
    
    # Combine all batches
    epoch_pred = np.concatenate(epoch_pred_values, axis=0)
    epoch_gt = np.concatenate(epoch_gt_values, axis=0)
    
    # Print epoch results
    avg_loss = epoch_loss / n_batches
    losses.append(avg_loss)
    print("\nxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx")
    print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.6f}")
    
    # Evaluate epoch performance
    if (epoch + 1) % 5 == 0:
        metrics = evaluate_model(epoch_pred, epoch_gt, epoch)
        all_metrics.append(metrics)
# Out:
# Starting training...
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 1/200, Loss: 33543.600432
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 2/200, Loss: 6097.380837
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 3/200, Loss: 3689.737258
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 4/200, Loss: 2305.725453
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 5/200, Loss: 1534.551658
#
# Epoch 5 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.10e-04
# Component 1: 2.73e-04
# Component 2: 1.12e-04
# Component 3: 2.99e-04
# Component 4: 3.15e-04
# Component 5: 1.16e-04
# Mean Diffusivity Absolute Error: 4.42e-05
# FA Absolute Error: 3.35e-01
# Angular Error: 57.063872609178105
#
# Prediction Statistics:
# Component 0: mean=1.01e-03, std=5.12e-04
# Component 1: mean=-2.64e-06, std=3.24e-04
# Component 2: mean=1.04e-03, std=5.28e-04
# Component 3: mean=4.76e-06, std=3.53e-04
# Component 4: mean=-2.49e-05, std=3.88e-04
# Component 5: mean=1.02e-03, std=5.25e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 6/200, Loss: 1309.345433
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 7/200, Loss: 1197.848802
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 8/200, Loss: 1038.249570
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 9/200, Loss: 1050.232451
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 10/200, Loss: 922.348783
#
# Epoch 10 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.05e-04
# Component 1: 1.67e-04
# Component 2: 1.13e-04
# Component 3: 1.89e-04
# Component 4: 1.65e-04
# Component 5: 1.09e-04
# Mean Diffusivity Absolute Error: 4.02e-05
# FA Absolute Error: 1.84e-01
# Angular Error: 55.28480455033441
#
# Prediction Statistics:
# Component 0: mean=9.85e-04, std=5.21e-04
# Component 1: mean=-1.24e-06, std=1.87e-04
# Component 2: mean=1.02e-03, std=5.25e-04
# Component 3: mean=1.63e-06, std=2.28e-04
# Component 4: mean=-2.23e-05, std=1.75e-04
# Component 5: mean=9.97e-04, std=5.37e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 11/200, Loss: 998.918279
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 12/200, Loss: 961.106149
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 13/200, Loss: 976.073024
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 14/200, Loss: 891.973594
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 15/200, Loss: 881.438286
#
# Epoch 15 Statistics:
#
# Absolute Errors per component:
# Component 0: 1.10e-04
# Component 1: 1.43e-04
# Component 2: 1.05e-04
# Component 3: 1.71e-04
# Component 4: 1.83e-04
# Component 5: 1.01e-04
# Mean Diffusivity Absolute Error: 3.54e-05
# FA Absolute Error: 1.95e-01
# Angular Error: 50.390159998999756
#
# Prediction Statistics:
# Component 0: mean=9.84e-04, std=5.24e-04
# Component 1: mean=-1.39e-06, std=1.81e-04
# Component 2: mean=1.02e-03, std=5.30e-04
# Component 3: mean=3.44e-06, std=2.26e-04
# Component 4: mean=-2.30e-05, std=2.37e-04
# Component 5: mean=9.98e-04, std=5.41e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 16/200, Loss: 869.265954
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 17/200, Loss: 781.860795
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 18/200, Loss: 780.411229
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 19/200, Loss: 781.791362
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 20/200, Loss: 721.505882
#
# Epoch 20 Statistics:
#
# Absolute Errors per component:
# Component 0: 9.80e-05
# Component 1: 1.42e-04
# Component 2: 1.01e-04
# Component 3: 1.27e-04
# Component 4: 1.34e-04
# Component 5: 1.03e-04
# Mean Diffusivity Absolute Error: 3.08e-05
# FA Absolute Error: 1.52e-01
# Angular Error: 47.247248080728355
#
# Prediction Statistics:
# Component 0: mean=9.86e-04, std=5.27e-04
# Component 1: mean=1.02e-06, std=1.87e-04
# Component 2: mean=1.02e-03, std=5.32e-04
# Component 3: mean=3.95e-06, std=1.74e-04
# Component 4: mean=-2.41e-05, std=1.82e-04
# Component 5: mean=9.96e-04, std=5.43e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 21/200, Loss: 687.778411
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 22/200, Loss: 651.434501
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 23/200, Loss: 686.335972
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 24/200, Loss: 654.085028
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 25/200, Loss: 621.879393
#
# Epoch 25 Statistics:
#
# Absolute Errors per component:
# Component 0: 5.50e-05
# Component 1: 1.15e-04
# Component 2: 6.12e-05
# Component 3: 1.19e-04
# Component 4: 1.19e-04
# Component 5: 8.53e-05
# Mean Diffusivity Absolute Error: 3.07e-05
# FA Absolute Error: 1.31e-01
# Angular Error: 39.36217752503701
#
# Prediction Statistics:
# Component 0: mean=9.91e-04, std=5.35e-04
# Component 1: mean=1.20e-07, std=1.60e-04
# Component 2: mean=1.03e-03, std=5.37e-04
# Component 3: mean=4.45e-06, std=1.69e-04
# Component 4: mean=-2.50e-05, std=1.74e-04
# Component 5: mean=1.00e-03, std=5.42e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 26/200, Loss: 594.394695
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 27/200, Loss: 568.155227
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 28/200, Loss: 575.226957
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 29/200, Loss: 553.694974
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 30/200, Loss: 557.550439
#
# Epoch 30 Statistics:
#
# Absolute Errors per component:
# Component 0: 6.16e-05
# Component 1: 1.07e-04
# Component 2: 5.19e-05
# Component 3: 1.02e-04
# Component 4: 1.09e-04
# Component 5: 5.51e-05
# Mean Diffusivity Absolute Error: 2.99e-05
# FA Absolute Error: 1.17e-01
# Angular Error: 35.68224995297142
#
# Prediction Statistics:
# Component 0: mean=9.91e-04, std=5.33e-04
# Component 1: mean=-7.84e-07, std=1.53e-04
# Component 2: mean=1.03e-03, std=5.41e-04
# Component 3: mean=2.74e-06, std=1.52e-04
# Component 4: mean=-2.30e-05, std=1.69e-04
# Component 5: mean=1.01e-03, std=5.51e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 31/200, Loss: 531.838652
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 32/200, Loss: 530.891974
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 33/200, Loss: 519.684610
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 34/200, Loss: 504.612657
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 35/200, Loss: 490.530144
#
# Epoch 35 Statistics:
#
# Absolute Errors per component:
# Component 0: 5.63e-05
# Component 1: 9.61e-05
# Component 2: 4.70e-05
# Component 3: 9.42e-05
# Component 4: 8.85e-05
# Component 5: 5.15e-05
# Mean Diffusivity Absolute Error: 2.87e-05
# FA Absolute Error: 9.86e-02
# Angular Error: 33.07209007866349
#
# Prediction Statistics:
# Component 0: mean=9.91e-04, std=5.32e-04
# Component 1: mean=-4.83e-07, std=1.45e-04
# Component 2: mean=1.03e-03, std=5.43e-04
# Component 3: mean=2.61e-06, std=1.43e-04
# Component 4: mean=-2.33e-05, std=1.46e-04
# Component 5: mean=1.00e-03, std=5.50e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 36/200, Loss: 488.868444
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 37/200, Loss: 456.922140
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 38/200, Loss: 452.894160
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 39/200, Loss: 450.624213
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 40/200, Loss: 465.349856
#
# Epoch 40 Statistics:
#
# Absolute Errors per component:
# Component 0: 5.05e-05
# Component 1: 8.88e-05
# Component 2: 4.98e-05
# Component 3: 8.53e-05
# Component 4: 8.97e-05
# Component 5: 5.31e-05
# Mean Diffusivity Absolute Error: 2.84e-05
# FA Absolute Error: 9.37e-02
# Angular Error: 32.14072646946864
#
# Prediction Statistics:
# Component 0: mean=9.90e-04, std=5.36e-04
# Component 1: mean=-9.16e-07, std=1.40e-04
# Component 2: mean=1.03e-03, std=5.44e-04
# Component 3: mean=1.39e-06, std=1.38e-04
# Component 4: mean=-2.35e-05, std=1.49e-04
# Component 5: mean=1.01e-03, std=5.51e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 41/200, Loss: 477.612807
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 42/200, Loss: 433.416962
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 43/200, Loss: 453.114829
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 44/200, Loss: 429.111905
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 45/200, Loss: 423.951772
#
# Epoch 45 Statistics:
#
# Absolute Errors per component:
# Component 0: 5.92e-05
# Component 1: 8.29e-05
# Component 2: 4.86e-05
# Component 3: 7.98e-05
# Component 4: 7.57e-05
# Component 5: 5.16e-05
# Mean Diffusivity Absolute Error: 2.90e-05
# FA Absolute Error: 8.19e-02
# Angular Error: 30.773265585321887
#
# Prediction Statistics:
# Component 0: mean=9.91e-04, std=5.33e-04
# Component 1: mean=-2.44e-07, std=1.32e-04
# Component 2: mean=1.03e-03, std=5.43e-04
# Component 3: mean=2.84e-06, std=1.33e-04
# Component 4: mean=-2.30e-05, std=1.39e-04
# Component 5: mean=1.00e-03, std=5.51e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 46/200, Loss: 417.825374
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 47/200, Loss: 426.117785
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 48/200, Loss: 417.632642
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 49/200, Loss: 432.817135
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 50/200, Loss: 406.094355
#
# Epoch 50 Statistics:
#
# Absolute Errors per component:
# Component 0: 5.53e-05
# Component 1: 7.97e-05
# Component 2: 4.53e-05
# Component 3: 7.61e-05
# Component 4: 7.28e-05
# Component 5: 5.02e-05
# Mean Diffusivity Absolute Error: 2.88e-05
# FA Absolute Error: 7.78e-02
# Angular Error: 29.980215307323657
#
# Prediction Statistics:
# Component 0: mean=9.91e-04, std=5.34e-04
# Component 1: mean=-7.79e-07, std=1.33e-04
# Component 2: mean=1.03e-03, std=5.45e-04
# Component 3: mean=2.36e-06, std=1.29e-04
# Component 4: mean=-2.38e-05, std=1.33e-04
# Component 5: mean=1.00e-03, std=5.50e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 51/200, Loss: 423.078651
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 52/200, Loss: 386.395223
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 53/200, Loss: 404.025976
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 54/200, Loss: 394.787697
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 55/200, Loss: 388.255526
#
# Epoch 55 Statistics:
#
# Absolute Errors per component:
# Component 0: 4.95e-05
# Component 1: 7.25e-05
# Component 2: 4.80e-05
# Component 3: 7.24e-05
# Component 4: 7.31e-05
# Component 5: 5.14e-05
# Mean Diffusivity Absolute Error: 2.77e-05
# FA Absolute Error: 7.37e-02
# Angular Error: 29.3935244006203
#
# Prediction Statistics:
# Component 0: mean=9.90e-04, std=5.37e-04
# Component 1: mean=-5.43e-07, std=1.25e-04
# Component 2: mean=1.03e-03, std=5.45e-04
# Component 3: mean=2.86e-06, std=1.26e-04
# Component 4: mean=-2.39e-05, std=1.35e-04
# Component 5: mean=1.00e-03, std=5.52e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 56/200, Loss: 399.838374
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 57/200, Loss: 381.098946
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 58/200, Loss: 379.090407
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 59/200, Loss: 383.482399
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 60/200, Loss: 375.180195
#
# Epoch 60 Statistics:
#
# Absolute Errors per component:
# Component 0: 5.82e-05
# Component 1: 7.19e-05
# Component 2: 4.72e-05
# Component 3: 6.79e-05
# Component 4: 6.98e-05
# Component 5: 5.04e-05
# Mean Diffusivity Absolute Error: 2.90e-05
# FA Absolute Error: 7.07e-02
# Angular Error: 28.590218779198562
#
# Prediction Statistics:
# Component 0: mean=9.91e-04, std=5.35e-04
# Component 1: mean=-4.86e-07, std=1.23e-04
# Component 2: mean=1.03e-03, std=5.45e-04
# Component 3: mean=3.13e-06, std=1.24e-04
# Component 4: mean=-2.30e-05, std=1.35e-04
# Component 5: mean=1.00e-03, std=5.53e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 61/200, Loss: 358.878016
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 62/200, Loss: 377.299661
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 63/200, Loss: 366.345528
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 64/200, Loss: 363.285978
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 65/200, Loss: 373.841673
#
# Epoch 65 Statistics:
#
# Absolute Errors per component:
# Component 0: 5.42e-05
# Component 1: 6.71e-05
# Component 2: 4.43e-05
# Component 3: 7.12e-05
# Component 4: 7.12e-05
# Component 5: 4.87e-05
# Mean Diffusivity Absolute Error: 2.83e-05
# FA Absolute Error: 7.03e-02
# Angular Error: 28.533801432524807
#
# Prediction Statistics:
# Component 0: mean=9.90e-04, std=5.37e-04
# Component 1: mean=-4.10e-08, std=1.23e-04
# Component 2: mean=1.03e-03, std=5.46e-04
# Component 3: mean=2.81e-06, std=1.27e-04
# Component 4: mean=-2.36e-05, std=1.32e-04
# Component 5: mean=1.00e-03, std=5.52e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 66/200, Loss: 354.537723
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 67/200, Loss: 351.602476
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 68/200, Loss: 356.491043
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 69/200, Loss: 368.018038
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 70/200, Loss: 351.414105
#
# Epoch 70 Statistics:
#
# Absolute Errors per component:
# Component 0: 4.92e-05
# Component 1: 6.74e-05
# Component 2: 4.76e-05
# Component 3: 6.46e-05
# Component 4: 6.42e-05
# Component 5: 5.05e-05
# Mean Diffusivity Absolute Error: 2.81e-05
# FA Absolute Error: 6.52e-02
# Angular Error: 27.880227503216446
#
# Prediction Statistics:
# Component 0: mean=9.90e-04, std=5.39e-04
# Component 1: mean=-8.80e-07, std=1.22e-04
# Component 2: mean=1.03e-03, std=5.46e-04
# Component 3: mean=3.02e-06, std=1.22e-04
# Component 4: mean=-2.34e-05, std=1.29e-04
# Component 5: mean=1.00e-03, std=5.52e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 71/200, Loss: 344.424358
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 72/200, Loss: 351.635948
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 73/200, Loss: 346.335185
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 74/200, Loss: 342.388429
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 75/200, Loss: 344.196157
#
# Epoch 75 Statistics:
#
# Absolute Errors per component:
# Component 0: 5.68e-05
# Component 1: 6.59e-05
# Component 2: 4.61e-05
# Component 3: 6.36e-05
# Component 4: 6.19e-05
# Component 5: 4.88e-05
# Mean Diffusivity Absolute Error: 2.81e-05
# FA Absolute Error: 6.31e-02
# Angular Error: 27.71824148971483
#
# Prediction Statistics:
# Component 0: mean=9.91e-04, std=5.37e-04
# Component 1: mean=-7.14e-07, std=1.20e-04
# Component 2: mean=1.03e-03, std=5.47e-04
# Component 3: mean=2.76e-06, std=1.22e-04
# Component 4: mean=-2.31e-05, std=1.29e-04
# Component 5: mean=1.00e-03, std=5.54e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 76/200, Loss: 336.768086
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 77/200, Loss: 345.651489
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 78/200, Loss: 349.958239
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 79/200, Loss: 337.805107
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 80/200, Loss: 331.167401
#
# Epoch 80 Statistics:
#
# Absolute Errors per component:
# Component 0: 5.27e-05
# Component 1: 6.17e-05
# Component 2: 4.29e-05
# Component 3: 6.20e-05
# Component 4: 6.06e-05
# Component 5: 4.74e-05
# Mean Diffusivity Absolute Error: 2.74e-05
# FA Absolute Error: 6.01e-02
# Angular Error: 26.75196436573767
#
# Prediction Statistics:
# Component 0: mean=9.90e-04, std=5.38e-04
# Component 1: mean=-8.27e-07, std=1.20e-04
# Component 2: mean=1.03e-03, std=5.47e-04
# Component 3: mean=2.87e-06, std=1.19e-04
# Component 4: mean=-2.38e-05, std=1.24e-04
# Component 5: mean=1.00e-03, std=5.53e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 81/200, Loss: 331.544300
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 82/200, Loss: 324.995937
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 83/200, Loss: 329.218306
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 84/200, Loss: 328.767370
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 85/200, Loss: 329.110351
#
# Epoch 85 Statistics:
#
# Absolute Errors per component:
# Component 0: 4.85e-05
# Component 1: 6.28e-05
# Component 2: 4.66e-05
# Component 3: 6.14e-05
# Component 4: 5.88e-05
# Component 5: 4.93e-05
# Mean Diffusivity Absolute Error: 2.77e-05
# FA Absolute Error: 6.00e-02
# Angular Error: 26.953066185302525
#
# Prediction Statistics:
# Component 0: mean=9.90e-04, std=5.40e-04
# Component 1: mean=-7.52e-07, std=1.19e-04
# Component 2: mean=1.03e-03, std=5.47e-04
# Component 3: mean=2.87e-06, std=1.21e-04
# Component 4: mean=-2.31e-05, std=1.26e-04
# Component 5: mean=1.00e-03, std=5.53e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 86/200, Loss: 328.844340
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 87/200, Loss: 329.629977
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 88/200, Loss: 326.712644
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 89/200, Loss: 328.094142
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 90/200, Loss: 322.123261
#
# Epoch 90 Statistics:
#
# Absolute Errors per component:
# Component 0: 5.57e-05
# Component 1: 6.42e-05
# Component 2: 4.50e-05
# Component 3: 5.88e-05
# Component 4: 5.55e-05
# Component 5: 4.78e-05
# Mean Diffusivity Absolute Error: 2.78e-05
# FA Absolute Error: 5.80e-02
# Angular Error: 26.771823918104825
#
# Prediction Statistics:
# Component 0: mean=9.90e-04, std=5.39e-04
# Component 1: mean=-3.77e-07, std=1.19e-04
# Component 2: mean=1.03e-03, std=5.48e-04
# Component 3: mean=3.26e-06, std=1.19e-04
# Component 4: mean=-2.32e-05, std=1.26e-04
# Component 5: mean=1.00e-03, std=5.55e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 91/200, Loss: 311.019500
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 92/200, Loss: 318.207895
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 93/200, Loss: 315.214609
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 94/200, Loss: 322.774542
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 95/200, Loss: 307.808303
#
# Epoch 95 Statistics:
#
# Absolute Errors per component:
# Component 0: 5.17e-05
# Component 1: 5.58e-05
# Component 2: 4.24e-05
# Component 3: 5.87e-05
# Component 4: 5.61e-05
# Component 5: 4.68e-05
# Mean Diffusivity Absolute Error: 2.69e-05
# FA Absolute Error: 5.50e-02
# Angular Error: 25.71705462333228
#
# Prediction Statistics:
# Component 0: mean=9.90e-04, std=5.39e-04
# Component 1: mean=-2.62e-07, std=1.16e-04
# Component 2: mean=1.03e-03, std=5.48e-04
# Component 3: mean=2.96e-06, std=1.18e-04
# Component 4: mean=-2.32e-05, std=1.22e-04
# Component 5: mean=1.00e-03, std=5.54e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 96/200, Loss: 317.291070
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 97/200, Loss: 308.090610
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 98/200, Loss: 301.422009
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 99/200, Loss: 307.111932
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 100/200, Loss: 309.854346
#
# Epoch 100 Statistics:
#
# Absolute Errors per component:
# Component 0: 4.73e-05
# Component 1: 5.77e-05
# Component 2: 4.55e-05
# Component 3: 5.88e-05
# Component 4: 5.53e-05
# Component 5: 4.82e-05
# Mean Diffusivity Absolute Error: 2.66e-05
# FA Absolute Error: 5.53e-02
# Angular Error: 26.133920712277398
#
# Prediction Statistics:
# Component 0: mean=9.89e-04, std=5.41e-04
# Component 1: mean=-5.99e-07, std=1.16e-04
# Component 2: mean=1.03e-03, std=5.48e-04
# Component 3: mean=3.20e-06, std=1.19e-04
# Component 4: mean=-2.27e-05, std=1.23e-04
# Component 5: mean=1.00e-03, std=5.55e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 101/200, Loss: 304.299653
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 102/200, Loss: 308.743141
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 103/200, Loss: 302.747600
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 104/200, Loss: 298.252712
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 105/200, Loss: 298.466223
#
# Epoch 105 Statistics:
#
# Absolute Errors per component:
# Component 0: 5.49e-05
# Component 1: 5.73e-05
# Component 2: 4.45e-05
# Component 3: 5.50e-05
# Component 4: 5.21e-05
# Component 5: 4.69e-05
# Mean Diffusivity Absolute Error: 2.75e-05
# FA Absolute Error: 5.31e-02
# Angular Error: 25.699131941667847
#
# Prediction Statistics:
# Component 0: mean=9.90e-04, std=5.39e-04
# Component 1: mean=-4.46e-07, std=1.14e-04
# Component 2: mean=1.03e-03, std=5.48e-04
# Component 3: mean=3.10e-06, std=1.17e-04
# Component 4: mean=-2.30e-05, std=1.24e-04
# Component 5: mean=1.00e-03, std=5.55e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 106/200, Loss: 299.002265
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 107/200, Loss: 304.143656
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 108/200, Loss: 292.385038
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 109/200, Loss: 297.584937
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 110/200, Loss: 295.643251
#
# Epoch 110 Statistics:
#
# Absolute Errors per component:
# Component 0: 5.07e-05
# Component 1: 5.50e-05
# Component 2: 4.20e-05
# Component 3: 5.57e-05
# Component 4: 5.28e-05
# Component 5: 4.60e-05
# Mean Diffusivity Absolute Error: 2.62e-05
# FA Absolute Error: 5.22e-02
# Angular Error: 25.245109750290872
#
# Prediction Statistics:
# Component 0: mean=9.90e-04, std=5.40e-04
# Component 1: mean=-2.39e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.49e-04
# Component 3: mean=3.03e-06, std=1.16e-04
# Component 4: mean=-2.30e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.55e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 111/200, Loss: 291.643636
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 112/200, Loss: 292.828557
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 113/200, Loss: 297.041450
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 114/200, Loss: 286.742646
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 115/200, Loss: 291.735549
#
# Epoch 115 Statistics:
#
# Absolute Errors per component:
# Component 0: 4.67e-05
# Component 1: 5.57e-05
# Component 2: 4.50e-05
# Component 3: 5.35e-05
# Component 4: 5.19e-05
# Component 5: 4.75e-05
# Mean Diffusivity Absolute Error: 2.60e-05
# FA Absolute Error: 5.14e-02
# Angular Error: 25.35931147248197
#
# Prediction Statistics:
# Component 0: mean=9.89e-04, std=5.41e-04
# Component 1: mean=-6.05e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.48e-04
# Component 3: mean=2.72e-06, std=1.16e-04
# Component 4: mean=-2.29e-05, std=1.21e-04
# Component 5: mean=1.00e-03, std=5.55e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 116/200, Loss: 289.224575
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 117/200, Loss: 288.140580
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 118/200, Loss: 288.480176
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 119/200, Loss: 292.051424
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 120/200, Loss: 289.245994
#
# Epoch 120 Statistics:
#
# Absolute Errors per component:
# Component 0: 5.40e-05
# Component 1: 5.48e-05
# Component 2: 4.39e-05
# Component 3: 5.31e-05
# Component 4: 5.12e-05
# Component 5: 4.65e-05
# Mean Diffusivity Absolute Error: 2.70e-05
# FA Absolute Error: 5.12e-02
# Angular Error: 25.381504341985586
#
# Prediction Statistics:
# Component 0: mean=9.90e-04, std=5.40e-04
# Component 1: mean=-2.71e-07, std=1.12e-04
# Component 2: mean=1.03e-03, std=5.48e-04
# Component 3: mean=3.03e-06, std=1.16e-04
# Component 4: mean=-2.33e-05, std=1.24e-04
# Component 5: mean=1.00e-03, std=5.56e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 121/200, Loss: 284.434594
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 122/200, Loss: 289.746687
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 123/200, Loss: 285.089657
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 124/200, Loss: 284.575242
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 125/200, Loss: 286.954585
#
# Epoch 125 Statistics:
#
# Absolute Errors per component:
# Component 0: 5.02e-05
# Component 1: 5.24e-05
# Component 2: 4.16e-05
# Component 3: 5.44e-05
# Component 4: 5.16e-05
# Component 5: 4.59e-05
# Mean Diffusivity Absolute Error: 2.63e-05
# FA Absolute Error: 5.07e-02
# Angular Error: 24.952242118932254
#
# Prediction Statistics:
# Component 0: mean=9.89e-04, std=5.40e-04
# Component 1: mean=-3.97e-07, std=1.14e-04
# Component 2: mean=1.03e-03, std=5.49e-04
# Component 3: mean=2.71e-06, std=1.16e-04
# Component 4: mean=-2.27e-05, std=1.19e-04
# Component 5: mean=1.00e-03, std=5.55e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 126/200, Loss: 285.409641
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 127/200, Loss: 278.561604
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 128/200, Loss: 285.996215
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 129/200, Loss: 275.224909
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 130/200, Loss: 290.255989
#
# Epoch 130 Statistics:
#
# Absolute Errors per component:
# Component 0: 4.66e-05
# Component 1: 5.53e-05
# Component 2: 4.50e-05
# Component 3: 5.34e-05
# Component 4: 5.15e-05
# Component 5: 4.75e-05
# Mean Diffusivity Absolute Error: 2.63e-05
# FA Absolute Error: 5.13e-02
# Angular Error: 25.365998824524304
#
# Prediction Statistics:
# Component 0: mean=9.89e-04, std=5.42e-04
# Component 1: mean=-5.78e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.49e-04
# Component 3: mean=2.97e-06, std=1.16e-04
# Component 4: mean=-2.30e-05, std=1.22e-04
# Component 5: mean=1.00e-03, std=5.55e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 131/200, Loss: 278.414394
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 132/200, Loss: 285.605425
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 133/200, Loss: 281.165354
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 134/200, Loss: 283.501320
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 135/200, Loss: 276.137958
#
# Epoch 135 Statistics:
#
# Absolute Errors per component:
# Component 0: 5.37e-05
# Component 1: 5.32e-05
# Component 2: 4.33e-05
# Component 3: 5.17e-05
# Component 4: 4.65e-05
# Component 5: 4.60e-05
# Mean Diffusivity Absolute Error: 2.64e-05
# FA Absolute Error: 4.87e-02
# Angular Error: 24.76923499247326
#
# Prediction Statistics:
# Component 0: mean=9.89e-04, std=5.40e-04
# Component 1: mean=-4.28e-07, std=1.12e-04
# Component 2: mean=1.03e-03, std=5.49e-04
# Component 3: mean=2.90e-06, std=1.15e-04
# Component 4: mean=-2.30e-05, std=1.21e-04
# Component 5: mean=1.00e-03, std=5.56e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 136/200, Loss: 276.321968
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 137/200, Loss: 281.475745
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 138/200, Loss: 272.042614
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 139/200, Loss: 278.403291
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 140/200, Loss: 275.980116
#
# Epoch 140 Statistics:
#
# Absolute Errors per component:
# Component 0: 4.97e-05
# Component 1: 5.00e-05
# Component 2: 4.13e-05
# Component 3: 5.23e-05
# Component 4: 4.97e-05
# Component 5: 4.52e-05
# Mean Diffusivity Absolute Error: 2.57e-05
# FA Absolute Error: 4.86e-02
# Angular Error: 24.412652546572026
#
# Prediction Statistics:
# Component 0: mean=9.89e-04, std=5.40e-04
# Component 1: mean=-9.49e-08, std=1.13e-04
# Component 2: mean=1.03e-03, std=5.49e-04
# Component 3: mean=2.82e-06, std=1.15e-04
# Component 4: mean=-2.30e-05, std=1.18e-04
# Component 5: mean=1.00e-03, std=5.56e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 141/200, Loss: 279.931356
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 142/200, Loss: 275.241356
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 143/200, Loss: 278.465493
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 144/200, Loss: 276.975805
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 145/200, Loss: 269.520198
#
# Epoch 145 Statistics:
#
# Absolute Errors per component:
# Component 0: 4.56e-05
# Component 1: 5.07e-05
# Component 2: 4.44e-05
# Component 3: 4.97e-05
# Component 4: 4.76e-05
# Component 5: 4.68e-05
# Mean Diffusivity Absolute Error: 2.56e-05
# FA Absolute Error: 4.72e-02
# Angular Error: 24.3144232173295
#
# Prediction Statistics:
# Component 0: mean=9.89e-04, std=5.42e-04
# Component 1: mean=-4.90e-07, std=1.12e-04
# Component 2: mean=1.03e-03, std=5.49e-04
# Component 3: mean=2.92e-06, std=1.14e-04
# Component 4: mean=-2.29e-05, std=1.19e-04
# Component 5: mean=1.00e-03, std=5.56e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 146/200, Loss: 278.663818
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 147/200, Loss: 272.742262
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 148/200, Loss: 273.669591
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 149/200, Loss: 274.277141
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 150/200, Loss: 274.210028
#
# Epoch 150 Statistics:
#
# Absolute Errors per component:
# Component 0: 5.31e-05
# Component 1: 5.26e-05
# Component 2: 4.30e-05
# Component 3: 5.09e-05
# Component 4: 4.68e-05
# Component 5: 4.58e-05
# Mean Diffusivity Absolute Error: 2.60e-05
# FA Absolute Error: 4.81e-02
# Angular Error: 24.670524219817064
#
# Prediction Statistics:
# Component 0: mean=9.89e-04, std=5.40e-04
# Component 1: mean=-1.41e-07, std=1.12e-04
# Component 2: mean=1.03e-03, std=5.49e-04
# Component 3: mean=2.87e-06, std=1.15e-04
# Component 4: mean=-2.30e-05, std=1.21e-04
# Component 5: mean=1.00e-03, std=5.56e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 151/200, Loss: 268.136614
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 152/200, Loss: 269.527762
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 153/200, Loss: 268.098413
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 154/200, Loss: 262.791799
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 155/200, Loss: 270.526654
#
# Epoch 155 Statistics:
#
# Absolute Errors per component:
# Component 0: 4.93e-05
# Component 1: 4.99e-05
# Component 2: 4.06e-05
# Component 3: 5.06e-05
# Component 4: 4.84e-05
# Component 5: 4.49e-05
# Mean Diffusivity Absolute Error: 2.53e-05
# FA Absolute Error: 4.77e-02
# Angular Error: 24.045557076117102
#
# Prediction Statistics:
# Component 0: mean=9.89e-04, std=5.40e-04
# Component 1: mean=-2.25e-07, std=1.13e-04
# Component 2: mean=1.03e-03, std=5.49e-04
# Component 3: mean=2.79e-06, std=1.13e-04
# Component 4: mean=-2.31e-05, std=1.18e-04
# Component 5: mean=1.00e-03, std=5.56e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 156/200, Loss: 270.010791
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 157/200, Loss: 264.286188
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 158/200, Loss: 268.215369
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 159/200, Loss: 263.252403
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 160/200, Loss: 262.864184
#
# Epoch 160 Statistics:
#
# Absolute Errors per component:
# Component 0: 4.58e-05
# Component 1: 4.95e-05
# Component 2: 4.40e-05
# Component 3: 4.92e-05
# Component 4: 4.54e-05
# Component 5: 4.63e-05
# Mean Diffusivity Absolute Error: 2.51e-05
# FA Absolute Error: 4.60e-02
# Angular Error: 23.95132293376902
#
# Prediction Statistics:
# Component 0: mean=9.88e-04, std=5.41e-04
# Component 1: mean=-5.52e-07, std=1.12e-04
# Component 2: mean=1.03e-03, std=5.49e-04
# Component 3: mean=3.13e-06, std=1.13e-04
# Component 4: mean=-2.29e-05, std=1.18e-04
# Component 5: mean=1.00e-03, std=5.56e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 161/200, Loss: 271.413788
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 162/200, Loss: 261.187131
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 163/200, Loss: 267.779016
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 164/200, Loss: 263.879976
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 165/200, Loss: 266.793648
#
# Epoch 165 Statistics:
#
# Absolute Errors per component:
# Component 0: 5.29e-05
# Component 1: 5.32e-05
# Component 2: 4.27e-05
# Component 3: 4.81e-05
# Component 4: 4.46e-05
# Component 5: 4.51e-05
# Mean Diffusivity Absolute Error: 2.55e-05
# FA Absolute Error: 4.69e-02
# Angular Error: 24.42798651021566
#
# Prediction Statistics:
# Component 0: mean=9.89e-04, std=5.40e-04
# Component 1: mean=-2.99e-07, std=1.12e-04
# Component 2: mean=1.03e-03, std=5.49e-04
# Component 3: mean=2.84e-06, std=1.13e-04
# Component 4: mean=-2.32e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.56e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 166/200, Loss: 260.285923
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 167/200, Loss: 267.807689
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 168/200, Loss: 260.653117
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 169/200, Loss: 264.158823
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 170/200, Loss: 263.742192
#
# Epoch 170 Statistics:
#
# Absolute Errors per component:
# Component 0: 4.90e-05
# Component 1: 4.89e-05
# Component 2: 4.03e-05
# Component 3: 4.86e-05
# Component 4: 4.74e-05
# Component 5: 4.45e-05
# Mean Diffusivity Absolute Error: 2.49e-05
# FA Absolute Error: 4.64e-02
# Angular Error: 23.82204142014881
#
# Prediction Statistics:
# Component 0: mean=9.89e-04, std=5.41e-04
# Component 1: mean=-2.41e-07, std=1.12e-04
# Component 2: mean=1.03e-03, std=5.49e-04
# Component 3: mean=3.29e-06, std=1.12e-04
# Component 4: mean=-2.31e-05, std=1.17e-04
# Component 5: mean=1.00e-03, std=5.56e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 171/200, Loss: 264.041194
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 172/200, Loss: 261.498442
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 173/200, Loss: 260.257814
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 174/200, Loss: 258.976174
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 175/200, Loss: 258.956220
#
# Epoch 175 Statistics:
#
# Absolute Errors per component:
# Component 0: 4.52e-05
# Component 1: 4.80e-05
# Component 2: 4.33e-05
# Component 3: 5.00e-05
# Component 4: 4.40e-05
# Component 5: 4.60e-05
# Mean Diffusivity Absolute Error: 2.45e-05
# FA Absolute Error: 4.54e-02
# Angular Error: 23.64623754879316
#
# Prediction Statistics:
# Component 0: mean=9.88e-04, std=5.41e-04
# Component 1: mean=-6.56e-07, std=1.10e-04
# Component 2: mean=1.03e-03, std=5.49e-04
# Component 3: mean=3.08e-06, std=1.14e-04
# Component 4: mean=-2.33e-05, std=1.18e-04
# Component 5: mean=1.00e-03, std=5.56e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.89e-04, std=5.49e-04
# Component 1: mean=-6.64e-07, std=1.15e-04
# Component 2: mean=1.03e-03, std=5.55e-04
# Component 3: mean=3.00e-06, std=1.16e-04
# Component 4: mean=-2.31e-05, std=1.20e-04
# Component 5: mean=1.00e-03, std=5.63e-04
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 176/200, Loss: 265.309076
#
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Epoch 177/200, Loss: 259.589703
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 44
#      42 # loss = model.weighted_mse_loss(pred, batch_data.y) * 1e6
#      43 loss = model.weighted_mae_loss(pred, batch_data.y) * 1e5
# ---> 44 loss.backward()
#      45 optimizer.step()
#      47 # Store batch results
#
# File c:\Users\ishui\anaconda3\envs\neuro\Lib\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File c:\Users\ishui\anaconda3\envs\neuro\Lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File c:\Users\ishui\anaconda3\envs\neuro\Lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(10, 6))
plt.semilogy(range(1, len(losses) + 1), losses)  # Using log scale for y-axis 
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.title('Training Loss Over Time')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(40, len(losses) + 1), losses[39:])  # Using log scale for y-axis
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.title('Training Loss Over Time')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(60, len(losses) + 1), losses[59:])  # Using log scale for y-axis
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Over Time')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(range(90, len(losses) + 1), losses[89:])  # Using log scale for y-axis
plt.xlabel('Epoch')
plt.ylabel('Loss (log scale)')
plt.title('Training Loss Over Time')
plt.grid(True)
plt.show()

# %%
# Plot FA error
plt.figure(figsize=(10, 6))
plt.plot([m['epoch'] for m in all_metrics if m['epoch'] >= 40], 
         [m['fa_error'] for m in all_metrics if m['epoch'] >= 40])
plt.xlabel('Epoch')
plt.ylabel('FA Error')
plt.title('FA Error Over Time')
plt.grid(True)
plt.show()

# Plot MD error
plt.figure(figsize=(10, 6))
plt.plot([m['epoch'] for m in all_metrics], [m['md_error'] for m in all_metrics])
plt.xlabel('Epoch')
plt.ylabel('MD Error')
plt.title('MD Error Over Time')
plt.grid(True)
plt.show()

# Ang error
plt.figure(figsize=(10, 6))
plt.plot([m['epoch'] for m in all_metrics if m['epoch'] >= 30], [m['angular_error'] for m in all_metrics if m['epoch'] >= 30])
plt.ylim(ymin=10)
plt.xlabel('Epoch')
plt.ylabel('Angular Error in degrees')
plt.title('Angular Error Over Time')
plt.grid(True)
plt.show()

# %%
print("\nStarting Final Evaluation...")
model.eval()
test_losses = []
test_preds = []
test_gts = []

with torch.no_grad():
    # Process all batches, including last partial batch
    for start in range(0, len(test_idx), batch_size):
        end = min(start + batch_size, len(test_idx))
        batch_indices = test_idx[start:end]
        
        # Create graph data using precomputed structures
        nodes, edges, edge_weights, tensors = create_batch_data(
            batch_indices,
            direction_structures_gpu[direction_set_idx],
            features_gpu,
            ground_truth_gpu
        )

        data_list = convert_to_torch_geometric(nodes, edges, edge_weights, tensors)
        batch_data = Batch.from_data_list(data_list).to(device)
        
        # Get predictions
        pred = model(batch_data.x, batch_data.edge_index, batch_data.edge_attr, batch_data.batch)
        
        # Calculate loss
        # test_loss = model.weighted_mse_loss(pred, batch_data.y) * 1e6
        test_loss = model.weighted_mae_loss(pred, batch_data.y) * 1e5
        test_losses.append(test_loss.item())
        
        # Store predictions and ground truth
        test_preds.append(pred.cpu().numpy())
        test_gts.append(batch_data.y.cpu().numpy())

# Combine results
all_test_preds = np.concatenate(test_preds, axis=0)
all_test_gts = np.concatenate(test_gts, axis=0)
avg_test_loss = np.mean(test_losses)

print(f"\nFinal Test Results:")
print(f"Average test loss: {avg_test_loss:.6f}")

# Use same evaluation function as training
metrics = evaluate_model(all_test_preds, all_test_gts, epoch=-2)

with open('results.txt', 'a') as f:
    f.write(f"\nTest Results {datetime.datetime.now()}:\n")
    f.write(f"Epochs = {epochs}, voxels trained on = {n_samples}, Batch_size = {batch_size}, Learning Rate = {learning_rate}\n")  # whatever hyperparams you care about
    f.write(f"Test loss={avg_test_loss:.6f}\n")
    f.write(f"MD Abs err = {metrics["md_error"]}, FA Abs err = {metrics["fa_error"]}, Ang err = {metrics["angular_error"]}\n")
    f.write("-" * 60 + "\n")

# Print random examples from full test set
print("\nExample predictions vs ground truth (randomly sampled):")
n_examples = 5
rand_indices = np.random.choice(len(all_test_preds), n_examples, replace=False)
for i, idx in enumerate(rand_indices):
    print(f"\nSample {i+1}:")
    print(f"Predicted: {all_test_preds[idx]}")
    print(f"Actual:    {all_test_gts[idx]}")
# Out:
# Starting Final Evaluation...
#
# Final Test Results:
# Average test loss: 219.523766
#
# Epoch -1 Statistics:
#
# Absolute Errors per component:
# Component 0: 5.15e-05
# Component 1: 3.65e-05
# Component 2: 4.18e-05
# Component 3: 4.09e-05
# Component 4: 4.08e-05
# Component 5: 4.12e-05
# Mean Diffusivity Absolute Error: 2.35e-05
# FA Absolute Error: 4.04e-02
# Angular Error: 11.6287518507185
#
# Prediction Statistics:
# Component 0: mean=9.87e-04, std=5.37e-04
# Component 1: mean=-1.60e-06, std=1.06e-04
# Component 2: mean=1.01e-03, std=5.39e-04
# Component 3: mean=-2.41e-05, std=1.06e-04
# Component 4: mean=2.61e-06, std=1.09e-04
# Component 5: mean=1.00e-03, std=5.50e-04
#
# Ground Truth Statistics:
# Component 0: mean=9.85e-04, std=5.44e-04
# Component 1: mean=8.57e-08, std=1.16e-04
# Component 2: mean=1.02e-03, std=5.53e-04
# Component 3: mean=3.50e-06, std=1.16e-04
# Component 4: mean=-2.35e-05, std=1.25e-04
# Component 5: mean=9.98e-04, std=5.62e-04
#
# Example predictions vs ground truth (randomly sampled):
#
# Sample 1:
# Predicted: [ 8.9525135e-04  5.9711787e-05  9.2636148e-04 -2.3159406e-05
#   1.5584759e-04  6.9545081e-04]
# Actual:    [ 8.95020271e-04  4.67537464e-05  1.06879435e-03 -9.11300847e-05
#   1.50105203e-04  6.36496905e-04]
#
# Sample 2:
# Predicted: [ 9.7134936e-04  1.1742215e-04  1.0721684e-03  2.6611649e-05
#  -4.6773996e-05  1.2177280e-03]
# Actual:    [ 1.12095625e-03  4.01553766e-05  1.10727055e-03  1.54346461e-04
#  -6.85598318e-05  1.34774825e-03]
#
# Sample 3:
# Predicted: [ 0.00069869 -0.00013088  0.00075515 -0.00031784  0.00019692  0.00082142]
# Actual:    [ 0.00073849 -0.00013633  0.00080021 -0.0003445   0.0002357   0.00071802]
#
# Sample 4:
# Predicted: [ 9.3576382e-04 -1.2727670e-06  7.2617701e-04  1.2181295e-04
#  -1.0512228e-04  9.9635904e-04]
# Actual:    [ 9.83869427e-04  1.83874988e-05  7.32708333e-04  1.45704608e-04
#  -1.35437688e-04  9.88017900e-04]
#
# Sample 5:
# Predicted: [1.0285547e-03 2.2766955e-05 1.1391612e-03 2.0168662e-05 2.7023578e-05
#  1.1644141e-03]
# Actual:    [ 1.01770533e-03 -3.06301195e-05  1.26350231e-03  1.29105297e-04
#   1.16652462e-04  1.10194291e-03]

# %%
# def count_parameters(model):
#     return sum(p.numel() for p in model.parameters() if p.requires_grad)

# total_params = count_parameters(model)
# print(f'Total trainable parameters: {total_params:,}')
